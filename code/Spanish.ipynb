# %% [markdown]
# ---
# # **SPANISH**
# ---

# %% [markdown]
# ### **STEP 1: Downloading and installing the dependencies:**
# >>**English PyMUSAS RuleBasedTagger**
#
# >>**English spaCy pipeline**
#
# >>**colorama:** *Colorama is a Python module that displays colored output in consoles.*
# ---

# %%
# !pip install https://github.com/UCREL/pymusas-models/releases/download/es_dual_upos2usas_contextual-0.3.3/es_dual_upos2usas_contextual-0.3.3-py3-none-any.whl
# !python -m spacy download es_core_news_sm
# Out:
# Collecting es-dual-upos2usas-contextual==0.3.3
#   Downloading https://github.com/UCREL/pymusas-models/releases/download/es_dual_upos2usas_contextual-0.3.3/es_dual_upos2usas_contextual-0.3.3-py3-none-any.whl (208 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.0/209.0 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<4.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from es-dual-upos2usas-contextual==0.3.3) (3.8.7)
# Collecting pymusas<0.4.0,>=0.3.0 (from es-dual-upos2usas-contextual==0.3.3)
#   Downloading pymusas-0.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from pymusas<0.4.0,>=0.3.0->es-dual-upos2usas-contextual==0.3.3) (2.5.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.50.0 in /usr/local/lib/python3.11/dist-packages (from pymusas<0.4.0,>=0.3.0->es-dual-upos2usas-contextual==0.3.3) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from pymusas<0.4.0,>=0.3.0->es-dual-upos2usas-contextual==0.3.3) (2.32.3)
# Collecting click<8.1.0 (from pymusas<0.4.0,>=0.3.0->es-dual-upos2usas-contextual==0.3.3)
#   Downloading click-8.0.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (1.1.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (0.16.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (2.0.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (2.11.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->pymusas<0.4.0,>=0.3.0->es-dual-upos2usas-contextual==0.3.3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->pymusas<0.4.0,>=0.3.0->es-dual-upos2usas-contextual==0.3.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->pymusas<0.4.0,>=0.3.0->es-dual-upos2usas-contextual==0.3.3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->pymusas<0.4.0,>=0.3.0->es-dual-upos2usas-contextual==0.3.3) (2025.6.15)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->es-dual-upos2usas-contextual==0.3.3) (0.1.2)
# Downloading pymusas-0.3.0-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 2.5 MB/s eta 0:00:00
# Downloading click-8.0.4-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: click, pymusas, es-dual-upos2usas-contextual
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 3.1.1 requires click>=8.1.3, but you have click 8.0.4 which is incompatible.
# dask 2024.12.1 requires click>=8.1, but you have click 8.0.4 which is incompatible.
# dask-cuda 25.2.0 requires click>=8.1, but you have click 8.0.4 which is incompatible.
# Successfully installed click-8.0.4 es-dual-upos2usas-contextual-0.3.3 pymusas-0.3.0
# Collecting es-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.8.0/es_core_news_sm-3.8.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 65.0 MB/s eta 0:00:00
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !pip install colorama
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %% [markdown]
# ---
# ### **STEP 2: Creating the tagger**
#
# ---

# %%
import spacy

# We exclude the following components as we do not need them.
nlp = spacy.load('es_core_news_sm', exclude=['parser', 'ner'])
# Load the Spanish PyMUSAS rule-based tagger in a separate spaCy pipeline
spanish_tagger_pipeline = spacy.load('es_dual_upos2usas_contextual')
# Adds the Spanish PyMUSAS rule-based tagger to the main spaCy pipeline
nlp.add_pipe('pymusas_rule_based_tagger', source=spanish_tagger_pipeline)

# %% [markdown]
# ---
#
# ### **STEP 3: Importing the libraries**
#
# ---

# %%
import re
import pandas as pd
import numpy as np
from colorama import Fore, Back, Style

import nltk
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %% [markdown]
# ---
# ### **STEP 4: Tagging text:** *tag_text function*
#
# >>**input:** piece of text
#
# >>**output:** python dictionary where *keys* represent the index of a sentence in the input text and *values* represent the usas semantic tags for that sentence
#
# ---

# %%
# Defining the tagging function
def tag_text(text):
  usas_eval_tags = {}
  usas_list = {}
  sentences = nltk.sent_tokenize(text)
  for i in range(len(sentences)):
    if(sentences[i]):
      print(Fore.GREEN + Style.BRIGHT + "------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
      print(Fore.CYAN + Style.BRIGHT + f"Sentence {i}:", sentences[i])
      print(Fore.CYAN + Style.BRIGHT + "------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
      sent = nlp(sentences[i])
      for token in sent:
        tags = token._.pymusas_tags
        print(Fore.CYAN + f'{token.text}:' + Fore.GREEN, tags)
        for tag in tags:
          usas_list[token.text] = token._.pymusas_tags
      usas_eval_tags[i] = usas_list
  return usas_eval_tags

# %%
# Input text 1
text_1 = """Hola camaradas, solo quería compartir mi historia después de una operación en la que marqué otro gol contra el cáncer y lo puse 3-0. Espero que pueda inspirar a alguien por ahí.

Fui diagnosticado con cáncer de colon en mayo de 2020, cuando tuve una hemorragia importante. Antes de darme cuenta, los cirujanos me extirparon 30 cm de colon. La recuperación fue dura, pero manejable. Lo bueno es que, aunque el tumor era grande, los ganglios linfáticos estaban limpios, colocándome en estadio 2. Según los médicos, estaba libre y era uno de los afortunados que podía dejar el cáncer atrás y contar la historia en un bar. El marcador era 1-0 para mí.

Sin embargo, más tarde aprendí por las malas que esta mierda también puede viajar por la sangre. En enero de 2021, mi escáner de rutina mostró noticias desagradables. Tenía varias lesiones en el hígado y mi mundo colapsó cuando el cirujano me dijo que era inoperable. Ahora era un estadio 4 de cáncer de colon con metástasis hepática inoperable y dos niños pequeños de 3 y 5 años que no podía dejar sin padre.

Esto fue durante los días de confinamiento por coronavirus, y mi familia e hijos no podían acompañarme todo el tiempo en el hospital por las restricciones.

Sin embargo, no soy de rendirme, y lo asumí como un nuevo reto que debía superar. Con pocas probabilidades al inicio, después de 1,5 años de quimioterapia y radioterapia que me patearon el trasero, no necesité ni siquiera una operación de hígado. El marcador iba 2-0 y cruzábamos los dedos para que no volviera nunca.

No volvió, pero un cáncer completamente distinto sería mi nuevo reto. Los médicos sospecharon algo en mi tiroides durante otro escáner de rutina. Tras pruebas y biopsias con aguja, resultó que ahora tengo cáncer de tiroides. Pensé: “meh, este es fácil”.

Ayer me extirparon toda la tiroides en una operación. El tumor ya medía 2 cm. Ahora estamos 3-0. No sé qué me espera, pero sea lo que sea, lo enfrentaré y lo combatiré. Mientras tanto, recibiré quimioterapia preventiva cada 6 meses y seguiré disfrutando de criar a mis hijos.

Así que, camarada, considera lo tuyo como un reto también. Tienes la fuerza y el optimismo para enfrentarlo, no importa lo dura que sea la vida. Mantén la cabeza en alto y sigue anotando."""

# %%
# Tagging input text 1
text1_tags = tag_text(text_1)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 0: Hola camaradas, solo quería compartir mi historia después de una operación en la que marqué otro gol contra el cáncer y lo puse 3-0.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Hola: ['Z99']
# camaradas: ['Z99']
# ,: ['PUNCT']
# solo: ['A14', 'S5-', 'N5---', 'S5-', 'S3.2-']
# quería: ['X7+', 'A2', 'S7', 'X2']
# compartir: ['S1.1.2+']
# mi: ['Z5', 'Z8', 'A9']
# historia: ['T1.1', 'X2', 'G1', 'P1', 'T3+']
# después: ['N4', 'Z5', 'T1.1']
# de: ['Z5']
# una: ['Z5', 'Z8', 'N1']
# operación: ['N2', 'B3', 'I2.2', 'G3', 'A1.1.1', 'X2.4']
# en: ['Z5', 'N3']
# la: ['Z5']
# que: ['Z5', 'Z8']
# marqué: ['Z99']
# otro: ['Z8', 'A6.1-m', 'N5++']
# gol: ['Z99']
# contra: ['Z5', 'A1.8', 'S3']
# el: ['Z5']
# cáncer: ['B2-']
# y: ['Z5', 'A1.8+']
# lo: ['Z5', 'Z8']
# puse: ['M2', 'A9', 'A1.1.1']
# 3-0: ['N1']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 1: Espero que pueda inspirar a alguien por ahí.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Espero: ['T1.3', 'X2.6+', 'A3+', 'E4.1+', 'X9.2+']
# que: ['Z5', 'Z8']
# pueda: ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1']
# inspirar: ['Z99']
# a: ['Z5']
# alguien: ['Z5', 'S2m']
# por: ['Z5', 'A2.2', 'M1', 'M6']
# ahí: ['M7', 'M6', 'T1.2', 'Z5']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 2: Fui diagnosticado con cáncer de colon en mayo de 2020, cuando tuve una hemorragia importante.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Fui: ['M1']
# diagnosticado: ['Z99']
# con: ['Z5', 'A4.1']
# cáncer: ['B2-']
# de: ['Z5']
# colon: ['Z99']
# en: ['Z5', 'N3']
# mayo: ['T1.3', 'Z1f']
# de: ['Z5']
# 2020: ['N1']
# ,: ['PUNCT']
# cuando: ['Z5', 'T1.1']
# tuve: ['A9']
# una: ['Z5', 'Z8', 'N1']
# hemorragia: ['Z99']
# importante: ['A5', 'A11.1+', 'A13.2']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 3: Antes de darme cuenta, los cirujanos me extirparon 30 cm de colon.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Antes: ['N4', 'Z5', 'N3', 'T1.1']
# de: ['Z5']
# darme: ['Z99']
# cuenta: ['I1.1/N2/Y2', 'N5', 'N5.1+', 'I1.3.1', 'O2']
# ,: ['PUNCT']
# los: ['Z5']
# cirujanos: ['B3/S2mf']
# me: ['Z5', 'Z8']
# extirparon: ['Z99']
# 30: ['N1']
# cm: ['Z99']
# de: ['Z5']
# colon: ['Z99']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 4: La recuperación fue dura, pero manejable.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# La: ['Z5']
# recuperación: ['Z99']
# fue: ['A3+', 'L1', 'Z5']
# dura: ['A13', 'O4']
# ,: ['PUNCT']
# pero: ['Z5', 'A2.2-', 'A6.1-']
# manejable: ['Z99']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 5: Lo bueno es que, aunque el tumor era grande, los ganglios linfáticos estaban limpios, colocándome en estadio 2.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lo: ['Z8m']
# bueno: ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+', 'E1', 'E2+']
# es: ['Z5', 'A3+']
# que: ['Z5', 'Z8']
# ,: ['PUNCT']
# aunque: ['Z5', 'A13']
# el: ['Z5']
# tumor: ['Z99']
# era: ['Z5', 'A3+']
# grande: ['N3.1+/A6.1+/A13.2+', 'A5']
# ,: ['PUNCT']
# los: ['Z5']
# ganglios: ['Z99']
# linfáticos: ['Z99']
# estaban: ['A3+']
# limpios: ['B4', 'O4.2+', 'G2.2+']
# ,: ['PUNCT']
# colocándome: ['Z99']
# en: ['Z5', 'N3']
# estadio: ['K5.1/H1']
# 2: ['N1']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 6: Según los médicos, estaba libre y era uno de los afortunados que podía dejar el cáncer atrás y contar la historia en un bar.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Según: ['Z5', 'A9', 'S1.1']
# los: ['Z5']
# médicos: ['B2']
# ,: ['PUNCT']
# estaba: ['A3+']
# libre: ['A10', 'S7.2', 'S9', 'A5.1+', 'X2.1', 'A1.7-', 'A5.2+', 'A12+', 'X5.2+']
# y: ['Z5', 'A1.8+']
# era: ['Z5', 'A3+']
# uno: ['Z5', 'N1', 'T3', 'T1.2', 'Z8']
# de: ['Z5']
# los: ['Z5']
# afortunados: ['A1.4+']
# que: ['Z5', 'Z8']
# podía: ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1']
# dejar: ['S7.4', 'A3']
# el: ['Z5']
# cáncer: ['B2-']
# atrás: ['Z5', 'N3']
# y: ['Z5', 'A1.8+']
# contar: ['N2', 'Q2.2', 'Q2.1', 'A10+', 'A11.1+']
# la: ['Z5']
# historia: ['T1.1', 'X2', 'G1', 'P1', 'T3+']
# en: ['Z5', 'N3']
# un: ['Z5', 'N1']
# bar: ['Z99']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 7: El marcador era 1-0 para mí.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# El: ['Z5']
# marcador: ['Z99']
# era: ['Z5', 'A3+']
# 1-0: ['N1']
# para: ['Z5']
# mí: ['Z8mf']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 8: Sin embargo, más tarde aprendí por las malas que esta mierda también puede viajar por la sangre.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sin: ['Z5', 'A13.7', 'A10-']
# embargo: ['I1', 'G2.1']
# ,: ['PUNCT']
# más: ['A13.3', 'N6++', 'Z5']
# tarde: ['T4-', 'L1-', 'T1.1']
# aprendí: ['X2.3+', 'P1']
# por: ['Z5', 'A2.2', 'M1', 'M6']
# las: ['Z5']
# malas: ['Z99']
# que: ['Z5', 'Z8']
# esta: ['Z5', 'A3', 'S2.2']
# mierda: ['Z99']
# también: ['N5++', 'Z5']
# puede: ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1<']
# viajar: ['M1', 'M5', 'M7', 'S3.1']
# por: ['Z5', 'A2.2', 'M1', 'M6']
# la: ['Z5']
# sangre: ['B2', 'O4.3']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 9: En enero de 2021, mi escáner de rutina mostró noticias desagradables.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# En: ['Z5', 'N3']
# enero: ['T1.3', 'O4.6-']
# de: ['Z5']
# 2021: ['N1']
# ,: ['PUNCT']
# mi: ['Z5', 'Z8', 'A9']
# escáner: ['Z99']
# de: ['Z5']
# rutina: ['A6.2+', 'X4.2', 'K4']
# mostró: ['A10+', 'S1.1.1']
# noticias: ['Q1', 'Q4']
# desagradables: ['O4.2-']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 10: Tenía varias lesiones en el hígado y mi mundo colapsó cuando el cirujano me dijo que era inoperable.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Tenía: ['A9']
# varias: ['Z5', 'A3', 'A6.3+']
# lesiones: ['Z99']
# en: ['Z5', 'N3']
# el: ['Z5']
# hígado: ['B1', 'F1', 'S2mf']
# y: ['Z5', 'A1.8+']
# mi: ['Z5', 'Z8', 'A9']
# mundo: ['W1', 'S5+c', 'A4.1', 'N5+', 'G2']
# colapsó: ['Z99']
# cuando: ['Z5', 'T1.1']
# el: ['Z5']
# cirujano: ['B3/S2mf']
# me: ['Z5', 'Z8']
# dijo: ['Q1']
# que: ['Z5', 'Z8']
# era: ['Z5', 'A3+']
# inoperable: ['Z99']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 11: Ahora era un estadio 4 de cáncer de colon con metástasis hepática inoperable y dos niños pequeños de 3 y 5 años que no podía dejar sin padre.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Ahora: ['T1.1.2', 'Z4', 'Z5']
# era: ['Z5', 'A3+']
# un: ['Z5', 'N1']
# estadio: ['K5.1/H1']
# 4: ['N1']
# de: ['Z5']
# cáncer: ['B2-']
# de: ['Z5']
# colon: ['Z99']
# con: ['Z5', 'A4.1']
# metástasis: ['Z99']
# hepática: ['Z99']
# inoperable: ['Z99']
# y: ['Z5', 'A1.8+']
# dos: ['Z5', 'N1', 'T3', 'T1.2']
# niños: ['S2mf', 'P1', 'A4.1', 'B1', 'E1+', 'E3']
# pequeños: ['A5', 'A13.7']
# de: ['Z5']
# 3: ['N1']
# y: ['Z5', 'A1.8+']
# 5: ['N1']
# años: ['T1', 'N1', 'T1.3', 'P1c']
# que: ['Z5', 'Z8']
# no: ['S8-', 'Z4', 'Z6', 'Z5']
# podía: ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1']
# dejar: ['S7.4', 'A3']
# sin: ['Z5', 'A13.7', 'A10-']
# padre: ['S4/B1', 'S4m', 'S9/S2.2m', 'S2.1', 'S7', 'P1', 'S5']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 12: Esto fue durante los días de confinamiento por coronavirus, y mi familia e hijos no podían acompañarme todo el tiempo en el hospital por las restricciones.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Esto: ['W3']
# fue: ['A3+', 'L1', 'Z5']
# durante: ['Z5', 'T1.1']
# los: ['Z5']
# días: ['T1.1']
# de: ['Z5']
# confinamiento: ['Z99']
# por: ['Z5', 'A2.2', 'M1', 'M6']
# coronavirus: ['Z99']
# ,: ['PUNCT']
# y: ['Z5', 'A1.8+']
# mi: ['Z5', 'Z8', 'A9']
# familia: ['S3', 'S1.1.3']
# e: ['Z5']
# hijos: ['S2.1/S2.2', 'S3.1', 'S5', 'A9']
# no: ['S8-', 'Z4', 'Z6', 'Z5']
# podían: ['S7']
# acompañarme: ['Z99']
# todo: ['Z5', 'Z8', 'S2', 'A4', 'A9']
# el: ['Z5']
# tiempo: ['T1/W4', 'K5.1', 'T1.2', 'T1.3', 'T1.1.2']
# en: ['Z5', 'N3']
# el: ['Z5']
# hospital: ['B3/H1c', 'B3', 'S1.2.4']
# por: ['Z5', 'A2.2', 'M1', 'M6']
# las: ['Z5']
# restricciones: ['A1.7+']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 13: Sin embargo, no soy de rendirme, y lo asumí como un nuevo reto que debía superar.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sin: ['Z5', 'A13.7', 'A10-']
# embargo: ['I1', 'G2.1']
# ,: ['PUNCT']
# no: ['S8-', 'Z4', 'Z6', 'Z5']
# soy: ['A3+', 'L1', 'Z5']
# de: ['Z5']
# rendirme: ['Z99']
# ,: ['PUNCT']
# y: ['Z5', 'A1.8+']
# lo: ['Z5', 'Z8']
# asumí: ['Z99']
# como: ['Z5']
# un: ['Z5', 'N1']
# nuevo: ['T3-', 'T1.1', 'A5']
# reto: ['Z99']
# que: ['Z5', 'Z8']
# debía: ['S6', 'A7+']
# superar: ['Z99']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 14: Con pocas probabilidades al inicio, después de 1,5 años de quimioterapia y radioterapia que me patearon el trasero, no necesité ni siquiera una operación de hígado.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Con: ['Z5', 'A4.1']
# pocas: ['Z5', 'Z8', 'A6.1-']
# probabilidades: ['A7', 'N1']
# al: ['Z5']
# inicio: ['Z99']
# ,: ['PUNCT']
# después: ['N4', 'Z5', 'T1.1']
# de: ['Z5']
# 1,5: ['N1']
# años: ['T1', 'N1', 'T1.3', 'P1c']
# de: ['Z5']
# quimioterapia: ['Z99']
# y: ['Z5', 'A1.8+']
# radioterapia: ['Z99']
# que: ['Z5', 'Z8']
# me: ['Z5', 'Z8']
# patearon: ['Z99']
# el: ['Z5']
# trasero: ['Z99']
# ,: ['PUNCT']
# no: ['S8-', 'Z4', 'Z6', 'Z5']
# necesité: ['S6+']
# ni: ['Z6', 'A1.8-']
# siquiera: ['Z5', 'A1.9']
# una: ['Z5', 'Z8', 'N1']
# operación: ['N2', 'B3', 'I2.2', 'G3', 'A1.1.1', 'X2.4']
# de: ['Z5']
# hígado: ['B1', 'F1', 'S2mf']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 15: El marcador iba 2-0 y cruzábamos los dedos para que no volviera nunca.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# El: ['Z5']
# marcador: ['Z99']
# iba: ['M1', 'M1', 'A2.1+', 'A1.1.1', 'A9-', 'A1.8+', 'Q2.1', 'N6+', 'I2.2', 'A1.1.2', 'T2-', 'S3.2', 'A6.3+', 'B2-/X1', 'B1']
# 2-0: ['N1']
# y: ['Z5', 'A1.8+']
# cruzábamos: ['Z99']
# los: ['Z5']
# dedos: ['B1']
# para: ['Z5']
# que: ['Z5', 'Z8']
# no: ['S8-', 'Z4', 'Z6', 'Z5']
# volviera: ['M1', 'A2.1+', 'A1.1.1', 'A9-', 'A1.8+', 'Q2.1', 'N6+', 'I2.2', 'A1.1.2', 'T2-', 'S3.2', 'A6.3+', 'B2-/X1', 'B1']
# nunca: ['Z5', 'Z6', 'T2-']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 16: No volvió, pero un cáncer completamente distinto sería mi nuevo reto.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# No: ['S8-', 'Z4', 'Z6', 'Z5']
# volvió: ['M1', 'A2.1+', 'A1.1.1', 'A9-', 'A1.8+', 'Q2.1', 'N6+', 'I2.2', 'A1.1.2', 'T2-', 'S3.2', 'A6.3+', 'B2-/X1', 'B1']
# ,: ['PUNCT']
# pero: ['Z5', 'A2.2-', 'A6.1-']
# un: ['Z5', 'N1']
# cáncer: ['B2-']
# completamente: ['A13.2']
# distinto: ['A6.1-', 'A11.2+']
# sería: ['A3+', 'L1', 'Z5']
# mi: ['Z5', 'Z8', 'A9']
# nuevo: ['T3-', 'T1.1', 'A5']
# reto: ['Z99']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 17: Los médicos sospecharon algo en mi tiroides durante otro escáner de rutina.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Los: ['Z5']
# médicos: ['B2']
# sospecharon: ['Z99']
# algo: ['Z5', 'Z8']
# en: ['Z5', 'N3']
# mi: ['Z5', 'Z8', 'A9']
# tiroides: ['Z99']
# durante: ['Z5', 'T1.1']
# otro: ['Z8', 'A6.1-m', 'N5++']
# escáner: ['Z99']
# de: ['Z5']
# rutina: ['A6.2+', 'X4.2', 'K4']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 18: Tras pruebas y biopsias con aguja, resultó que ahora tengo cáncer de tiroides.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Tras: ['Z5', 'M6', 'M1']
# pruebas: ['P1', 'X2.4', 'B3']
# y: ['Z5', 'A1.8+']
# biopsias: ['Z99']
# con: ['Z5', 'A4.1']
# aguja: ['Z99']
# ,: ['PUNCT']
# resultó: ['A8', 'A2.1+', 'O4.2+']
# que: ['Z5', 'Z8']
# ahora: ['T1.1.2', 'Z4', 'Z5']
# tengo: ['A9']
# cáncer: ['B2-']
# de: ['Z5']
# tiroides: ['Z99']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 19: Pensé: “meh, este es fácil”.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Pensé: ['X2.1']
# :: ['PUNCT']
# “: ['Z99']
# meh: ['Z99']
# ,: ['PUNCT']
# este: ['W3']
# es: ['Z5', 'A3+']
# fácil: ['A12+', 'S8+', 'A7+']
# ”: ['PUNCT']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 20: Ayer me extirparon toda la tiroides en una operación.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Ayer: ['Z5', 'T1.1']
# me: ['Z5', 'Z8']
# extirparon: ['Z99']
# toda: ['Z5', 'S2', 'A4', 'A9']
# la: ['Z5']
# tiroides: ['Z99']
# en: ['Z5', 'N3']
# una: ['Z5', 'Z8', 'N1']
# operación: ['N2', 'B3', 'I2.2', 'G3', 'A1.1.1', 'X2.4']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 21: El tumor ya medía 2 cm.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# El: ['Z5']
# tumor: ['Z99']
# ya: ['Z5', 'T1.1.2', 'T2', 'A2.1+']
# medía: ['N3.1']
# 2: ['N1']
# cm: ['Z99']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 22: Ahora estamos 3-0.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Ahora: ['T1.1.2', 'Z4', 'Z5']
# estamos: ['A3+']
# 3-0: ['N1']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 23: No sé qué me espera, pero sea lo que sea, lo enfrentaré y lo combatiré.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# No: ['S8-', 'Z4', 'Z6', 'Z5']
# sé: ['Z5', 'A3+', 'X2.2', 'X2.3']
# qué: ['Z5', 'Z8']
# me: ['Z5', 'Z8']
# espera: ['T1.3', 'A3+', 'A11.1+', 'S1.1.1']
# ,: ['PUNCT']
# pero: ['Z5', 'A2.2-', 'A6.1-']
# sea: ['A3+']
# lo: ['Z5', 'Z8']
# que: ['Z5', 'Z8']
# sea: ['A3+']
# ,: ['PUNCT']
# lo: ['Z5', 'Z8']
# enfrentaré: ['Z99']
# y: ['Z5', 'A1.8+']
# lo: ['Z5', 'Z8']
# combatiré: ['Z99']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 24: Mientras tanto, recibiré quimioterapia preventiva cada 6 meses y seguiré disfrutando de criar a mis hijos.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Mientras: ['Z5', 'T1']
# tanto: ['N5+++/T1.3']
# ,: ['PUNCT']
# recibiré: ['Z99']
# quimioterapia: ['Z99']
# preventiva: ['Z99']
# cada: ['N5']
# 6: ['N1']
# meses: ['T1.1']
# y: ['Z5', 'A1.8+']
# seguiré: ['A1.1.1', 'A3', 'M1', 'Y2']
# disfrutando: ['E2+', 'A9+', 'E4.1+']
# de: ['Z5']
# criar: ['S1.1', 'P1', 'X1']
# a: ['Z5']
# mis: ['Z5', 'A8', 'A9+']
# hijos: ['S2.1/S2.2', 'S3.1', 'S5', 'A9']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 25: Así que, camarada, considera lo tuyo como un reto también.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Así: ['Z5', 'A8', 'N3']
# que: ['Z5', 'Z8']
# ,: ['PUNCT']
# camarada: ['Z99']
# ,: ['PUNCT']
# considera: ['X2']
# lo: ['Z5', 'Z8']
# tuyo: ['A9', 'N5', 'Z8']
# como: ['Z5']
# un: ['Z5', 'N1']
# reto: ['Z99']
# también: ['N5++', 'Z5']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 26: Tienes la fuerza y el optimismo para enfrentarlo, no importa lo dura que sea la vida.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Tienes: ['Z99']
# la: ['Z5']
# fuerza: ['S1.2.5+', 'N5+', 'A5.1+', 'X5.2+', 'S7.1+', 'X9.1+', 'O4.1', 'S1.2.3+']
# y: ['Z5', 'A1.8+']
# el: ['Z5']
# optimismo: ['X2.6+/A5.1+']
# para: ['Z5']
# enfrentarlo: ['Z99']
# ,: ['PUNCT']
# no: ['S8-', 'Z4', 'Z6', 'Z5']
# importa: ['Z99']
# lo: ['Z5', 'Z8']
# dura: ['A13', 'O4']
# que: ['Z5', 'Z8']
# sea: ['A3+']
# la: ['Z5']
# vida: ['L1+', 'A3+', 'T1.3', 'S1.1.1', 'A1.1.1', 'X5.2+', 'Q4.1', 'A11.1+++', 'A5.4+/C1']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 27: Mantén la cabeza en alto y sigue anotando.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Mantén: ['Z99']
# la: ['Z5']
# cabeza: ['B1', 'G1', 'G3']
# en: ['Z5', 'N3']
# alto: ['S2.1', 'N3.7+']
# y: ['Z5', 'A1.8+']
# sigue: ['A3', 'M1']
# anotando: ['Z99']
# .: ['PUNCT']

# %%
# Output tags text 1
text1_tags
# Out:
# {0: {'Hola': ['Z99'],
#   'camaradas': ['Z99'],
#   ',': ['PUNCT'],
#   'solo': ['A14', 'S5-', 'N5---', 'S5-', 'S3.2-'],
#   'quería': ['X7+', 'A2', 'S7', 'X2'],
#   'compartir': ['S1.1.2+'],
#   'mi': ['Z5', 'Z8', 'A9'],
#   'historia': ['T1.1', 'X2', 'G1', 'P1', 'T3+'],
#   'después': ['N4', 'Z5', 'T1.1'],
#   'de': ['Z5'],
#   'una': ['Z5', 'Z8', 'N1'],
#   'operación': ['N2', 'B3', 'I2.2', 'G3', 'A1.1.1', 'X2.4'],
#   'en': ['Z5', 'N3'],
#   'la': ['Z5'],
#   'que': ['Z5', 'Z8'],
#   'marqué': ['Z99'],
#   'otro': ['Z8', 'A6.1-m', 'N5++'],
#   'gol': ['Z99'],
#   'contra': ['Z5', 'A1.8', 'S3'],
#   'el': ['Z5'],
#   'cáncer': ['B2-'],
#   'y': ['Z5', 'A1.8+'],
#   'lo': ['Z5', 'Z8'],
#   'puse': ['M2', 'A9', 'A1.1.1'],
#   '3-0': ['N1'],
#   '.': ['PUNCT'],
#   'Espero': ['T1.3', 'X2.6+', 'A3+', 'E4.1+', 'X9.2+'],
#   'pueda': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'inspirar': ['Z99'],
#   'a': ['Z5'],
#   'alguien': ['Z5', 'S2m'],
#   'por': ['Z5', 'A2.2', 'M1', 'M6'],
#   'ahí': ['M7', 'M6', 'T1.2', 'Z5'],
#   'Fui': ['M1'],
#   'diagnosticado': ['Z99'],
#   'con': ['Z5', 'A4.1'],
#   'colon': ['Z99'],
#   'mayo': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'cuando': ['Z5', 'T1.1'],
#   'tuve': ['A9'],
#   'hemorragia': ['Z99'],
#   'importante': ['A5', 'A11.1+', 'A13.2'],
#   'Antes': ['N4', 'Z5', 'N3', 'T1.1'],
#   'darme': ['Z99'],
#   'cuenta': ['I1.1/N2/Y2', 'N5', 'N5.1+', 'I1.3.1', 'O2'],
#   'los': ['Z5'],
#   'cirujanos': ['B3/S2mf'],
#   'me': ['Z5', 'Z8'],
#   'extirparon': ['Z99'],
#   '30': ['N1'],
#   'cm': ['Z99'],
#   'La': ['Z5'],
#   'recuperación': ['Z99'],
#   'fue': ['A3+', 'L1', 'Z5'],
#   'dura': ['A13', 'O4'],
#   'pero': ['Z5', 'A2.2-', 'A6.1-'],
#   'manejable': ['Z99'],
#   'Lo': ['Z8m'],
#   'bueno': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+', 'E1', 'E2+'],
#   'es': ['Z5', 'A3+'],
#   'aunque': ['Z5', 'A13'],
#   'tumor': ['Z99'],
#   'era': ['Z5', 'A3+'],
#   'grande': ['N3.1+/A6.1+/A13.2+', 'A5'],
#   'ganglios': ['Z99'],
#   'linfáticos': ['Z99'],
#   'estaban': ['A3+'],
#   'limpios': ['B4', 'O4.2+', 'G2.2+'],
#   'colocándome': ['Z99'],
#   'estadio': ['K5.1/H1'],
#   '2': ['N1'],
#   'Según': ['Z5', 'A9', 'S1.1'],
#   'médicos': ['B2'],
#   'estaba': ['A3+'],
#   'libre': ['A10',
#    'S7.2',
#    'S9',
#    'A5.1+',
#    'X2.1',
#    'A1.7-',
#    'A5.2+',
#    'A12+',
#    'X5.2+'],
#   'uno': ['Z5', 'N1', 'T3', 'T1.2', 'Z8'],
#   'afortunados': ['A1.4+'],
#   'podía': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'dejar': ['S7.4', 'A3'],
#   'atrás': ['Z5', 'N3'],
#   'contar': ['N2', 'Q2.2', 'Q2.1', 'A10+', 'A11.1+'],
#   'un': ['Z5', 'N1'],
#   'bar': ['Z99'],
#   'El': ['Z5'],
#   'marcador': ['Z99'],
#   '1-0': ['N1'],
#   'para': ['Z5'],
#   'mí': ['Z8mf'],
#   'Sin': ['Z5', 'A13.7', 'A10-'],
#   'embargo': ['I1', 'G2.1'],
#   'más': ['A13.3', 'N6++', 'Z5'],
#   'tarde': ['T4-', 'L1-', 'T1.1'],
#   'aprendí': ['X2.3+', 'P1'],
#   'las': ['Z5'],
#   'malas': ['Z99'],
#   'esta': ['Z5', 'A3', 'S2.2'],
#   'mierda': ['Z99'],
#   'también': ['N5++', 'Z5'],
#   'puede': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1<'],
#   'viajar': ['M1', 'M5', 'M7', 'S3.1'],
#   'sangre': ['B2', 'O4.3'],
#   'En': ['Z5', 'N3'],
#   'enero': ['T1.3', 'O4.6-'],
#   '2021': ['N1'],
#   'escáner': ['Z99'],
#   'rutina': ['A6.2+', 'X4.2', 'K4'],
#   'mostró': ['A10+', 'S1.1.1'],
#   'noticias': ['Q1', 'Q4'],
#   'desagradables': ['O4.2-'],
#   'Tenía': ['A9'],
#   'varias': ['Z5', 'A3', 'A6.3+'],
#   'lesiones': ['Z99'],
#   'hígado': ['B1', 'F1', 'S2mf'],
#   'mundo': ['W1', 'S5+c', 'A4.1', 'N5+', 'G2'],
#   'colapsó': ['Z99'],
#   'cirujano': ['B3/S2mf'],
#   'dijo': ['Q1'],
#   'inoperable': ['Z99'],
#   'Ahora': ['T1.1.2', 'Z4', 'Z5'],
#   '4': ['N1'],
#   'metástasis': ['Z99'],
#   'hepática': ['Z99'],
#   'dos': ['Z5', 'N1', 'T3', 'T1.2'],
#   'niños': ['S2mf', 'P1', 'A4.1', 'B1', 'E1+', 'E3'],
#   'pequeños': ['A5', 'A13.7'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'años': ['T1', 'N1', 'T1.3', 'P1c'],
#   'no': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'sin': ['Z5', 'A13.7', 'A10-'],
#   'padre': ['S4/B1', 'S4m', 'S9/S2.2m', 'S2.1', 'S7', 'P1', 'S5'],
#   'Esto': ['W3'],
#   'durante': ['Z5', 'T1.1'],
#   'días': ['T1.1'],
#   'confinamiento': ['Z99'],
#   'coronavirus': ['Z99'],
#   'familia': ['S3', 'S1.1.3'],
#   'e': ['Z5'],
#   'hijos': ['S2.1/S2.2', 'S3.1', 'S5', 'A9'],
#   'podían': ['S7'],
#   'acompañarme': ['Z99'],
#   'todo': ['Z5', 'Z8', 'S2', 'A4', 'A9'],
#   'tiempo': ['T1/W4', 'K5.1', 'T1.2', 'T1.3', 'T1.1.2'],
#   'hospital': ['B3/H1c', 'B3', 'S1.2.4'],
#   'restricciones': ['A1.7+'],
#   'soy': ['A3+', 'L1', 'Z5'],
#   'rendirme': ['Z99'],
#   'asumí': ['Z99'],
#   'como': ['Z5'],
#   'nuevo': ['T3-', 'T1.1', 'A5'],
#   'reto': ['Z99'],
#   'debía': ['S6', 'A7+'],
#   'superar': ['Z99'],
#   'Con': ['Z5', 'A4.1'],
#   'pocas': ['Z5', 'Z8', 'A6.1-'],
#   'probabilidades': ['A7', 'N1'],
#   'al': ['Z5'],
#   'inicio': ['Z99'],
#   '1,5': ['N1'],
#   'quimioterapia': ['Z99'],
#   'radioterapia': ['Z99'],
#   'patearon': ['Z99'],
#   'trasero': ['Z99'],
#   'necesité': ['S6+'],
#   'ni': ['Z6', 'A1.8-'],
#   'siquiera': ['Z5', 'A1.9'],
#   'iba': ['M1',
#    'M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   '2-0': ['N1'],
#   'cruzábamos': ['Z99'],
#   'dedos': ['B1'],
#   'volviera': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'nunca': ['Z5', 'Z6', 'T2-'],
#   'No': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'volvió': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'completamente': ['A13.2'],
#   'distinto': ['A6.1-', 'A11.2+'],
#   'sería': ['A3+', 'L1', 'Z5'],
#   'Los': ['Z5'],
#   'sospecharon': ['Z99'],
#   'algo': ['Z5', 'Z8'],
#   'tiroides': ['Z99'],
#   'Tras': ['Z5', 'M6', 'M1'],
#   'pruebas': ['P1', 'X2.4', 'B3'],
#   'biopsias': ['Z99'],
#   'aguja': ['Z99'],
#   'resultó': ['A8', 'A2.1+', 'O4.2+'],
#   'ahora': ['T1.1.2', 'Z4', 'Z5'],
#   'tengo': ['A9'],
#   'Pensé': ['X2.1'],
#   ':': ['PUNCT'],
#   '“': ['Z99'],
#   'meh': ['Z99'],
#   'este': ['W3'],
#   'fácil': ['A12+', 'S8+', 'A7+'],
#   '”': ['PUNCT'],
#   'Ayer': ['Z5', 'T1.1'],
#   'toda': ['Z5', 'S2', 'A4', 'A9'],
#   'ya': ['Z5', 'T1.1.2', 'T2', 'A2.1+'],
#   'medía': ['N3.1'],
#   'estamos': ['A3+'],
#   'sé': ['Z5', 'A3+', 'X2.2', 'X2.3'],
#   'qué': ['Z5', 'Z8'],
#   'espera': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1'],
#   'sea': ['A3+'],
#   'enfrentaré': ['Z99'],
#   'combatiré': ['Z99'],
#   'Mientras': ['Z5', 'T1'],
#   'tanto': ['N5+++/T1.3'],
#   'recibiré': ['Z99'],
#   'preventiva': ['Z99'],
#   'cada': ['N5'],
#   '6': ['N1'],
#   'meses': ['T1.1'],
#   'seguiré': ['A1.1.1', 'A3', 'M1', 'Y2'],
#   'disfrutando': ['E2+', 'A9+', 'E4.1+'],
#   'criar': ['S1.1', 'P1', 'X1'],
#   'mis': ['Z5', 'A8', 'A9+'],
#   'Así': ['Z5', 'A8', 'N3'],
#   'camarada': ['Z99'],
#   'considera': ['X2'],
#   'tuyo': ['A9', 'N5', 'Z8'],
#   'Tienes': ['Z99'],
#   'fuerza': ['S1.2.5+',
#    'N5+',
#    'A5.1+',
#    'X5.2+',
#    'S7.1+',
#    'X9.1+',
#    'O4.1',
#    'S1.2.3+'],
#   'optimismo': ['X2.6+/A5.1+'],
#   'enfrentarlo': ['Z99'],
#   'importa': ['Z99'],
#   'vida': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'Mantén': ['Z99'],
#   'cabeza': ['B1', 'G1', 'G3'],
#   'alto': ['S2.1', 'N3.7+'],
#   'sigue': ['A3', 'M1'],
#   'anotando': ['Z99']},
#  1: {'Hola': ['Z99'],
#   'camaradas': ['Z99'],
#   ',': ['PUNCT'],
#   'solo': ['A14', 'S5-', 'N5---', 'S5-', 'S3.2-'],
#   'quería': ['X7+', 'A2', 'S7', 'X2'],
#   'compartir': ['S1.1.2+'],
#   'mi': ['Z5', 'Z8', 'A9'],
#   'historia': ['T1.1', 'X2', 'G1', 'P1', 'T3+'],
#   'después': ['N4', 'Z5', 'T1.1'],
#   'de': ['Z5'],
#   'una': ['Z5', 'Z8', 'N1'],
#   'operación': ['N2', 'B3', 'I2.2', 'G3', 'A1.1.1', 'X2.4'],
#   'en': ['Z5', 'N3'],
#   'la': ['Z5'],
#   'que': ['Z5', 'Z8'],
#   'marqué': ['Z99'],
#   'otro': ['Z8', 'A6.1-m', 'N5++'],
#   'gol': ['Z99'],
#   'contra': ['Z5', 'A1.8', 'S3'],
#   'el': ['Z5'],
#   'cáncer': ['B2-'],
#   'y': ['Z5', 'A1.8+'],
#   'lo': ['Z5', 'Z8'],
#   'puse': ['M2', 'A9', 'A1.1.1'],
#   '3-0': ['N1'],
#   '.': ['PUNCT'],
#   'Espero': ['T1.3', 'X2.6+', 'A3+', 'E4.1+', 'X9.2+'],
#   'pueda': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'inspirar': ['Z99'],
#   'a': ['Z5'],
#   'alguien': ['Z5', 'S2m'],
#   'por': ['Z5', 'A2.2', 'M1', 'M6'],
#   'ahí': ['M7', 'M6', 'T1.2', 'Z5'],
#   'Fui': ['M1'],
#   'diagnosticado': ['Z99'],
#   'con': ['Z5', 'A4.1'],
#   'colon': ['Z99'],
#   'mayo': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'cuando': ['Z5', 'T1.1'],
#   'tuve': ['A9'],
#   'hemorragia': ['Z99'],
#   'importante': ['A5', 'A11.1+', 'A13.2'],
#   'Antes': ['N4', 'Z5', 'N3', 'T1.1'],
#   'darme': ['Z99'],
#   'cuenta': ['I1.1/N2/Y2', 'N5', 'N5.1+', 'I1.3.1', 'O2'],
#   'los': ['Z5'],
#   'cirujanos': ['B3/S2mf'],
#   'me': ['Z5', 'Z8'],
#   'extirparon': ['Z99'],
#   '30': ['N1'],
#   'cm': ['Z99'],
#   'La': ['Z5'],
#   'recuperación': ['Z99'],
#   'fue': ['A3+', 'L1', 'Z5'],
#   'dura': ['A13', 'O4'],
#   'pero': ['Z5', 'A2.2-', 'A6.1-'],
#   'manejable': ['Z99'],
#   'Lo': ['Z8m'],
#   'bueno': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+', 'E1', 'E2+'],
#   'es': ['Z5', 'A3+'],
#   'aunque': ['Z5', 'A13'],
#   'tumor': ['Z99'],
#   'era': ['Z5', 'A3+'],
#   'grande': ['N3.1+/A6.1+/A13.2+', 'A5'],
#   'ganglios': ['Z99'],
#   'linfáticos': ['Z99'],
#   'estaban': ['A3+'],
#   'limpios': ['B4', 'O4.2+', 'G2.2+'],
#   'colocándome': ['Z99'],
#   'estadio': ['K5.1/H1'],
#   '2': ['N1'],
#   'Según': ['Z5', 'A9', 'S1.1'],
#   'médicos': ['B2'],
#   'estaba': ['A3+'],
#   'libre': ['A10',
#    'S7.2',
#    'S9',
#    'A5.1+',
#    'X2.1',
#    'A1.7-',
#    'A5.2+',
#    'A12+',
#    'X5.2+'],
#   'uno': ['Z5', 'N1', 'T3', 'T1.2', 'Z8'],
#   'afortunados': ['A1.4+'],
#   'podía': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'dejar': ['S7.4', 'A3'],
#   'atrás': ['Z5', 'N3'],
#   'contar': ['N2', 'Q2.2', 'Q2.1', 'A10+', 'A11.1+'],
#   'un': ['Z5', 'N1'],
#   'bar': ['Z99'],
#   'El': ['Z5'],
#   'marcador': ['Z99'],
#   '1-0': ['N1'],
#   'para': ['Z5'],
#   'mí': ['Z8mf'],
#   'Sin': ['Z5', 'A13.7', 'A10-'],
#   'embargo': ['I1', 'G2.1'],
#   'más': ['A13.3', 'N6++', 'Z5'],
#   'tarde': ['T4-', 'L1-', 'T1.1'],
#   'aprendí': ['X2.3+', 'P1'],
#   'las': ['Z5'],
#   'malas': ['Z99'],
#   'esta': ['Z5', 'A3', 'S2.2'],
#   'mierda': ['Z99'],
#   'también': ['N5++', 'Z5'],
#   'puede': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1<'],
#   'viajar': ['M1', 'M5', 'M7', 'S3.1'],
#   'sangre': ['B2', 'O4.3'],
#   'En': ['Z5', 'N3'],
#   'enero': ['T1.3', 'O4.6-'],
#   '2021': ['N1'],
#   'escáner': ['Z99'],
#   'rutina': ['A6.2+', 'X4.2', 'K4'],
#   'mostró': ['A10+', 'S1.1.1'],
#   'noticias': ['Q1', 'Q4'],
#   'desagradables': ['O4.2-'],
#   'Tenía': ['A9'],
#   'varias': ['Z5', 'A3', 'A6.3+'],
#   'lesiones': ['Z99'],
#   'hígado': ['B1', 'F1', 'S2mf'],
#   'mundo': ['W1', 'S5+c', 'A4.1', 'N5+', 'G2'],
#   'colapsó': ['Z99'],
#   'cirujano': ['B3/S2mf'],
#   'dijo': ['Q1'],
#   'inoperable': ['Z99'],
#   'Ahora': ['T1.1.2', 'Z4', 'Z5'],
#   '4': ['N1'],
#   'metástasis': ['Z99'],
#   'hepática': ['Z99'],
#   'dos': ['Z5', 'N1', 'T3', 'T1.2'],
#   'niños': ['S2mf', 'P1', 'A4.1', 'B1', 'E1+', 'E3'],
#   'pequeños': ['A5', 'A13.7'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'años': ['T1', 'N1', 'T1.3', 'P1c'],
#   'no': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'sin': ['Z5', 'A13.7', 'A10-'],
#   'padre': ['S4/B1', 'S4m', 'S9/S2.2m', 'S2.1', 'S7', 'P1', 'S5'],
#   'Esto': ['W3'],
#   'durante': ['Z5', 'T1.1'],
#   'días': ['T1.1'],
#   'confinamiento': ['Z99'],
#   'coronavirus': ['Z99'],
#   'familia': ['S3', 'S1.1.3'],
#   'e': ['Z5'],
#   'hijos': ['S2.1/S2.2', 'S3.1', 'S5', 'A9'],
#   'podían': ['S7'],
#   'acompañarme': ['Z99'],
#   'todo': ['Z5', 'Z8', 'S2', 'A4', 'A9'],
#   'tiempo': ['T1/W4', 'K5.1', 'T1.2', 'T1.3', 'T1.1.2'],
#   'hospital': ['B3/H1c', 'B3', 'S1.2.4'],
#   'restricciones': ['A1.7+'],
#   'soy': ['A3+', 'L1', 'Z5'],
#   'rendirme': ['Z99'],
#   'asumí': ['Z99'],
#   'como': ['Z5'],
#   'nuevo': ['T3-', 'T1.1', 'A5'],
#   'reto': ['Z99'],
#   'debía': ['S6', 'A7+'],
#   'superar': ['Z99'],
#   'Con': ['Z5', 'A4.1'],
#   'pocas': ['Z5', 'Z8', 'A6.1-'],
#   'probabilidades': ['A7', 'N1'],
#   'al': ['Z5'],
#   'inicio': ['Z99'],
#   '1,5': ['N1'],
#   'quimioterapia': ['Z99'],
#   'radioterapia': ['Z99'],
#   'patearon': ['Z99'],
#   'trasero': ['Z99'],
#   'necesité': ['S6+'],
#   'ni': ['Z6', 'A1.8-'],
#   'siquiera': ['Z5', 'A1.9'],
#   'iba': ['M1',
#    'M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   '2-0': ['N1'],
#   'cruzábamos': ['Z99'],
#   'dedos': ['B1'],
#   'volviera': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'nunca': ['Z5', 'Z6', 'T2-'],
#   'No': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'volvió': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'completamente': ['A13.2'],
#   'distinto': ['A6.1-', 'A11.2+'],
#   'sería': ['A3+', 'L1', 'Z5'],
#   'Los': ['Z5'],
#   'sospecharon': ['Z99'],
#   'algo': ['Z5', 'Z8'],
#   'tiroides': ['Z99'],
#   'Tras': ['Z5', 'M6', 'M1'],
#   'pruebas': ['P1', 'X2.4', 'B3'],
#   'biopsias': ['Z99'],
#   'aguja': ['Z99'],
#   'resultó': ['A8', 'A2.1+', 'O4.2+'],
#   'ahora': ['T1.1.2', 'Z4', 'Z5'],
#   'tengo': ['A9'],
#   'Pensé': ['X2.1'],
#   ':': ['PUNCT'],
#   '“': ['Z99'],
#   'meh': ['Z99'],
#   'este': ['W3'],
#   'fácil': ['A12+', 'S8+', 'A7+'],
#   '”': ['PUNCT'],
#   'Ayer': ['Z5', 'T1.1'],
#   'toda': ['Z5', 'S2', 'A4', 'A9'],
#   'ya': ['Z5', 'T1.1.2', 'T2', 'A2.1+'],
#   'medía': ['N3.1'],
#   'estamos': ['A3+'],
#   'sé': ['Z5', 'A3+', 'X2.2', 'X2.3'],
#   'qué': ['Z5', 'Z8'],
#   'espera': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1'],
#   'sea': ['A3+'],
#   'enfrentaré': ['Z99'],
#   'combatiré': ['Z99'],
#   'Mientras': ['Z5', 'T1'],
#   'tanto': ['N5+++/T1.3'],
#   'recibiré': ['Z99'],
#   'preventiva': ['Z99'],
#   'cada': ['N5'],
#   '6': ['N1'],
#   'meses': ['T1.1'],
#   'seguiré': ['A1.1.1', 'A3', 'M1', 'Y2'],
#   'disfrutando': ['E2+', 'A9+', 'E4.1+'],
#   'criar': ['S1.1', 'P1', 'X1'],
#   'mis': ['Z5', 'A8', 'A9+'],
#   'Así': ['Z5', 'A8', 'N3'],
#   'camarada': ['Z99'],
#   'considera': ['X2'],
#   'tuyo': ['A9', 'N5', 'Z8'],
#   'Tienes': ['Z99'],
#   'fuerza': ['S1.2.5+',
#    'N5+',
#    'A5.1+',
#    'X5.2+',
#    'S7.1+',
#    'X9.1+',
#    'O4.1',
#    'S1.2.3+'],
#   'optimismo': ['X2.6+/A5.1+'],
#   'enfrentarlo': ['Z99'],
#   'importa': ['Z99'],
#   'vida': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'Mantén': ['Z99'],
#   'cabeza': ['B1', 'G1', 'G3'],
#   'alto': ['S2.1', 'N3.7+'],
#   'sigue': ['A3', 'M1'],
#   'anotando': ['Z99']},
#  2: {'Hola': ['Z99'],
#   'camaradas': ['Z99'],
#   ',': ['PUNCT'],
#   'solo': ['A14', 'S5-', 'N5---', 'S5-', 'S3.2-'],
#   'quería': ['X7+', 'A2', 'S7', 'X2'],
#   'compartir': ['S1.1.2+'],
#   'mi': ['Z5', 'Z8', 'A9'],
#   'historia': ['T1.1', 'X2', 'G1', 'P1', 'T3+'],
#   'después': ['N4', 'Z5', 'T1.1'],
#   'de': ['Z5'],
#   'una': ['Z5', 'Z8', 'N1'],
#   'operación': ['N2', 'B3', 'I2.2', 'G3', 'A1.1.1', 'X2.4'],
#   'en': ['Z5', 'N3'],
#   'la': ['Z5'],
#   'que': ['Z5', 'Z8'],
#   'marqué': ['Z99'],
#   'otro': ['Z8', 'A6.1-m', 'N5++'],
#   'gol': ['Z99'],
#   'contra': ['Z5', 'A1.8', 'S3'],
#   'el': ['Z5'],
#   'cáncer': ['B2-'],
#   'y': ['Z5', 'A1.8+'],
#   'lo': ['Z5', 'Z8'],
#   'puse': ['M2', 'A9', 'A1.1.1'],
#   '3-0': ['N1'],
#   '.': ['PUNCT'],
#   'Espero': ['T1.3', 'X2.6+', 'A3+', 'E4.1+', 'X9.2+'],
#   'pueda': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'inspirar': ['Z99'],
#   'a': ['Z5'],
#   'alguien': ['Z5', 'S2m'],
#   'por': ['Z5', 'A2.2', 'M1', 'M6'],
#   'ahí': ['M7', 'M6', 'T1.2', 'Z5'],
#   'Fui': ['M1'],
#   'diagnosticado': ['Z99'],
#   'con': ['Z5', 'A4.1'],
#   'colon': ['Z99'],
#   'mayo': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'cuando': ['Z5', 'T1.1'],
#   'tuve': ['A9'],
#   'hemorragia': ['Z99'],
#   'importante': ['A5', 'A11.1+', 'A13.2'],
#   'Antes': ['N4', 'Z5', 'N3', 'T1.1'],
#   'darme': ['Z99'],
#   'cuenta': ['I1.1/N2/Y2', 'N5', 'N5.1+', 'I1.3.1', 'O2'],
#   'los': ['Z5'],
#   'cirujanos': ['B3/S2mf'],
#   'me': ['Z5', 'Z8'],
#   'extirparon': ['Z99'],
#   '30': ['N1'],
#   'cm': ['Z99'],
#   'La': ['Z5'],
#   'recuperación': ['Z99'],
#   'fue': ['A3+', 'L1', 'Z5'],
#   'dura': ['A13', 'O4'],
#   'pero': ['Z5', 'A2.2-', 'A6.1-'],
#   'manejable': ['Z99'],
#   'Lo': ['Z8m'],
#   'bueno': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+', 'E1', 'E2+'],
#   'es': ['Z5', 'A3+'],
#   'aunque': ['Z5', 'A13'],
#   'tumor': ['Z99'],
#   'era': ['Z5', 'A3+'],
#   'grande': ['N3.1+/A6.1+/A13.2+', 'A5'],
#   'ganglios': ['Z99'],
#   'linfáticos': ['Z99'],
#   'estaban': ['A3+'],
#   'limpios': ['B4', 'O4.2+', 'G2.2+'],
#   'colocándome': ['Z99'],
#   'estadio': ['K5.1/H1'],
#   '2': ['N1'],
#   'Según': ['Z5', 'A9', 'S1.1'],
#   'médicos': ['B2'],
#   'estaba': ['A3+'],
#   'libre': ['A10',
#    'S7.2',
#    'S9',
#    'A5.1+',
#    'X2.1',
#    'A1.7-',
#    'A5.2+',
#    'A12+',
#    'X5.2+'],
#   'uno': ['Z5', 'N1', 'T3', 'T1.2', 'Z8'],
#   'afortunados': ['A1.4+'],
#   'podía': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'dejar': ['S7.4', 'A3'],
#   'atrás': ['Z5', 'N3'],
#   'contar': ['N2', 'Q2.2', 'Q2.1', 'A10+', 'A11.1+'],
#   'un': ['Z5', 'N1'],
#   'bar': ['Z99'],
#   'El': ['Z5'],
#   'marcador': ['Z99'],
#   '1-0': ['N1'],
#   'para': ['Z5'],
#   'mí': ['Z8mf'],
#   'Sin': ['Z5', 'A13.7', 'A10-'],
#   'embargo': ['I1', 'G2.1'],
#   'más': ['A13.3', 'N6++', 'Z5'],
#   'tarde': ['T4-', 'L1-', 'T1.1'],
#   'aprendí': ['X2.3+', 'P1'],
#   'las': ['Z5'],
#   'malas': ['Z99'],
#   'esta': ['Z5', 'A3', 'S2.2'],
#   'mierda': ['Z99'],
#   'también': ['N5++', 'Z5'],
#   'puede': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1<'],
#   'viajar': ['M1', 'M5', 'M7', 'S3.1'],
#   'sangre': ['B2', 'O4.3'],
#   'En': ['Z5', 'N3'],
#   'enero': ['T1.3', 'O4.6-'],
#   '2021': ['N1'],
#   'escáner': ['Z99'],
#   'rutina': ['A6.2+', 'X4.2', 'K4'],
#   'mostró': ['A10+', 'S1.1.1'],
#   'noticias': ['Q1', 'Q4'],
#   'desagradables': ['O4.2-'],
#   'Tenía': ['A9'],
#   'varias': ['Z5', 'A3', 'A6.3+'],
#   'lesiones': ['Z99'],
#   'hígado': ['B1', 'F1', 'S2mf'],
#   'mundo': ['W1', 'S5+c', 'A4.1', 'N5+', 'G2'],
#   'colapsó': ['Z99'],
#   'cirujano': ['B3/S2mf'],
#   'dijo': ['Q1'],
#   'inoperable': ['Z99'],
#   'Ahora': ['T1.1.2', 'Z4', 'Z5'],
#   '4': ['N1'],
#   'metástasis': ['Z99'],
#   'hepática': ['Z99'],
#   'dos': ['Z5', 'N1', 'T3', 'T1.2'],
#   'niños': ['S2mf', 'P1', 'A4.1', 'B1', 'E1+', 'E3'],
#   'pequeños': ['A5', 'A13.7'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'años': ['T1', 'N1', 'T1.3', 'P1c'],
#   'no': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'sin': ['Z5', 'A13.7', 'A10-'],
#   'padre': ['S4/B1', 'S4m', 'S9/S2.2m', 'S2.1', 'S7', 'P1', 'S5'],
#   'Esto': ['W3'],
#   'durante': ['Z5', 'T1.1'],
#   'días': ['T1.1'],
#   'confinamiento': ['Z99'],
#   'coronavirus': ['Z99'],
#   'familia': ['S3', 'S1.1.3'],
#   'e': ['Z5'],
#   'hijos': ['S2.1/S2.2', 'S3.1', 'S5', 'A9'],
#   'podían': ['S7'],
#   'acompañarme': ['Z99'],
#   'todo': ['Z5', 'Z8', 'S2', 'A4', 'A9'],
#   'tiempo': ['T1/W4', 'K5.1', 'T1.2', 'T1.3', 'T1.1.2'],
#   'hospital': ['B3/H1c', 'B3', 'S1.2.4'],
#   'restricciones': ['A1.7+'],
#   'soy': ['A3+', 'L1', 'Z5'],
#   'rendirme': ['Z99'],
#   'asumí': ['Z99'],
#   'como': ['Z5'],
#   'nuevo': ['T3-', 'T1.1', 'A5'],
#   'reto': ['Z99'],
#   'debía': ['S6', 'A7+'],
#   'superar': ['Z99'],
#   'Con': ['Z5', 'A4.1'],
#   'pocas': ['Z5', 'Z8', 'A6.1-'],
#   'probabilidades': ['A7', 'N1'],
#   'al': ['Z5'],
#   'inicio': ['Z99'],
#   '1,5': ['N1'],
#   'quimioterapia': ['Z99'],
#   'radioterapia': ['Z99'],
#   'patearon': ['Z99'],
#   'trasero': ['Z99'],
#   'necesité': ['S6+'],
#   'ni': ['Z6', 'A1.8-'],
#   'siquiera': ['Z5', 'A1.9'],
#   'iba': ['M1',
#    'M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   '2-0': ['N1'],
#   'cruzábamos': ['Z99'],
#   'dedos': ['B1'],
#   'volviera': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'nunca': ['Z5', 'Z6', 'T2-'],
#   'No': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'volvió': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'completamente': ['A13.2'],
#   'distinto': ['A6.1-', 'A11.2+'],
#   'sería': ['A3+', 'L1', 'Z5'],
#   'Los': ['Z5'],
#   'sospecharon': ['Z99'],
#   'algo': ['Z5', 'Z8'],
#   'tiroides': ['Z99'],
#   'Tras': ['Z5', 'M6', 'M1'],
#   'pruebas': ['P1', 'X2.4', 'B3'],
#   'biopsias': ['Z99'],
#   'aguja': ['Z99'],
#   'resultó': ['A8', 'A2.1+', 'O4.2+'],
#   'ahora': ['T1.1.2', 'Z4', 'Z5'],
#   'tengo': ['A9'],
#   'Pensé': ['X2.1'],
#   ':': ['PUNCT'],
#   '“': ['Z99'],
#   'meh': ['Z99'],
#   'este': ['W3'],
#   'fácil': ['A12+', 'S8+', 'A7+'],
#   '”': ['PUNCT'],
#   'Ayer': ['Z5', 'T1.1'],
#   'toda': ['Z5', 'S2', 'A4', 'A9'],
#   'ya': ['Z5', 'T1.1.2', 'T2', 'A2.1+'],
#   'medía': ['N3.1'],
#   'estamos': ['A3+'],
#   'sé': ['Z5', 'A3+', 'X2.2', 'X2.3'],
#   'qué': ['Z5', 'Z8'],
#   'espera': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1'],
#   'sea': ['A3+'],
#   'enfrentaré': ['Z99'],
#   'combatiré': ['Z99'],
#   'Mientras': ['Z5', 'T1'],
#   'tanto': ['N5+++/T1.3'],
#   'recibiré': ['Z99'],
#   'preventiva': ['Z99'],
#   'cada': ['N5'],
#   '6': ['N1'],
#   'meses': ['T1.1'],
#   'seguiré': ['A1.1.1', 'A3', 'M1', 'Y2'],
#   'disfrutando': ['E2+', 'A9+', 'E4.1+'],
#   'criar': ['S1.1', 'P1', 'X1'],
#   'mis': ['Z5', 'A8', 'A9+'],
#   'Así': ['Z5', 'A8', 'N3'],
#   'camarada': ['Z99'],
#   'considera': ['X2'],
#   'tuyo': ['A9', 'N5', 'Z8'],
#   'Tienes': ['Z99'],
#   'fuerza': ['S1.2.5+',
#    'N5+',
#    'A5.1+',
#    'X5.2+',
#    'S7.1+',
#    'X9.1+',
#    'O4.1',
#    'S1.2.3+'],
#   'optimismo': ['X2.6+/A5.1+'],
#   'enfrentarlo': ['Z99'],
#   'importa': ['Z99'],
#   'vida': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'Mantén': ['Z99'],
#   'cabeza': ['B1', 'G1', 'G3'],
#   'alto': ['S2.1', 'N3.7+'],
#   'sigue': ['A3', 'M1'],
#   'anotando': ['Z99']},
#  3: {'Hola': ['Z99'],
#   'camaradas': ['Z99'],
#   ',': ['PUNCT'],
#   'solo': ['A14', 'S5-', 'N5---', 'S5-', 'S3.2-'],
#   'quería': ['X7+', 'A2', 'S7', 'X2'],
#   'compartir': ['S1.1.2+'],
#   'mi': ['Z5', 'Z8', 'A9'],
#   'historia': ['T1.1', 'X2', 'G1', 'P1', 'T3+'],
#   'después': ['N4', 'Z5', 'T1.1'],
#   'de': ['Z5'],
#   'una': ['Z5', 'Z8', 'N1'],
#   'operación': ['N2', 'B3', 'I2.2', 'G3', 'A1.1.1', 'X2.4'],
#   'en': ['Z5', 'N3'],
#   'la': ['Z5'],
#   'que': ['Z5', 'Z8'],
#   'marqué': ['Z99'],
#   'otro': ['Z8', 'A6.1-m', 'N5++'],
#   'gol': ['Z99'],
#   'contra': ['Z5', 'A1.8', 'S3'],
#   'el': ['Z5'],
#   'cáncer': ['B2-'],
#   'y': ['Z5', 'A1.8+'],
#   'lo': ['Z5', 'Z8'],
#   'puse': ['M2', 'A9', 'A1.1.1'],
#   '3-0': ['N1'],
#   '.': ['PUNCT'],
#   'Espero': ['T1.3', 'X2.6+', 'A3+', 'E4.1+', 'X9.2+'],
#   'pueda': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'inspirar': ['Z99'],
#   'a': ['Z5'],
#   'alguien': ['Z5', 'S2m'],
#   'por': ['Z5', 'A2.2', 'M1', 'M6'],
#   'ahí': ['M7', 'M6', 'T1.2', 'Z5'],
#   'Fui': ['M1'],
#   'diagnosticado': ['Z99'],
#   'con': ['Z5', 'A4.1'],
#   'colon': ['Z99'],
#   'mayo': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'cuando': ['Z5', 'T1.1'],
#   'tuve': ['A9'],
#   'hemorragia': ['Z99'],
#   'importante': ['A5', 'A11.1+', 'A13.2'],
#   'Antes': ['N4', 'Z5', 'N3', 'T1.1'],
#   'darme': ['Z99'],
#   'cuenta': ['I1.1/N2/Y2', 'N5', 'N5.1+', 'I1.3.1', 'O2'],
#   'los': ['Z5'],
#   'cirujanos': ['B3/S2mf'],
#   'me': ['Z5', 'Z8'],
#   'extirparon': ['Z99'],
#   '30': ['N1'],
#   'cm': ['Z99'],
#   'La': ['Z5'],
#   'recuperación': ['Z99'],
#   'fue': ['A3+', 'L1', 'Z5'],
#   'dura': ['A13', 'O4'],
#   'pero': ['Z5', 'A2.2-', 'A6.1-'],
#   'manejable': ['Z99'],
#   'Lo': ['Z8m'],
#   'bueno': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+', 'E1', 'E2+'],
#   'es': ['Z5', 'A3+'],
#   'aunque': ['Z5', 'A13'],
#   'tumor': ['Z99'],
#   'era': ['Z5', 'A3+'],
#   'grande': ['N3.1+/A6.1+/A13.2+', 'A5'],
#   'ganglios': ['Z99'],
#   'linfáticos': ['Z99'],
#   'estaban': ['A3+'],
#   'limpios': ['B4', 'O4.2+', 'G2.2+'],
#   'colocándome': ['Z99'],
#   'estadio': ['K5.1/H1'],
#   '2': ['N1'],
#   'Según': ['Z5', 'A9', 'S1.1'],
#   'médicos': ['B2'],
#   'estaba': ['A3+'],
#   'libre': ['A10',
#    'S7.2',
#    'S9',
#    'A5.1+',
#    'X2.1',
#    'A1.7-',
#    'A5.2+',
#    'A12+',
#    'X5.2+'],
#   'uno': ['Z5', 'N1', 'T3', 'T1.2', 'Z8'],
#   'afortunados': ['A1.4+'],
#   'podía': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'dejar': ['S7.4', 'A3'],
#   'atrás': ['Z5', 'N3'],
#   'contar': ['N2', 'Q2.2', 'Q2.1', 'A10+', 'A11.1+'],
#   'un': ['Z5', 'N1'],
#   'bar': ['Z99'],
#   'El': ['Z5'],
#   'marcador': ['Z99'],
#   '1-0': ['N1'],
#   'para': ['Z5'],
#   'mí': ['Z8mf'],
#   'Sin': ['Z5', 'A13.7', 'A10-'],
#   'embargo': ['I1', 'G2.1'],
#   'más': ['A13.3', 'N6++', 'Z5'],
#   'tarde': ['T4-', 'L1-', 'T1.1'],
#   'aprendí': ['X2.3+', 'P1'],
#   'las': ['Z5'],
#   'malas': ['Z99'],
#   'esta': ['Z5', 'A3', 'S2.2'],
#   'mierda': ['Z99'],
#   'también': ['N5++', 'Z5'],
#   'puede': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1<'],
#   'viajar': ['M1', 'M5', 'M7', 'S3.1'],
#   'sangre': ['B2', 'O4.3'],
#   'En': ['Z5', 'N3'],
#   'enero': ['T1.3', 'O4.6-'],
#   '2021': ['N1'],
#   'escáner': ['Z99'],
#   'rutina': ['A6.2+', 'X4.2', 'K4'],
#   'mostró': ['A10+', 'S1.1.1'],
#   'noticias': ['Q1', 'Q4'],
#   'desagradables': ['O4.2-'],
#   'Tenía': ['A9'],
#   'varias': ['Z5', 'A3', 'A6.3+'],
#   'lesiones': ['Z99'],
#   'hígado': ['B1', 'F1', 'S2mf'],
#   'mundo': ['W1', 'S5+c', 'A4.1', 'N5+', 'G2'],
#   'colapsó': ['Z99'],
#   'cirujano': ['B3/S2mf'],
#   'dijo': ['Q1'],
#   'inoperable': ['Z99'],
#   'Ahora': ['T1.1.2', 'Z4', 'Z5'],
#   '4': ['N1'],
#   'metástasis': ['Z99'],
#   'hepática': ['Z99'],
#   'dos': ['Z5', 'N1', 'T3', 'T1.2'],
#   'niños': ['S2mf', 'P1', 'A4.1', 'B1', 'E1+', 'E3'],
#   'pequeños': ['A5', 'A13.7'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'años': ['T1', 'N1', 'T1.3', 'P1c'],
#   'no': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'sin': ['Z5', 'A13.7', 'A10-'],
#   'padre': ['S4/B1', 'S4m', 'S9/S2.2m', 'S2.1', 'S7', 'P1', 'S5'],
#   'Esto': ['W3'],
#   'durante': ['Z5', 'T1.1'],
#   'días': ['T1.1'],
#   'confinamiento': ['Z99'],
#   'coronavirus': ['Z99'],
#   'familia': ['S3', 'S1.1.3'],
#   'e': ['Z5'],
#   'hijos': ['S2.1/S2.2', 'S3.1', 'S5', 'A9'],
#   'podían': ['S7'],
#   'acompañarme': ['Z99'],
#   'todo': ['Z5', 'Z8', 'S2', 'A4', 'A9'],
#   'tiempo': ['T1/W4', 'K5.1', 'T1.2', 'T1.3', 'T1.1.2'],
#   'hospital': ['B3/H1c', 'B3', 'S1.2.4'],
#   'restricciones': ['A1.7+'],
#   'soy': ['A3+', 'L1', 'Z5'],
#   'rendirme': ['Z99'],
#   'asumí': ['Z99'],
#   'como': ['Z5'],
#   'nuevo': ['T3-', 'T1.1', 'A5'],
#   'reto': ['Z99'],
#   'debía': ['S6', 'A7+'],
#   'superar': ['Z99'],
#   'Con': ['Z5', 'A4.1'],
#   'pocas': ['Z5', 'Z8', 'A6.1-'],
#   'probabilidades': ['A7', 'N1'],
#   'al': ['Z5'],
#   'inicio': ['Z99'],
#   '1,5': ['N1'],
#   'quimioterapia': ['Z99'],
#   'radioterapia': ['Z99'],
#   'patearon': ['Z99'],
#   'trasero': ['Z99'],
#   'necesité': ['S6+'],
#   'ni': ['Z6', 'A1.8-'],
#   'siquiera': ['Z5', 'A1.9'],
#   'iba': ['M1',
#    'M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   '2-0': ['N1'],
#   'cruzábamos': ['Z99'],
#   'dedos': ['B1'],
#   'volviera': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'nunca': ['Z5', 'Z6', 'T2-'],
#   'No': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'volvió': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'completamente': ['A13.2'],
#   'distinto': ['A6.1-', 'A11.2+'],
#   'sería': ['A3+', 'L1', 'Z5'],
#   'Los': ['Z5'],
#   'sospecharon': ['Z99'],
#   'algo': ['Z5', 'Z8'],
#   'tiroides': ['Z99'],
#   'Tras': ['Z5', 'M6', 'M1'],
#   'pruebas': ['P1', 'X2.4', 'B3'],
#   'biopsias': ['Z99'],
#   'aguja': ['Z99'],
#   'resultó': ['A8', 'A2.1+', 'O4.2+'],
#   'ahora': ['T1.1.2', 'Z4', 'Z5'],
#   'tengo': ['A9'],
#   'Pensé': ['X2.1'],
#   ':': ['PUNCT'],
#   '“': ['Z99'],
#   'meh': ['Z99'],
#   'este': ['W3'],
#   'fácil': ['A12+', 'S8+', 'A7+'],
#   '”': ['PUNCT'],
#   'Ayer': ['Z5', 'T1.1'],
#   'toda': ['Z5', 'S2', 'A4', 'A9'],
#   'ya': ['Z5', 'T1.1.2', 'T2', 'A2.1+'],
#   'medía': ['N3.1'],
#   'estamos': ['A3+'],
#   'sé': ['Z5', 'A3+', 'X2.2', 'X2.3'],
#   'qué': ['Z5', 'Z8'],
#   'espera': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1'],
#   'sea': ['A3+'],
#   'enfrentaré': ['Z99'],
#   'combatiré': ['Z99'],
#   'Mientras': ['Z5', 'T1'],
#   'tanto': ['N5+++/T1.3'],
#   'recibiré': ['Z99'],
#   'preventiva': ['Z99'],
#   'cada': ['N5'],
#   '6': ['N1'],
#   'meses': ['T1.1'],
#   'seguiré': ['A1.1.1', 'A3', 'M1', 'Y2'],
#   'disfrutando': ['E2+', 'A9+', 'E4.1+'],
#   'criar': ['S1.1', 'P1', 'X1'],
#   'mis': ['Z5', 'A8', 'A9+'],
#   'Así': ['Z5', 'A8', 'N3'],
#   'camarada': ['Z99'],
#   'considera': ['X2'],
#   'tuyo': ['A9', 'N5', 'Z8'],
#   'Tienes': ['Z99'],
#   'fuerza': ['S1.2.5+',
#    'N5+',
#    'A5.1+',
#    'X5.2+',
#    'S7.1+',
#    'X9.1+',
#    'O4.1',
#    'S1.2.3+'],
#   'optimismo': ['X2.6+/A5.1+'],
#   'enfrentarlo': ['Z99'],
#   'importa': ['Z99'],
#   'vida': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'Mantén': ['Z99'],
#   'cabeza': ['B1', 'G1', 'G3'],
#   'alto': ['S2.1', 'N3.7+'],
#   'sigue': ['A3', 'M1'],
#   'anotando': ['Z99']},
#  4: {'Hola': ['Z99'],
#   'camaradas': ['Z99'],
#   ',': ['PUNCT'],
#   'solo': ['A14', 'S5-', 'N5---', 'S5-', 'S3.2-'],
#   'quería': ['X7+', 'A2', 'S7', 'X2'],
#   'compartir': ['S1.1.2+'],
#   'mi': ['Z5', 'Z8', 'A9'],
#   'historia': ['T1.1', 'X2', 'G1', 'P1', 'T3+'],
#   'después': ['N4', 'Z5', 'T1.1'],
#   'de': ['Z5'],
#   'una': ['Z5', 'Z8', 'N1'],
#   'operación': ['N2', 'B3', 'I2.2', 'G3', 'A1.1.1', 'X2.4'],
#   'en': ['Z5', 'N3'],
#   'la': ['Z5'],
#   'que': ['Z5', 'Z8'],
#   'marqué': ['Z99'],
#   'otro': ['Z8', 'A6.1-m', 'N5++'],
#   'gol': ['Z99'],
#   'contra': ['Z5', 'A1.8', 'S3'],
#   'el': ['Z5'],
#   'cáncer': ['B2-'],
#   'y': ['Z5', 'A1.8+'],
#   'lo': ['Z5', 'Z8'],
#   'puse': ['M2', 'A9', 'A1.1.1'],
#   '3-0': ['N1'],
#   '.': ['PUNCT'],
#   'Espero': ['T1.3', 'X2.6+', 'A3+', 'E4.1+', 'X9.2+'],
#   'pueda': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'inspirar': ['Z99'],
#   'a': ['Z5'],
#   'alguien': ['Z5', 'S2m'],
#   'por': ['Z5', 'A2.2', 'M1', 'M6'],
#   'ahí': ['M7', 'M6', 'T1.2', 'Z5'],
#   'Fui': ['M1'],
#   'diagnosticado': ['Z99'],
#   'con': ['Z5', 'A4.1'],
#   'colon': ['Z99'],
#   'mayo': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'cuando': ['Z5', 'T1.1'],
#   'tuve': ['A9'],
#   'hemorragia': ['Z99'],
#   'importante': ['A5', 'A11.1+', 'A13.2'],
#   'Antes': ['N4', 'Z5', 'N3', 'T1.1'],
#   'darme': ['Z99'],
#   'cuenta': ['I1.1/N2/Y2', 'N5', 'N5.1+', 'I1.3.1', 'O2'],
#   'los': ['Z5'],
#   'cirujanos': ['B3/S2mf'],
#   'me': ['Z5', 'Z8'],
#   'extirparon': ['Z99'],
#   '30': ['N1'],
#   'cm': ['Z99'],
#   'La': ['Z5'],
#   'recuperación': ['Z99'],
#   'fue': ['A3+', 'L1', 'Z5'],
#   'dura': ['A13', 'O4'],
#   'pero': ['Z5', 'A2.2-', 'A6.1-'],
#   'manejable': ['Z99'],
#   'Lo': ['Z8m'],
#   'bueno': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+', 'E1', 'E2+'],
#   'es': ['Z5', 'A3+'],
#   'aunque': ['Z5', 'A13'],
#   'tumor': ['Z99'],
#   'era': ['Z5', 'A3+'],
#   'grande': ['N3.1+/A6.1+/A13.2+', 'A5'],
#   'ganglios': ['Z99'],
#   'linfáticos': ['Z99'],
#   'estaban': ['A3+'],
#   'limpios': ['B4', 'O4.2+', 'G2.2+'],
#   'colocándome': ['Z99'],
#   'estadio': ['K5.1/H1'],
#   '2': ['N1'],
#   'Según': ['Z5', 'A9', 'S1.1'],
#   'médicos': ['B2'],
#   'estaba': ['A3+'],
#   'libre': ['A10',
#    'S7.2',
#    'S9',
#    'A5.1+',
#    'X2.1',
#    'A1.7-',
#    'A5.2+',
#    'A12+',
#    'X5.2+'],
#   'uno': ['Z5', 'N1', 'T3', 'T1.2', 'Z8'],
#   'afortunados': ['A1.4+'],
#   'podía': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'dejar': ['S7.4', 'A3'],
#   'atrás': ['Z5', 'N3'],
#   'contar': ['N2', 'Q2.2', 'Q2.1', 'A10+', 'A11.1+'],
#   'un': ['Z5', 'N1'],
#   'bar': ['Z99'],
#   'El': ['Z5'],
#   'marcador': ['Z99'],
#   '1-0': ['N1'],
#   'para': ['Z5'],
#   'mí': ['Z8mf'],
#   'Sin': ['Z5', 'A13.7', 'A10-'],
#   'embargo': ['I1', 'G2.1'],
#   'más': ['A13.3', 'N6++', 'Z5'],
#   'tarde': ['T4-', 'L1-', 'T1.1'],
#   'aprendí': ['X2.3+', 'P1'],
#   'las': ['Z5'],
#   'malas': ['Z99'],
#   'esta': ['Z5', 'A3', 'S2.2'],
#   'mierda': ['Z99'],
#   'también': ['N5++', 'Z5'],
#   'puede': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1<'],
#   'viajar': ['M1', 'M5', 'M7', 'S3.1'],
#   'sangre': ['B2', 'O4.3'],
#   'En': ['Z5', 'N3'],
#   'enero': ['T1.3', 'O4.6-'],
#   '2021': ['N1'],
#   'escáner': ['Z99'],
#   'rutina': ['A6.2+', 'X4.2', 'K4'],
#   'mostró': ['A10+', 'S1.1.1'],
#   'noticias': ['Q1', 'Q4'],
#   'desagradables': ['O4.2-'],
#   'Tenía': ['A9'],
#   'varias': ['Z5', 'A3', 'A6.3+'],
#   'lesiones': ['Z99'],
#   'hígado': ['B1', 'F1', 'S2mf'],
#   'mundo': ['W1', 'S5+c', 'A4.1', 'N5+', 'G2'],
#   'colapsó': ['Z99'],
#   'cirujano': ['B3/S2mf'],
#   'dijo': ['Q1'],
#   'inoperable': ['Z99'],
#   'Ahora': ['T1.1.2', 'Z4', 'Z5'],
#   '4': ['N1'],
#   'metástasis': ['Z99'],
#   'hepática': ['Z99'],
#   'dos': ['Z5', 'N1', 'T3', 'T1.2'],
#   'niños': ['S2mf', 'P1', 'A4.1', 'B1', 'E1+', 'E3'],
#   'pequeños': ['A5', 'A13.7'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'años': ['T1', 'N1', 'T1.3', 'P1c'],
#   'no': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'sin': ['Z5', 'A13.7', 'A10-'],
#   'padre': ['S4/B1', 'S4m', 'S9/S2.2m', 'S2.1', 'S7', 'P1', 'S5'],
#   'Esto': ['W3'],
#   'durante': ['Z5', 'T1.1'],
#   'días': ['T1.1'],
#   'confinamiento': ['Z99'],
#   'coronavirus': ['Z99'],
#   'familia': ['S3', 'S1.1.3'],
#   'e': ['Z5'],
#   'hijos': ['S2.1/S2.2', 'S3.1', 'S5', 'A9'],
#   'podían': ['S7'],
#   'acompañarme': ['Z99'],
#   'todo': ['Z5', 'Z8', 'S2', 'A4', 'A9'],
#   'tiempo': ['T1/W4', 'K5.1', 'T1.2', 'T1.3', 'T1.1.2'],
#   'hospital': ['B3/H1c', 'B3', 'S1.2.4'],
#   'restricciones': ['A1.7+'],
#   'soy': ['A3+', 'L1', 'Z5'],
#   'rendirme': ['Z99'],
#   'asumí': ['Z99'],
#   'como': ['Z5'],
#   'nuevo': ['T3-', 'T1.1', 'A5'],
#   'reto': ['Z99'],
#   'debía': ['S6', 'A7+'],
#   'superar': ['Z99'],
#   'Con': ['Z5', 'A4.1'],
#   'pocas': ['Z5', 'Z8', 'A6.1-'],
#   'probabilidades': ['A7', 'N1'],
#   'al': ['Z5'],
#   'inicio': ['Z99'],
#   '1,5': ['N1'],
#   'quimioterapia': ['Z99'],
#   'radioterapia': ['Z99'],
#   'patearon': ['Z99'],
#   'trasero': ['Z99'],
#   'necesité': ['S6+'],
#   'ni': ['Z6', 'A1.8-'],
#   'siquiera': ['Z5', 'A1.9'],
#   'iba': ['M1',
#    'M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   '2-0': ['N1'],
#   'cruzábamos': ['Z99'],
#   'dedos': ['B1'],
#   'volviera': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'nunca': ['Z5', 'Z6', 'T2-'],
#   'No': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'volvió': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'completamente': ['A13.2'],
#   'distinto': ['A6.1-', 'A11.2+'],
#   'sería': ['A3+', 'L1', 'Z5'],
#   'Los': ['Z5'],
#   'sospecharon': ['Z99'],
#   'algo': ['Z5', 'Z8'],
#   'tiroides': ['Z99'],
#   'Tras': ['Z5', 'M6', 'M1'],
#   'pruebas': ['P1', 'X2.4', 'B3'],
#   'biopsias': ['Z99'],
#   'aguja': ['Z99'],
#   'resultó': ['A8', 'A2.1+', 'O4.2+'],
#   'ahora': ['T1.1.2', 'Z4', 'Z5'],
#   'tengo': ['A9'],
#   'Pensé': ['X2.1'],
#   ':': ['PUNCT'],
#   '“': ['Z99'],
#   'meh': ['Z99'],
#   'este': ['W3'],
#   'fácil': ['A12+', 'S8+', 'A7+'],
#   '”': ['PUNCT'],
#   'Ayer': ['Z5', 'T1.1'],
#   'toda': ['Z5', 'S2', 'A4', 'A9'],
#   'ya': ['Z5', 'T1.1.2', 'T2', 'A2.1+'],
#   'medía': ['N3.1'],
#   'estamos': ['A3+'],
#   'sé': ['Z5', 'A3+', 'X2.2', 'X2.3'],
#   'qué': ['Z5', 'Z8'],
#   'espera': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1'],
#   'sea': ['A3+'],
#   'enfrentaré': ['Z99'],
#   'combatiré': ['Z99'],
#   'Mientras': ['Z5', 'T1'],
#   'tanto': ['N5+++/T1.3'],
#   'recibiré': ['Z99'],
#   'preventiva': ['Z99'],
#   'cada': ['N5'],
#   '6': ['N1'],
#   'meses': ['T1.1'],
#   'seguiré': ['A1.1.1', 'A3', 'M1', 'Y2'],
#   'disfrutando': ['E2+', 'A9+', 'E4.1+'],
#   'criar': ['S1.1', 'P1', 'X1'],
#   'mis': ['Z5', 'A8', 'A9+'],
#   'Así': ['Z5', 'A8', 'N3'],
#   'camarada': ['Z99'],
#   'considera': ['X2'],
#   'tuyo': ['A9', 'N5', 'Z8'],
#   'Tienes': ['Z99'],
#   'fuerza': ['S1.2.5+',
#    'N5+',
#    'A5.1+',
#    'X5.2+',
#    'S7.1+',
#    'X9.1+',
#    'O4.1',
#    'S1.2.3+'],
#   'optimismo': ['X2.6+/A5.1+'],
#   'enfrentarlo': ['Z99'],
#   'importa': ['Z99'],
#   'vida': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'Mantén': ['Z99'],
#   'cabeza': ['B1', 'G1', 'G3'],
#   'alto': ['S2.1', 'N3.7+'],
#   'sigue': ['A3', 'M1'],
#   'anotando': ['Z99']},
#  5: {'Hola': ['Z99'],
#   'camaradas': ['Z99'],
#   ',': ['PUNCT'],
#   'solo': ['A14', 'S5-', 'N5---', 'S5-', 'S3.2-'],
#   'quería': ['X7+', 'A2', 'S7', 'X2'],
#   'compartir': ['S1.1.2+'],
#   'mi': ['Z5', 'Z8', 'A9'],
#   'historia': ['T1.1', 'X2', 'G1', 'P1', 'T3+'],
#   'después': ['N4', 'Z5', 'T1.1'],
#   'de': ['Z5'],
#   'una': ['Z5', 'Z8', 'N1'],
#   'operación': ['N2', 'B3', 'I2.2', 'G3', 'A1.1.1', 'X2.4'],
#   'en': ['Z5', 'N3'],
#   'la': ['Z5'],
#   'que': ['Z5', 'Z8'],
#   'marqué': ['Z99'],
#   'otro': ['Z8', 'A6.1-m', 'N5++'],
#   'gol': ['Z99'],
#   'contra': ['Z5', 'A1.8', 'S3'],
#   'el': ['Z5'],
#   'cáncer': ['B2-'],
#   'y': ['Z5', 'A1.8+'],
#   'lo': ['Z5', 'Z8'],
#   'puse': ['M2', 'A9', 'A1.1.1'],
#   '3-0': ['N1'],
#   '.': ['PUNCT'],
#   'Espero': ['T1.3', 'X2.6+', 'A3+', 'E4.1+', 'X9.2+'],
#   'pueda': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'inspirar': ['Z99'],
#   'a': ['Z5'],
#   'alguien': ['Z5', 'S2m'],
#   'por': ['Z5', 'A2.2', 'M1', 'M6'],
#   'ahí': ['M7', 'M6', 'T1.2', 'Z5'],
#   'Fui': ['M1'],
#   'diagnosticado': ['Z99'],
#   'con': ['Z5', 'A4.1'],
#   'colon': ['Z99'],
#   'mayo': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'cuando': ['Z5', 'T1.1'],
#   'tuve': ['A9'],
#   'hemorragia': ['Z99'],
#   'importante': ['A5', 'A11.1+', 'A13.2'],
#   'Antes': ['N4', 'Z5', 'N3', 'T1.1'],
#   'darme': ['Z99'],
#   'cuenta': ['I1.1/N2/Y2', 'N5', 'N5.1+', 'I1.3.1', 'O2'],
#   'los': ['Z5'],
#   'cirujanos': ['B3/S2mf'],
#   'me': ['Z5', 'Z8'],
#   'extirparon': ['Z99'],
#   '30': ['N1'],
#   'cm': ['Z99'],
#   'La': ['Z5'],
#   'recuperación': ['Z99'],
#   'fue': ['A3+', 'L1', 'Z5'],
#   'dura': ['A13', 'O4'],
#   'pero': ['Z5', 'A2.2-', 'A6.1-'],
#   'manejable': ['Z99'],
#   'Lo': ['Z8m'],
#   'bueno': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+', 'E1', 'E2+'],
#   'es': ['Z5', 'A3+'],
#   'aunque': ['Z5', 'A13'],
#   'tumor': ['Z99'],
#   'era': ['Z5', 'A3+'],
#   'grande': ['N3.1+/A6.1+/A13.2+', 'A5'],
#   'ganglios': ['Z99'],
#   'linfáticos': ['Z99'],
#   'estaban': ['A3+'],
#   'limpios': ['B4', 'O4.2+', 'G2.2+'],
#   'colocándome': ['Z99'],
#   'estadio': ['K5.1/H1'],
#   '2': ['N1'],
#   'Según': ['Z5', 'A9', 'S1.1'],
#   'médicos': ['B2'],
#   'estaba': ['A3+'],
#   'libre': ['A10',
#    'S7.2',
#    'S9',
#    'A5.1+',
#    'X2.1',
#    'A1.7-',
#    'A5.2+',
#    'A12+',
#    'X5.2+'],
#   'uno': ['Z5', 'N1', 'T3', 'T1.2', 'Z8'],
#   'afortunados': ['A1.4+'],
#   'podía': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'dejar': ['S7.4', 'A3'],
#   'atrás': ['Z5', 'N3'],
#   'contar': ['N2', 'Q2.2', 'Q2.1', 'A10+', 'A11.1+'],
#   'un': ['Z5', 'N1'],
#   'bar': ['Z99'],
#   'El': ['Z5'],
#   'marcador': ['Z99'],
#   '1-0': ['N1'],
#   'para': ['Z5'],
#   'mí': ['Z8mf'],
#   'Sin': ['Z5', 'A13.7', 'A10-'],
#   'embargo': ['I1', 'G2.1'],
#   'más': ['A13.3', 'N6++', 'Z5'],
#   'tarde': ['T4-', 'L1-', 'T1.1'],
#   'aprendí': ['X2.3+', 'P1'],
#   'las': ['Z5'],
#   'malas': ['Z99'],
#   'esta': ['Z5', 'A3', 'S2.2'],
#   'mierda': ['Z99'],
#   'también': ['N5++', 'Z5'],
#   'puede': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1<'],
#   'viajar': ['M1', 'M5', 'M7', 'S3.1'],
#   'sangre': ['B2', 'O4.3'],
#   'En': ['Z5', 'N3'],
#   'enero': ['T1.3', 'O4.6-'],
#   '2021': ['N1'],
#   'escáner': ['Z99'],
#   'rutina': ['A6.2+', 'X4.2', 'K4'],
#   'mostró': ['A10+', 'S1.1.1'],
#   'noticias': ['Q1', 'Q4'],
#   'desagradables': ['O4.2-'],
#   'Tenía': ['A9'],
#   'varias': ['Z5', 'A3', 'A6.3+'],
#   'lesiones': ['Z99'],
#   'hígado': ['B1', 'F1', 'S2mf'],
#   'mundo': ['W1', 'S5+c', 'A4.1', 'N5+', 'G2'],
#   'colapsó': ['Z99'],
#   'cirujano': ['B3/S2mf'],
#   'dijo': ['Q1'],
#   'inoperable': ['Z99'],
#   'Ahora': ['T1.1.2', 'Z4', 'Z5'],
#   '4': ['N1'],
#   'metástasis': ['Z99'],
#   'hepática': ['Z99'],
#   'dos': ['Z5', 'N1', 'T3', 'T1.2'],
#   'niños': ['S2mf', 'P1', 'A4.1', 'B1', 'E1+', 'E3'],
#   'pequeños': ['A5', 'A13.7'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'años': ['T1', 'N1', 'T1.3', 'P1c'],
#   'no': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'sin': ['Z5', 'A13.7', 'A10-'],
#   'padre': ['S4/B1', 'S4m', 'S9/S2.2m', 'S2.1', 'S7', 'P1', 'S5'],
#   'Esto': ['W3'],
#   'durante': ['Z5', 'T1.1'],
#   'días': ['T1.1'],
#   'confinamiento': ['Z99'],
#   'coronavirus': ['Z99'],
#   'familia': ['S3', 'S1.1.3'],
#   'e': ['Z5'],
#   'hijos': ['S2.1/S2.2', 'S3.1', 'S5', 'A9'],
#   'podían': ['S7'],
#   'acompañarme': ['Z99'],
#   'todo': ['Z5', 'Z8', 'S2', 'A4', 'A9'],
#   'tiempo': ['T1/W4', 'K5.1', 'T1.2', 'T1.3', 'T1.1.2'],
#   'hospital': ['B3/H1c', 'B3', 'S1.2.4'],
#   'restricciones': ['A1.7+'],
#   'soy': ['A3+', 'L1', 'Z5'],
#   'rendirme': ['Z99'],
#   'asumí': ['Z99'],
#   'como': ['Z5'],
#   'nuevo': ['T3-', 'T1.1', 'A5'],
#   'reto': ['Z99'],
#   'debía': ['S6', 'A7+'],
#   'superar': ['Z99'],
#   'Con': ['Z5', 'A4.1'],
#   'pocas': ['Z5', 'Z8', 'A6.1-'],
#   'probabilidades': ['A7', 'N1'],
#   'al': ['Z5'],
#   'inicio': ['Z99'],
#   '1,5': ['N1'],
#   'quimioterapia': ['Z99'],
#   'radioterapia': ['Z99'],
#   'patearon': ['Z99'],
#   'trasero': ['Z99'],
#   'necesité': ['S6+'],
#   'ni': ['Z6', 'A1.8-'],
#   'siquiera': ['Z5', 'A1.9'],
#   'iba': ['M1',
#    'M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   '2-0': ['N1'],
#   'cruzábamos': ['Z99'],
#   'dedos': ['B1'],
#   'volviera': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'nunca': ['Z5', 'Z6', 'T2-'],
#   'No': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'volvió': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'completamente': ['A13.2'],
#   'distinto': ['A6.1-', 'A11.2+'],
#   'sería': ['A3+', 'L1', 'Z5'],
#   'Los': ['Z5'],
#   'sospecharon': ['Z99'],
#   'algo': ['Z5', 'Z8'],
#   'tiroides': ['Z99'],
#   'Tras': ['Z5', 'M6', 'M1'],
#   'pruebas': ['P1', 'X2.4', 'B3'],
#   'biopsias': ['Z99'],
#   'aguja': ['Z99'],
#   'resultó': ['A8', 'A2.1+', 'O4.2+'],
#   'ahora': ['T1.1.2', 'Z4', 'Z5'],
#   'tengo': ['A9'],
#   'Pensé': ['X2.1'],
#   ':': ['PUNCT'],
#   '“': ['Z99'],
#   'meh': ['Z99'],
#   'este': ['W3'],
#   'fácil': ['A12+', 'S8+', 'A7+'],
#   '”': ['PUNCT'],
#   'Ayer': ['Z5', 'T1.1'],
#   'toda': ['Z5', 'S2', 'A4', 'A9'],
#   'ya': ['Z5', 'T1.1.2', 'T2', 'A2.1+'],
#   'medía': ['N3.1'],
#   'estamos': ['A3+'],
#   'sé': ['Z5', 'A3+', 'X2.2', 'X2.3'],
#   'qué': ['Z5', 'Z8'],
#   'espera': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1'],
#   'sea': ['A3+'],
#   'enfrentaré': ['Z99'],
#   'combatiré': ['Z99'],
#   'Mientras': ['Z5', 'T1'],
#   'tanto': ['N5+++/T1.3'],
#   'recibiré': ['Z99'],
#   'preventiva': ['Z99'],
#   'cada': ['N5'],
#   '6': ['N1'],
#   'meses': ['T1.1'],
#   'seguiré': ['A1.1.1', 'A3', 'M1', 'Y2'],
#   'disfrutando': ['E2+', 'A9+', 'E4.1+'],
#   'criar': ['S1.1', 'P1', 'X1'],
#   'mis': ['Z5', 'A8', 'A9+'],
#   'Así': ['Z5', 'A8', 'N3'],
#   'camarada': ['Z99'],
#   'considera': ['X2'],
#   'tuyo': ['A9', 'N5', 'Z8'],
#   'Tienes': ['Z99'],
#   'fuerza': ['S1.2.5+',
#    'N5+',
#    'A5.1+',
#    'X5.2+',
#    'S7.1+',
#    'X9.1+',
#    'O4.1',
#    'S1.2.3+'],
#   'optimismo': ['X2.6+/A5.1+'],
#   'enfrentarlo': ['Z99'],
#   'importa': ['Z99'],
#   'vida': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'Mantén': ['Z99'],
#   'cabeza': ['B1', 'G1', 'G3'],
#   'alto': ['S2.1', 'N3.7+'],
#   'sigue': ['A3', 'M1'],
#   'anotando': ['Z99']},
#  6: {'Hola': ['Z99'],
#   'camaradas': ['Z99'],
#   ',': ['PUNCT'],
#   'solo': ['A14', 'S5-', 'N5---', 'S5-', 'S3.2-'],
#   'quería': ['X7+', 'A2', 'S7', 'X2'],
#   'compartir': ['S1.1.2+'],
#   'mi': ['Z5', 'Z8', 'A9'],
#   'historia': ['T1.1', 'X2', 'G1', 'P1', 'T3+'],
#   'después': ['N4', 'Z5', 'T1.1'],
#   'de': ['Z5'],
#   'una': ['Z5', 'Z8', 'N1'],
#   'operación': ['N2', 'B3', 'I2.2', 'G3', 'A1.1.1', 'X2.4'],
#   'en': ['Z5', 'N3'],
#   'la': ['Z5'],
#   'que': ['Z5', 'Z8'],
#   'marqué': ['Z99'],
#   'otro': ['Z8', 'A6.1-m', 'N5++'],
#   'gol': ['Z99'],
#   'contra': ['Z5', 'A1.8', 'S3'],
#   'el': ['Z5'],
#   'cáncer': ['B2-'],
#   'y': ['Z5', 'A1.8+'],
#   'lo': ['Z5', 'Z8'],
#   'puse': ['M2', 'A9', 'A1.1.1'],
#   '3-0': ['N1'],
#   '.': ['PUNCT'],
#   'Espero': ['T1.3', 'X2.6+', 'A3+', 'E4.1+', 'X9.2+'],
#   'pueda': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'inspirar': ['Z99'],
#   'a': ['Z5'],
#   'alguien': ['Z5', 'S2m'],
#   'por': ['Z5', 'A2.2', 'M1', 'M6'],
#   'ahí': ['M7', 'M6', 'T1.2', 'Z5'],
#   'Fui': ['M1'],
#   'diagnosticado': ['Z99'],
#   'con': ['Z5', 'A4.1'],
#   'colon': ['Z99'],
#   'mayo': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'cuando': ['Z5', 'T1.1'],
#   'tuve': ['A9'],
#   'hemorragia': ['Z99'],
#   'importante': ['A5', 'A11.1+', 'A13.2'],
#   'Antes': ['N4', 'Z5', 'N3', 'T1.1'],
#   'darme': ['Z99'],
#   'cuenta': ['I1.1/N2/Y2', 'N5', 'N5.1+', 'I1.3.1', 'O2'],
#   'los': ['Z5'],
#   'cirujanos': ['B3/S2mf'],
#   'me': ['Z5', 'Z8'],
#   'extirparon': ['Z99'],
#   '30': ['N1'],
#   'cm': ['Z99'],
#   'La': ['Z5'],
#   'recuperación': ['Z99'],
#   'fue': ['A3+', 'L1', 'Z5'],
#   'dura': ['A13', 'O4'],
#   'pero': ['Z5', 'A2.2-', 'A6.1-'],
#   'manejable': ['Z99'],
#   'Lo': ['Z8m'],
#   'bueno': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+', 'E1', 'E2+'],
#   'es': ['Z5', 'A3+'],
#   'aunque': ['Z5', 'A13'],
#   'tumor': ['Z99'],
#   'era': ['Z5', 'A3+'],
#   'grande': ['N3.1+/A6.1+/A13.2+', 'A5'],
#   'ganglios': ['Z99'],
#   'linfáticos': ['Z99'],
#   'estaban': ['A3+'],
#   'limpios': ['B4', 'O4.2+', 'G2.2+'],
#   'colocándome': ['Z99'],
#   'estadio': ['K5.1/H1'],
#   '2': ['N1'],
#   'Según': ['Z5', 'A9', 'S1.1'],
#   'médicos': ['B2'],
#   'estaba': ['A3+'],
#   'libre': ['A10',
#    'S7.2',
#    'S9',
#    'A5.1+',
#    'X2.1',
#    'A1.7-',
#    'A5.2+',
#    'A12+',
#    'X5.2+'],
#   'uno': ['Z5', 'N1', 'T3', 'T1.2', 'Z8'],
#   'afortunados': ['A1.4+'],
#   'podía': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'dejar': ['S7.4', 'A3'],
#   'atrás': ['Z5', 'N3'],
#   'contar': ['N2', 'Q2.2', 'Q2.1', 'A10+', 'A11.1+'],
#   'un': ['Z5', 'N1'],
#   'bar': ['Z99'],
#   'El': ['Z5'],
#   'marcador': ['Z99'],
#   '1-0': ['N1'],
#   'para': ['Z5'],
#   'mí': ['Z8mf'],
#   'Sin': ['Z5', 'A13.7', 'A10-'],
#   'embargo': ['I1', 'G2.1'],
#   'más': ['A13.3', 'N6++', 'Z5'],
#   'tarde': ['T4-', 'L1-', 'T1.1'],
#   'aprendí': ['X2.3+', 'P1'],
#   'las': ['Z5'],
#   'malas': ['Z99'],
#   'esta': ['Z5', 'A3', 'S2.2'],
#   'mierda': ['Z99'],
#   'también': ['N5++', 'Z5'],
#   'puede': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1<'],
#   'viajar': ['M1', 'M5', 'M7', 'S3.1'],
#   'sangre': ['B2', 'O4.3'],
#   'En': ['Z5', 'N3'],
#   'enero': ['T1.3', 'O4.6-'],
#   '2021': ['N1'],
#   'escáner': ['Z99'],
#   'rutina': ['A6.2+', 'X4.2', 'K4'],
#   'mostró': ['A10+', 'S1.1.1'],
#   'noticias': ['Q1', 'Q4'],
#   'desagradables': ['O4.2-'],
#   'Tenía': ['A9'],
#   'varias': ['Z5', 'A3', 'A6.3+'],
#   'lesiones': ['Z99'],
#   'hígado': ['B1', 'F1', 'S2mf'],
#   'mundo': ['W1', 'S5+c', 'A4.1', 'N5+', 'G2'],
#   'colapsó': ['Z99'],
#   'cirujano': ['B3/S2mf'],
#   'dijo': ['Q1'],
#   'inoperable': ['Z99'],
#   'Ahora': ['T1.1.2', 'Z4', 'Z5'],
#   '4': ['N1'],
#   'metástasis': ['Z99'],
#   'hepática': ['Z99'],
#   'dos': ['Z5', 'N1', 'T3', 'T1.2'],
#   'niños': ['S2mf', 'P1', 'A4.1', 'B1', 'E1+', 'E3'],
#   'pequeños': ['A5', 'A13.7'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'años': ['T1', 'N1', 'T1.3', 'P1c'],
#   'no': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'sin': ['Z5', 'A13.7', 'A10-'],
#   'padre': ['S4/B1', 'S4m', 'S9/S2.2m', 'S2.1', 'S7', 'P1', 'S5'],
#   'Esto': ['W3'],
#   'durante': ['Z5', 'T1.1'],
#   'días': ['T1.1'],
#   'confinamiento': ['Z99'],
#   'coronavirus': ['Z99'],
#   'familia': ['S3', 'S1.1.3'],
#   'e': ['Z5'],
#   'hijos': ['S2.1/S2.2', 'S3.1', 'S5', 'A9'],
#   'podían': ['S7'],
#   'acompañarme': ['Z99'],
#   'todo': ['Z5', 'Z8', 'S2', 'A4', 'A9'],
#   'tiempo': ['T1/W4', 'K5.1', 'T1.2', 'T1.3', 'T1.1.2'],
#   'hospital': ['B3/H1c', 'B3', 'S1.2.4'],
#   'restricciones': ['A1.7+'],
#   'soy': ['A3+', 'L1', 'Z5'],
#   'rendirme': ['Z99'],
#   'asumí': ['Z99'],
#   'como': ['Z5'],
#   'nuevo': ['T3-', 'T1.1', 'A5'],
#   'reto': ['Z99'],
#   'debía': ['S6', 'A7+'],
#   'superar': ['Z99'],
#   'Con': ['Z5', 'A4.1'],
#   'pocas': ['Z5', 'Z8', 'A6.1-'],
#   'probabilidades': ['A7', 'N1'],
#   'al': ['Z5'],
#   'inicio': ['Z99'],
#   '1,5': ['N1'],
# ...
#   'Tras': ['Z5', 'M6', 'M1'],
#   'pruebas': ['P1', 'X2.4', 'B3'],
#   'biopsias': ['Z99'],
#   'aguja': ['Z99'],
#   'resultó': ['A8', 'A2.1+', 'O4.2+'],
#   'ahora': ['T1.1.2', 'Z4', 'Z5'],
#   'tengo': ['A9'],
#   'Pensé': ['X2.1'],
#   ':': ['PUNCT'],
#   '“': ['Z99'],
#   'meh': ['Z99'],
#   'este': ['W3'],
#   'fácil': ['A12+', 'S8+', 'A7+'],
#   '”': ['PUNCT'],
#   'Ayer': ['Z5', 'T1.1'],
#   'toda': ['Z5', 'S2', 'A4', 'A9'],
#   'ya': ['Z5', 'T1.1.2', 'T2', 'A2.1+'],
#   'medía': ['N3.1'],
#   'estamos': ['A3+'],
#   'sé': ['Z5', 'A3+', 'X2.2', 'X2.3'],
#   'qué': ['Z5', 'Z8'],
#   'espera': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1'],
#   'sea': ['A3+'],
#   'enfrentaré': ['Z99'],
#   'combatiré': ['Z99'],
#   'Mientras': ['Z5', 'T1'],
#   'tanto': ['N5+++/T1.3'],
#   'recibiré': ['Z99'],
#   'preventiva': ['Z99'],
#   'cada': ['N5'],
#   '6': ['N1'],
#   'meses': ['T1.1'],
#   'seguiré': ['A1.1.1', 'A3', 'M1', 'Y2'],
#   'disfrutando': ['E2+', 'A9+', 'E4.1+'],
#   'criar': ['S1.1', 'P1', 'X1'],
#   'mis': ['Z5', 'A8', 'A9+'],
#   'Así': ['Z5', 'A8', 'N3'],
#   'camarada': ['Z99'],
#   'considera': ['X2'],
#   'tuyo': ['A9', 'N5', 'Z8'],
#   'Tienes': ['Z99'],
#   'fuerza': ['S1.2.5+',
#    'N5+',
#    'A5.1+',
#    'X5.2+',
#    'S7.1+',
#    'X9.1+',
#    'O4.1',
#    'S1.2.3+'],
#   'optimismo': ['X2.6+/A5.1+'],
#   'enfrentarlo': ['Z99'],
#   'importa': ['Z99'],
#   'vida': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'Mantén': ['Z99'],
#   'cabeza': ['B1', 'G1', 'G3'],
#   'alto': ['S2.1', 'N3.7+'],
#   'sigue': ['A3', 'M1'],
#   'anotando': ['Z99']},
#  26: {'Hola': ['Z99'],
#   'camaradas': ['Z99'],
#   ',': ['PUNCT'],
#   'solo': ['A14', 'S5-', 'N5---', 'S5-', 'S3.2-'],
#   'quería': ['X7+', 'A2', 'S7', 'X2'],
#   'compartir': ['S1.1.2+'],
#   'mi': ['Z5', 'Z8', 'A9'],
#   'historia': ['T1.1', 'X2', 'G1', 'P1', 'T3+'],
#   'después': ['N4', 'Z5', 'T1.1'],
#   'de': ['Z5'],
#   'una': ['Z5', 'Z8', 'N1'],
#   'operación': ['N2', 'B3', 'I2.2', 'G3', 'A1.1.1', 'X2.4'],
#   'en': ['Z5', 'N3'],
#   'la': ['Z5'],
#   'que': ['Z5', 'Z8'],
#   'marqué': ['Z99'],
#   'otro': ['Z8', 'A6.1-m', 'N5++'],
#   'gol': ['Z99'],
#   'contra': ['Z5', 'A1.8', 'S3'],
#   'el': ['Z5'],
#   'cáncer': ['B2-'],
#   'y': ['Z5', 'A1.8+'],
#   'lo': ['Z5', 'Z8'],
#   'puse': ['M2', 'A9', 'A1.1.1'],
#   '3-0': ['N1'],
#   '.': ['PUNCT'],
#   'Espero': ['T1.3', 'X2.6+', 'A3+', 'E4.1+', 'X9.2+'],
#   'pueda': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'inspirar': ['Z99'],
#   'a': ['Z5'],
#   'alguien': ['Z5', 'S2m'],
#   'por': ['Z5', 'A2.2', 'M1', 'M6'],
#   'ahí': ['M7', 'M6', 'T1.2', 'Z5'],
#   'Fui': ['M1'],
#   'diagnosticado': ['Z99'],
#   'con': ['Z5', 'A4.1'],
#   'colon': ['Z99'],
#   'mayo': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'cuando': ['Z5', 'T1.1'],
#   'tuve': ['A9'],
#   'hemorragia': ['Z99'],
#   'importante': ['A5', 'A11.1+', 'A13.2'],
#   'Antes': ['N4', 'Z5', 'N3', 'T1.1'],
#   'darme': ['Z99'],
#   'cuenta': ['I1.1/N2/Y2', 'N5', 'N5.1+', 'I1.3.1', 'O2'],
#   'los': ['Z5'],
#   'cirujanos': ['B3/S2mf'],
#   'me': ['Z5', 'Z8'],
#   'extirparon': ['Z99'],
#   '30': ['N1'],
#   'cm': ['Z99'],
#   'La': ['Z5'],
#   'recuperación': ['Z99'],
#   'fue': ['A3+', 'L1', 'Z5'],
#   'dura': ['A13', 'O4'],
#   'pero': ['Z5', 'A2.2-', 'A6.1-'],
#   'manejable': ['Z99'],
#   'Lo': ['Z8m'],
#   'bueno': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+', 'E1', 'E2+'],
#   'es': ['Z5', 'A3+'],
#   'aunque': ['Z5', 'A13'],
#   'tumor': ['Z99'],
#   'era': ['Z5', 'A3+'],
#   'grande': ['N3.1+/A6.1+/A13.2+', 'A5'],
#   'ganglios': ['Z99'],
#   'linfáticos': ['Z99'],
#   'estaban': ['A3+'],
#   'limpios': ['B4', 'O4.2+', 'G2.2+'],
#   'colocándome': ['Z99'],
#   'estadio': ['K5.1/H1'],
#   '2': ['N1'],
#   'Según': ['Z5', 'A9', 'S1.1'],
#   'médicos': ['B2'],
#   'estaba': ['A3+'],
#   'libre': ['A10',
#    'S7.2',
#    'S9',
#    'A5.1+',
#    'X2.1',
#    'A1.7-',
#    'A5.2+',
#    'A12+',
#    'X5.2+'],
#   'uno': ['Z5', 'N1', 'T3', 'T1.2', 'Z8'],
#   'afortunados': ['A1.4+'],
#   'podía': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'dejar': ['S7.4', 'A3'],
#   'atrás': ['Z5', 'N3'],
#   'contar': ['N2', 'Q2.2', 'Q2.1', 'A10+', 'A11.1+'],
#   'un': ['Z5', 'N1'],
#   'bar': ['Z99'],
#   'El': ['Z5'],
#   'marcador': ['Z99'],
#   '1-0': ['N1'],
#   'para': ['Z5'],
#   'mí': ['Z8mf'],
#   'Sin': ['Z5', 'A13.7', 'A10-'],
#   'embargo': ['I1', 'G2.1'],
#   'más': ['A13.3', 'N6++', 'Z5'],
#   'tarde': ['T4-', 'L1-', 'T1.1'],
#   'aprendí': ['X2.3+', 'P1'],
#   'las': ['Z5'],
#   'malas': ['Z99'],
#   'esta': ['Z5', 'A3', 'S2.2'],
#   'mierda': ['Z99'],
#   'también': ['N5++', 'Z5'],
#   'puede': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1<'],
#   'viajar': ['M1', 'M5', 'M7', 'S3.1'],
#   'sangre': ['B2', 'O4.3'],
#   'En': ['Z5', 'N3'],
#   'enero': ['T1.3', 'O4.6-'],
#   '2021': ['N1'],
#   'escáner': ['Z99'],
#   'rutina': ['A6.2+', 'X4.2', 'K4'],
#   'mostró': ['A10+', 'S1.1.1'],
#   'noticias': ['Q1', 'Q4'],
#   'desagradables': ['O4.2-'],
#   'Tenía': ['A9'],
#   'varias': ['Z5', 'A3', 'A6.3+'],
#   'lesiones': ['Z99'],
#   'hígado': ['B1', 'F1', 'S2mf'],
#   'mundo': ['W1', 'S5+c', 'A4.1', 'N5+', 'G2'],
#   'colapsó': ['Z99'],
#   'cirujano': ['B3/S2mf'],
#   'dijo': ['Q1'],
#   'inoperable': ['Z99'],
#   'Ahora': ['T1.1.2', 'Z4', 'Z5'],
#   '4': ['N1'],
#   'metástasis': ['Z99'],
#   'hepática': ['Z99'],
#   'dos': ['Z5', 'N1', 'T3', 'T1.2'],
#   'niños': ['S2mf', 'P1', 'A4.1', 'B1', 'E1+', 'E3'],
#   'pequeños': ['A5', 'A13.7'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'años': ['T1', 'N1', 'T1.3', 'P1c'],
#   'no': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'sin': ['Z5', 'A13.7', 'A10-'],
#   'padre': ['S4/B1', 'S4m', 'S9/S2.2m', 'S2.1', 'S7', 'P1', 'S5'],
#   'Esto': ['W3'],
#   'durante': ['Z5', 'T1.1'],
#   'días': ['T1.1'],
#   'confinamiento': ['Z99'],
#   'coronavirus': ['Z99'],
#   'familia': ['S3', 'S1.1.3'],
#   'e': ['Z5'],
#   'hijos': ['S2.1/S2.2', 'S3.1', 'S5', 'A9'],
#   'podían': ['S7'],
#   'acompañarme': ['Z99'],
#   'todo': ['Z5', 'Z8', 'S2', 'A4', 'A9'],
#   'tiempo': ['T1/W4', 'K5.1', 'T1.2', 'T1.3', 'T1.1.2'],
#   'hospital': ['B3/H1c', 'B3', 'S1.2.4'],
#   'restricciones': ['A1.7+'],
#   'soy': ['A3+', 'L1', 'Z5'],
#   'rendirme': ['Z99'],
#   'asumí': ['Z99'],
#   'como': ['Z5'],
#   'nuevo': ['T3-', 'T1.1', 'A5'],
#   'reto': ['Z99'],
#   'debía': ['S6', 'A7+'],
#   'superar': ['Z99'],
#   'Con': ['Z5', 'A4.1'],
#   'pocas': ['Z5', 'Z8', 'A6.1-'],
#   'probabilidades': ['A7', 'N1'],
#   'al': ['Z5'],
#   'inicio': ['Z99'],
#   '1,5': ['N1'],
#   'quimioterapia': ['Z99'],
#   'radioterapia': ['Z99'],
#   'patearon': ['Z99'],
#   'trasero': ['Z99'],
#   'necesité': ['S6+'],
#   'ni': ['Z6', 'A1.8-'],
#   'siquiera': ['Z5', 'A1.9'],
#   'iba': ['M1',
#    'M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   '2-0': ['N1'],
#   'cruzábamos': ['Z99'],
#   'dedos': ['B1'],
#   'volviera': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'nunca': ['Z5', 'Z6', 'T2-'],
#   'No': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'volvió': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'completamente': ['A13.2'],
#   'distinto': ['A6.1-', 'A11.2+'],
#   'sería': ['A3+', 'L1', 'Z5'],
#   'Los': ['Z5'],
#   'sospecharon': ['Z99'],
#   'algo': ['Z5', 'Z8'],
#   'tiroides': ['Z99'],
#   'Tras': ['Z5', 'M6', 'M1'],
#   'pruebas': ['P1', 'X2.4', 'B3'],
#   'biopsias': ['Z99'],
#   'aguja': ['Z99'],
#   'resultó': ['A8', 'A2.1+', 'O4.2+'],
#   'ahora': ['T1.1.2', 'Z4', 'Z5'],
#   'tengo': ['A9'],
#   'Pensé': ['X2.1'],
#   ':': ['PUNCT'],
#   '“': ['Z99'],
#   'meh': ['Z99'],
#   'este': ['W3'],
#   'fácil': ['A12+', 'S8+', 'A7+'],
#   '”': ['PUNCT'],
#   'Ayer': ['Z5', 'T1.1'],
#   'toda': ['Z5', 'S2', 'A4', 'A9'],
#   'ya': ['Z5', 'T1.1.2', 'T2', 'A2.1+'],
#   'medía': ['N3.1'],
#   'estamos': ['A3+'],
#   'sé': ['Z5', 'A3+', 'X2.2', 'X2.3'],
#   'qué': ['Z5', 'Z8'],
#   'espera': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1'],
#   'sea': ['A3+'],
#   'enfrentaré': ['Z99'],
#   'combatiré': ['Z99'],
#   'Mientras': ['Z5', 'T1'],
#   'tanto': ['N5+++/T1.3'],
#   'recibiré': ['Z99'],
#   'preventiva': ['Z99'],
#   'cada': ['N5'],
#   '6': ['N1'],
#   'meses': ['T1.1'],
#   'seguiré': ['A1.1.1', 'A3', 'M1', 'Y2'],
#   'disfrutando': ['E2+', 'A9+', 'E4.1+'],
#   'criar': ['S1.1', 'P1', 'X1'],
#   'mis': ['Z5', 'A8', 'A9+'],
#   'Así': ['Z5', 'A8', 'N3'],
#   'camarada': ['Z99'],
#   'considera': ['X2'],
#   'tuyo': ['A9', 'N5', 'Z8'],
#   'Tienes': ['Z99'],
#   'fuerza': ['S1.2.5+',
#    'N5+',
#    'A5.1+',
#    'X5.2+',
#    'S7.1+',
#    'X9.1+',
#    'O4.1',
#    'S1.2.3+'],
#   'optimismo': ['X2.6+/A5.1+'],
#   'enfrentarlo': ['Z99'],
#   'importa': ['Z99'],
#   'vida': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'Mantén': ['Z99'],
#   'cabeza': ['B1', 'G1', 'G3'],
#   'alto': ['S2.1', 'N3.7+'],
#   'sigue': ['A3', 'M1'],
#   'anotando': ['Z99']},
#  27: {'Hola': ['Z99'],
#   'camaradas': ['Z99'],
#   ',': ['PUNCT'],
#   'solo': ['A14', 'S5-', 'N5---', 'S5-', 'S3.2-'],
#   'quería': ['X7+', 'A2', 'S7', 'X2'],
#   'compartir': ['S1.1.2+'],
#   'mi': ['Z5', 'Z8', 'A9'],
#   'historia': ['T1.1', 'X2', 'G1', 'P1', 'T3+'],
#   'después': ['N4', 'Z5', 'T1.1'],
#   'de': ['Z5'],
#   'una': ['Z5', 'Z8', 'N1'],
#   'operación': ['N2', 'B3', 'I2.2', 'G3', 'A1.1.1', 'X2.4'],
#   'en': ['Z5', 'N3'],
#   'la': ['Z5'],
#   'que': ['Z5', 'Z8'],
#   'marqué': ['Z99'],
#   'otro': ['Z8', 'A6.1-m', 'N5++'],
#   'gol': ['Z99'],
#   'contra': ['Z5', 'A1.8', 'S3'],
#   'el': ['Z5'],
#   'cáncer': ['B2-'],
#   'y': ['Z5', 'A1.8+'],
#   'lo': ['Z5', 'Z8'],
#   'puse': ['M2', 'A9', 'A1.1.1'],
#   '3-0': ['N1'],
#   '.': ['PUNCT'],
#   'Espero': ['T1.3', 'X2.6+', 'A3+', 'E4.1+', 'X9.2+'],
#   'pueda': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'inspirar': ['Z99'],
#   'a': ['Z5'],
#   'alguien': ['Z5', 'S2m'],
#   'por': ['Z5', 'A2.2', 'M1', 'M6'],
#   'ahí': ['M7', 'M6', 'T1.2', 'Z5'],
#   'Fui': ['M1'],
#   'diagnosticado': ['Z99'],
#   'con': ['Z5', 'A4.1'],
#   'colon': ['Z99'],
#   'mayo': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'cuando': ['Z5', 'T1.1'],
#   'tuve': ['A9'],
#   'hemorragia': ['Z99'],
#   'importante': ['A5', 'A11.1+', 'A13.2'],
#   'Antes': ['N4', 'Z5', 'N3', 'T1.1'],
#   'darme': ['Z99'],
#   'cuenta': ['I1.1/N2/Y2', 'N5', 'N5.1+', 'I1.3.1', 'O2'],
#   'los': ['Z5'],
#   'cirujanos': ['B3/S2mf'],
#   'me': ['Z5', 'Z8'],
#   'extirparon': ['Z99'],
#   '30': ['N1'],
#   'cm': ['Z99'],
#   'La': ['Z5'],
#   'recuperación': ['Z99'],
#   'fue': ['A3+', 'L1', 'Z5'],
#   'dura': ['A13', 'O4'],
#   'pero': ['Z5', 'A2.2-', 'A6.1-'],
#   'manejable': ['Z99'],
#   'Lo': ['Z8m'],
#   'bueno': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+', 'E1', 'E2+'],
#   'es': ['Z5', 'A3+'],
#   'aunque': ['Z5', 'A13'],
#   'tumor': ['Z99'],
#   'era': ['Z5', 'A3+'],
#   'grande': ['N3.1+/A6.1+/A13.2+', 'A5'],
#   'ganglios': ['Z99'],
#   'linfáticos': ['Z99'],
#   'estaban': ['A3+'],
#   'limpios': ['B4', 'O4.2+', 'G2.2+'],
#   'colocándome': ['Z99'],
#   'estadio': ['K5.1/H1'],
#   '2': ['N1'],
#   'Según': ['Z5', 'A9', 'S1.1'],
#   'médicos': ['B2'],
#   'estaba': ['A3+'],
#   'libre': ['A10',
#    'S7.2',
#    'S9',
#    'A5.1+',
#    'X2.1',
#    'A1.7-',
#    'A5.2+',
#    'A12+',
#    'X5.2+'],
#   'uno': ['Z5', 'N1', 'T3', 'T1.2', 'Z8'],
#   'afortunados': ['A1.4+'],
#   'podía': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1'],
#   'dejar': ['S7.4', 'A3'],
#   'atrás': ['Z5', 'N3'],
#   'contar': ['N2', 'Q2.2', 'Q2.1', 'A10+', 'A11.1+'],
#   'un': ['Z5', 'N1'],
#   'bar': ['Z99'],
#   'El': ['Z5'],
#   'marcador': ['Z99'],
#   '1-0': ['N1'],
#   'para': ['Z5'],
#   'mí': ['Z8mf'],
#   'Sin': ['Z5', 'A13.7', 'A10-'],
#   'embargo': ['I1', 'G2.1'],
#   'más': ['A13.3', 'N6++', 'Z5'],
#   'tarde': ['T4-', 'L1-', 'T1.1'],
#   'aprendí': ['X2.3+', 'P1'],
#   'las': ['Z5'],
#   'malas': ['Z99'],
#   'esta': ['Z5', 'A3', 'S2.2'],
#   'mierda': ['Z99'],
#   'también': ['N5++', 'Z5'],
#   'puede': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2', 'S7', 'G1<'],
#   'viajar': ['M1', 'M5', 'M7', 'S3.1'],
#   'sangre': ['B2', 'O4.3'],
#   'En': ['Z5', 'N3'],
#   'enero': ['T1.3', 'O4.6-'],
#   '2021': ['N1'],
#   'escáner': ['Z99'],
#   'rutina': ['A6.2+', 'X4.2', 'K4'],
#   'mostró': ['A10+', 'S1.1.1'],
#   'noticias': ['Q1', 'Q4'],
#   'desagradables': ['O4.2-'],
#   'Tenía': ['A9'],
#   'varias': ['Z5', 'A3', 'A6.3+'],
#   'lesiones': ['Z99'],
#   'hígado': ['B1', 'F1', 'S2mf'],
#   'mundo': ['W1', 'S5+c', 'A4.1', 'N5+', 'G2'],
#   'colapsó': ['Z99'],
#   'cirujano': ['B3/S2mf'],
#   'dijo': ['Q1'],
#   'inoperable': ['Z99'],
#   'Ahora': ['T1.1.2', 'Z4', 'Z5'],
#   '4': ['N1'],
#   'metástasis': ['Z99'],
#   'hepática': ['Z99'],
#   'dos': ['Z5', 'N1', 'T3', 'T1.2'],
#   'niños': ['S2mf', 'P1', 'A4.1', 'B1', 'E1+', 'E3'],
#   'pequeños': ['A5', 'A13.7'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'años': ['T1', 'N1', 'T1.3', 'P1c'],
#   'no': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'sin': ['Z5', 'A13.7', 'A10-'],
#   'padre': ['S4/B1', 'S4m', 'S9/S2.2m', 'S2.1', 'S7', 'P1', 'S5'],
#   'Esto': ['W3'],
#   'durante': ['Z5', 'T1.1'],
#   'días': ['T1.1'],
#   'confinamiento': ['Z99'],
#   'coronavirus': ['Z99'],
#   'familia': ['S3', 'S1.1.3'],
#   'e': ['Z5'],
#   'hijos': ['S2.1/S2.2', 'S3.1', 'S5', 'A9'],
#   'podían': ['S7'],
#   'acompañarme': ['Z99'],
#   'todo': ['Z5', 'Z8', 'S2', 'A4', 'A9'],
#   'tiempo': ['T1/W4', 'K5.1', 'T1.2', 'T1.3', 'T1.1.2'],
#   'hospital': ['B3/H1c', 'B3', 'S1.2.4'],
#   'restricciones': ['A1.7+'],
#   'soy': ['A3+', 'L1', 'Z5'],
#   'rendirme': ['Z99'],
#   'asumí': ['Z99'],
#   'como': ['Z5'],
#   'nuevo': ['T3-', 'T1.1', 'A5'],
#   'reto': ['Z99'],
#   'debía': ['S6', 'A7+'],
#   'superar': ['Z99'],
#   'Con': ['Z5', 'A4.1'],
#   'pocas': ['Z5', 'Z8', 'A6.1-'],
#   'probabilidades': ['A7', 'N1'],
#   'al': ['Z5'],
#   'inicio': ['Z99'],
#   '1,5': ['N1'],
#   'quimioterapia': ['Z99'],
#   'radioterapia': ['Z99'],
#   'patearon': ['Z99'],
#   'trasero': ['Z99'],
#   'necesité': ['S6+'],
#   'ni': ['Z6', 'A1.8-'],
#   'siquiera': ['Z5', 'A1.9'],
#   'iba': ['M1',
#    'M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   '2-0': ['N1'],
#   'cruzábamos': ['Z99'],
#   'dedos': ['B1'],
#   'volviera': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'nunca': ['Z5', 'Z6', 'T2-'],
#   'No': ['S8-', 'Z4', 'Z6', 'Z5'],
#   'volvió': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1',
#    'B1'],
#   'completamente': ['A13.2'],
#   'distinto': ['A6.1-', 'A11.2+'],
#   'sería': ['A3+', 'L1', 'Z5'],
#   'Los': ['Z5'],
#   'sospecharon': ['Z99'],
#   'algo': ['Z5', 'Z8'],
#   'tiroides': ['Z99'],
#   'Tras': ['Z5', 'M6', 'M1'],
#   'pruebas': ['P1', 'X2.4', 'B3'],
#   'biopsias': ['Z99'],
#   'aguja': ['Z99'],
#   'resultó': ['A8', 'A2.1+', 'O4.2+'],
#   'ahora': ['T1.1.2', 'Z4', 'Z5'],
#   'tengo': ['A9'],
#   'Pensé': ['X2.1'],
#   ':': ['PUNCT'],
#   '“': ['Z99'],
#   'meh': ['Z99'],
#   'este': ['W3'],
#   'fácil': ['A12+', 'S8+', 'A7+'],
#   '”': ['PUNCT'],
#   'Ayer': ['Z5', 'T1.1'],
#   'toda': ['Z5', 'S2', 'A4', 'A9'],
#   'ya': ['Z5', 'T1.1.2', 'T2', 'A2.1+'],
#   'medía': ['N3.1'],
#   'estamos': ['A3+'],
#   'sé': ['Z5', 'A3+', 'X2.2', 'X2.3'],
#   'qué': ['Z5', 'Z8'],
#   'espera': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1'],
#   'sea': ['A3+'],
#   'enfrentaré': ['Z99'],
#   'combatiré': ['Z99'],
#   'Mientras': ['Z5', 'T1'],
#   'tanto': ['N5+++/T1.3'],
#   'recibiré': ['Z99'],
#   'preventiva': ['Z99'],
#   'cada': ['N5'],
#   '6': ['N1'],
#   'meses': ['T1.1'],
#   'seguiré': ['A1.1.1', 'A3', 'M1', 'Y2'],
#   'disfrutando': ['E2+', 'A9+', 'E4.1+'],
#   'criar': ['S1.1', 'P1', 'X1'],
#   'mis': ['Z5', 'A8', 'A9+'],
#   'Así': ['Z5', 'A8', 'N3'],
#   'camarada': ['Z99'],
#   'considera': ['X2'],
#   'tuyo': ['A9', 'N5', 'Z8'],
#   'Tienes': ['Z99'],
#   'fuerza': ['S1.2.5+',
#    'N5+',
#    'A5.1+',
#    'X5.2+',
#    'S7.1+',
#    'X9.1+',
#    'O4.1',
#    'S1.2.3+'],
#   'optimismo': ['X2.6+/A5.1+'],
#   'enfrentarlo': ['Z99'],
#   'importa': ['Z99'],
#   'vida': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'Mantén': ['Z99'],
#   'cabeza': ['B1', 'G1', 'G3'],
#   'alto': ['S2.1', 'N3.7+'],
#   'sigue': ['A3', 'M1'],
#   'anotando': ['Z99']}}

# %% [markdown]
# ---
#
# ### **STEP 5: Extracting emotion words using USAS emotion tags:** *usas_emotion_tags function*
#
# >>**input:** piece of text
#
# >>**output:** python dictionary where *keys* represent a sentence in the input text and *values* represent a dictionary of usas tagged emotion words and tags for that sentence
#
# ---

# %%
usas_emo_cls_dict = {'E1': 'Emotional Actions, States And Processes General',
 'E1+': 'Emotional',
 'E1-': 'Unemotional',
 'E2': 'Liking',
 'E2+': 'Like',
 'E2-': 'Dislike',
 'E3': 'Calm/Violent/Angry',
 'E3+': 'Calm',
 'E3-': 'Violent/Angry',
 'E4': 'Happiness and Contentment',
 'E4.1': 'Happy/sad',
 'E4.1+': 'Happy',
 'E4.1-': 'Sad',
 'E4.2': 'Contentment',
 'E4.2+': 'Content',
 'E4.2-': 'Discontent',
 'E5': 'Bravery and Fear',
 'E5+': 'Bravery',
 'E5-': 'Fear/shock',
 'E6': 'Worry and confidence',
 'E6+': 'Confident',
 'E6-': 'Worry'}

# %%
# Defining the emotion tag extraction function
def usas_emotion_tags(text):
  usas_eval_tags = {}
  sentences = nltk.sent_tokenize(text)
  for i in range(len(sentences)):
    if(sentences[i]):
      usas_list = {}
      sent = nlp(sentences[i])
      print("\n")
      print(Fore.MAGENTA + Style.BRIGHT + "--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
      print(Fore.BLUE + Style.BRIGHT + f"Sentence {i}:", sentences[i])
      for token in sent:
        tags = token._.pymusas_tags
        emo_tags = [x for x in tags if x.startswith('E')]
        if emo_tags:
          usas_list[token.text] = emo_tags
          print(Fore.MAGENTA + f'{token.text}:' + Fore.GREEN, emo_tags)
      usas_eval_tags[sentences[i]] = usas_list
  return usas_eval_tags

# %%
# Text 1 emotion tag extraction
text1_emo_tags = usas_emotion_tags(text_1)
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 0: Hola camaradas, solo quería compartir mi historia después de una operación en la que marqué otro gol contra el cáncer y lo puse 3-0.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 1: Espero que pueda inspirar a alguien por ahí.
# Espero: ['E4.1+']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 2: Fui diagnosticado con cáncer de colon en mayo de 2020, cuando tuve una hemorragia importante.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 3: Antes de darme cuenta, los cirujanos me extirparon 30 cm de colon.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 4: La recuperación fue dura, pero manejable.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 5: Lo bueno es que, aunque el tumor era grande, los ganglios linfáticos estaban limpios, colocándome en estadio 2.
# bueno: ['E1', 'E2+']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 6: Según los médicos, estaba libre y era uno de los afortunados que podía dejar el cáncer atrás y contar la historia en un bar.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 7: El marcador era 1-0 para mí.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 8: Sin embargo, más tarde aprendí por las malas que esta mierda también puede viajar por la sangre.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 9: En enero de 2021, mi escáner de rutina mostró noticias desagradables.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 10: Tenía varias lesiones en el hígado y mi mundo colapsó cuando el cirujano me dijo que era inoperable.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 11: Ahora era un estadio 4 de cáncer de colon con metástasis hepática inoperable y dos niños pequeños de 3 y 5 años que no podía dejar sin padre.
# niños: ['E1+', 'E3']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 12: Esto fue durante los días de confinamiento por coronavirus, y mi familia e hijos no podían acompañarme todo el tiempo en el hospital por las restricciones.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 13: Sin embargo, no soy de rendirme, y lo asumí como un nuevo reto que debía superar.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 14: Con pocas probabilidades al inicio, después de 1,5 años de quimioterapia y radioterapia que me patearon el trasero, no necesité ni siquiera una operación de hígado.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 15: El marcador iba 2-0 y cruzábamos los dedos para que no volviera nunca.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 16: No volvió, pero un cáncer completamente distinto sería mi nuevo reto.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 17: Los médicos sospecharon algo en mi tiroides durante otro escáner de rutina.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 18: Tras pruebas y biopsias con aguja, resultó que ahora tengo cáncer de tiroides.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 19: Pensé: “meh, este es fácil”.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 20: Ayer me extirparon toda la tiroides en una operación.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 21: El tumor ya medía 2 cm.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 22: Ahora estamos 3-0.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 23: No sé qué me espera, pero sea lo que sea, lo enfrentaré y lo combatiré.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 24: Mientras tanto, recibiré quimioterapia preventiva cada 6 meses y seguiré disfrutando de criar a mis hijos.
# disfrutando: ['E2+', 'E4.1+']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 25: Así que, camarada, considera lo tuyo como un reto también.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 26: Tienes la fuerza y el optimismo para enfrentarlo, no importa lo dura que sea la vida.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 27: Mantén la cabeza en alto y sigue anotando.

# %%
text1_emo_tags
# Out:
# {'Hola camaradas, solo quería compartir mi historia después de una operación en la que marqué otro gol contra el cáncer y lo puse 3-0.': {},
#  'Espero que pueda inspirar a alguien por ahí.': {'Espero': ['E4.1+']},
#  'Fui diagnosticado con cáncer de colon en mayo de 2020, cuando tuve una hemorragia importante.': {},
#  'Antes de darme cuenta, los cirujanos me extirparon 30 cm de colon.': {},
#  'La recuperación fue dura, pero manejable.': {},
#  'Lo bueno es que, aunque el tumor era grande, los ganglios linfáticos estaban limpios, colocándome en estadio 2.': {'bueno': ['E1',
#    'E2+']},
#  'Según los médicos, estaba libre y era uno de los afortunados que podía dejar el cáncer atrás y contar la historia en un bar.': {},
#  'El marcador era 1-0 para mí.': {},
#  'Sin embargo, más tarde aprendí por las malas que esta mierda también puede viajar por la sangre.': {},
#  'En enero de 2021, mi escáner de rutina mostró noticias desagradables.': {},
#  'Tenía varias lesiones en el hígado y mi mundo colapsó cuando el cirujano me dijo que era inoperable.': {},
#  'Ahora era un estadio 4 de cáncer de colon con metástasis hepática inoperable y dos niños pequeños de 3 y 5 años que no podía dejar sin padre.': {'niños': ['E1+',
#    'E3']},
#  'Esto fue durante los días de confinamiento por coronavirus, y mi familia e hijos no podían acompañarme todo el tiempo en el hospital por las restricciones.': {},
#  'Sin embargo, no soy de rendirme, y lo asumí como un nuevo reto que debía superar.': {},
#  'Con pocas probabilidades al inicio, después de 1,5 años de quimioterapia y radioterapia que me patearon el trasero, no necesité ni siquiera una operación de hígado.': {},
#  'El marcador iba 2-0 y cruzábamos los dedos para que no volviera nunca.': {},
#  'No volvió, pero un cáncer completamente distinto sería mi nuevo reto.': {},
#  'Los médicos sospecharon algo en mi tiroides durante otro escáner de rutina.': {},
#  'Tras pruebas y biopsias con aguja, resultó que ahora tengo cáncer de tiroides.': {},
#  'Pensé: “meh, este es fácil”.': {},
#  'Ayer me extirparon toda la tiroides en una operación.': {},
#  'El tumor ya medía 2 cm.': {},
#  'Ahora estamos 3-0.': {},
#  'No sé qué me espera, pero sea lo que sea, lo enfrentaré y lo combatiré.': {},
#  'Mientras tanto, recibiré quimioterapia preventiva cada 6 meses y seguiré disfrutando de criar a mis hijos.': {'disfrutando': ['E2+',
#    'E4.1+']},
#  'Así que, camarada, considera lo tuyo como un reto también.': {},
#  'Tienes la fuerza y el optimismo para enfrentarlo, no importa lo dura que sea la vida.': {},
#  'Mantén la cabeza en alto y sigue anotando.': {}}

# %% [markdown]
# ---
#
# ### **STEP 6: USAS Sentiment Classification:** *usas_sentiment_classifier function*
#
# >>**input:** dictionary of sentence and emotion word tags
#
# >>**output:** sentiment class *positive*, *negative*, *neutral* with counts per class
#
# ---

# %%
# Defining the sentiment classifier
def usas_sentiment_classifier(usas_emo_tag, positive, negative, neutral):
  sentiment_cls = {}
  for sent, emo_dict in usas_emo_tag.items():
    neg, pos, neu = 0, 0, 0
    if(emo_dict):
      for key, val_list in emo_dict.items():
        for val in val_list:
          if val.endswith('-'):
            neg+=1
            negative+=1
          elif  val.endswith('+'):
            pos+=1
            positive+=1
          else:
            neu+=1
            neutral+=1
    else:
      neu+=1
      neutral+=1
    if neg==max(pos, neg, neu):
          sentiment = 'negative'
          sentiment_cls[sent] = sentiment
    elif pos==max(pos, neg, neu):
          sentiment = 'positive'
          sentiment_cls[sent] = sentiment
    else:
          sentiment = 'neutral'
          sentiment_cls[sent] = sentiment
    print(Fore.MAGENTA + Style.BRIGHT + "Sentence:", sent)
    print(Fore.GREEN + Style.BRIGHT + "class:", sentiment)
    print("\n")
    print(Fore.GREEN + Style.BRIGHT + "--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
  return sentiment_cls, positive, negative, neutral

# %%
# Sentiment counts and tagging
sentiments_text1, pos_text1, neg_text1, neu_text1 = usas_sentiment_classifier(text1_emo_tags, 0, 0, 0)
# Out:
# Sentence: Hola camaradas, solo quería compartir mi historia después de una operación en la que marqué otro gol contra el cáncer y lo puse 3-0.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Espero que pueda inspirar a alguien por ahí.
# class: positive
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Fui diagnosticado con cáncer de colon en mayo de 2020, cuando tuve una hemorragia importante.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Antes de darme cuenta, los cirujanos me extirparon 30 cm de colon.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: La recuperación fue dura, pero manejable.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Lo bueno es que, aunque el tumor era grande, los ganglios linfáticos estaban limpios, colocándome en estadio 2.
# class: positive
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Según los médicos, estaba libre y era uno de los afortunados que podía dejar el cáncer atrás y contar la historia en un bar.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: El marcador era 1-0 para mí.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Sin embargo, más tarde aprendí por las malas que esta mierda también puede viajar por la sangre.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: En enero de 2021, mi escáner de rutina mostró noticias desagradables.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Tenía varias lesiones en el hígado y mi mundo colapsó cuando el cirujano me dijo que era inoperable.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ahora era un estadio 4 de cáncer de colon con metástasis hepática inoperable y dos niños pequeños de 3 y 5 años que no podía dejar sin padre.
# class: positive
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Esto fue durante los días de confinamiento por coronavirus, y mi familia e hijos no podían acompañarme todo el tiempo en el hospital por las restricciones.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Sin embargo, no soy de rendirme, y lo asumí como un nuevo reto que debía superar.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Con pocas probabilidades al inicio, después de 1,5 años de quimioterapia y radioterapia que me patearon el trasero, no necesité ni siquiera una operación de hígado.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: El marcador iba 2-0 y cruzábamos los dedos para que no volviera nunca.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: No volvió, pero un cáncer completamente distinto sería mi nuevo reto.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Los médicos sospecharon algo en mi tiroides durante otro escáner de rutina.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Tras pruebas y biopsias con aguja, resultó que ahora tengo cáncer de tiroides.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Pensé: “meh, este es fácil”.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ayer me extirparon toda la tiroides en una operación.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: El tumor ya medía 2 cm.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ahora estamos 3-0.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: No sé qué me espera, pero sea lo que sea, lo enfrentaré y lo combatiré.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Mientras tanto, recibiré quimioterapia preventiva cada 6 meses y seguiré disfrutando de criar a mis hijos.
# class: positive
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Así que, camarada, considera lo tuyo como un reto también.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Tienes la fuerza y el optimismo para enfrentarlo, no importa lo dura que sea la vida.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Mantén la cabeza en alto y sigue anotando.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Text 1 sentiment tags per sentence
sentiments_text1
# Out:
# {'Hola camaradas, solo quería compartir mi historia después de una operación en la que marqué otro gol contra el cáncer y lo puse 3-0.': 'neutral',
#  'Espero que pueda inspirar a alguien por ahí.': 'positive',
#  'Fui diagnosticado con cáncer de colon en mayo de 2020, cuando tuve una hemorragia importante.': 'neutral',
#  'Antes de darme cuenta, los cirujanos me extirparon 30 cm de colon.': 'neutral',
#  'La recuperación fue dura, pero manejable.': 'neutral',
#  'Lo bueno es que, aunque el tumor era grande, los ganglios linfáticos estaban limpios, colocándome en estadio 2.': 'positive',
#  'Según los médicos, estaba libre y era uno de los afortunados que podía dejar el cáncer atrás y contar la historia en un bar.': 'neutral',
#  'El marcador era 1-0 para mí.': 'neutral',
#  'Sin embargo, más tarde aprendí por las malas que esta mierda también puede viajar por la sangre.': 'neutral',
#  'En enero de 2021, mi escáner de rutina mostró noticias desagradables.': 'neutral',
#  'Tenía varias lesiones en el hígado y mi mundo colapsó cuando el cirujano me dijo que era inoperable.': 'neutral',
#  'Ahora era un estadio 4 de cáncer de colon con metástasis hepática inoperable y dos niños pequeños de 3 y 5 años que no podía dejar sin padre.': 'positive',
#  'Esto fue durante los días de confinamiento por coronavirus, y mi familia e hijos no podían acompañarme todo el tiempo en el hospital por las restricciones.': 'neutral',
#  'Sin embargo, no soy de rendirme, y lo asumí como un nuevo reto que debía superar.': 'neutral',
#  'Con pocas probabilidades al inicio, después de 1,5 años de quimioterapia y radioterapia que me patearon el trasero, no necesité ni siquiera una operación de hígado.': 'neutral',
#  'El marcador iba 2-0 y cruzábamos los dedos para que no volviera nunca.': 'neutral',
#  'No volvió, pero un cáncer completamente distinto sería mi nuevo reto.': 'neutral',
#  'Los médicos sospecharon algo en mi tiroides durante otro escáner de rutina.': 'neutral',
#  'Tras pruebas y biopsias con aguja, resultó que ahora tengo cáncer de tiroides.': 'neutral',
#  'Pensé: “meh, este es fácil”.': 'neutral',
#  'Ayer me extirparon toda la tiroides en una operación.': 'neutral',
#  'El tumor ya medía 2 cm.': 'neutral',
#  'Ahora estamos 3-0.': 'neutral',
#  'No sé qué me espera, pero sea lo que sea, lo enfrentaré y lo combatiré.': 'neutral',
#  'Mientras tanto, recibiré quimioterapia preventiva cada 6 meses y seguiré disfrutando de criar a mis hijos.': 'positive',
#  'Así que, camarada, considera lo tuyo como un reto también.': 'neutral',
#  'Tienes la fuerza y el optimismo para enfrentarlo, no importa lo dura que sea la vida.': 'neutral',
#  'Mantén la cabeza en alto y sigue anotando.': 'neutral'}

# %%
# Text 1 sentiment counts for per class
print(f'Text 1: positive = {pos_text1}, negative = {neg_text1}, neutral = {neu_text1}')
# Out:
# Text 1: positive = 5, negative = 0, neutral = 26

# %%
text1_emo_tags
# Out:
# {'Hola camaradas, solo quería compartir mi historia después de una operación en la que marqué otro gol contra el cáncer y lo puse 3-0.': {},
#  'Espero que pueda inspirar a alguien por ahí.': {'Espero': ['E4.1+']},
#  'Fui diagnosticado con cáncer de colon en mayo de 2020, cuando tuve una hemorragia importante.': {},
#  'Antes de darme cuenta, los cirujanos me extirparon 30 cm de colon.': {},
#  'La recuperación fue dura, pero manejable.': {},
#  'Lo bueno es que, aunque el tumor era grande, los ganglios linfáticos estaban limpios, colocándome en estadio 2.': {'bueno': ['E1',
#    'E2+']},
#  'Según los médicos, estaba libre y era uno de los afortunados que podía dejar el cáncer atrás y contar la historia en un bar.': {},
#  'El marcador era 1-0 para mí.': {},
#  'Sin embargo, más tarde aprendí por las malas que esta mierda también puede viajar por la sangre.': {},
#  'En enero de 2021, mi escáner de rutina mostró noticias desagradables.': {},
#  'Tenía varias lesiones en el hígado y mi mundo colapsó cuando el cirujano me dijo que era inoperable.': {},
#  'Ahora era un estadio 4 de cáncer de colon con metástasis hepática inoperable y dos niños pequeños de 3 y 5 años que no podía dejar sin padre.': {'niños': ['E1+',
#    'E3']},
#  'Esto fue durante los días de confinamiento por coronavirus, y mi familia e hijos no podían acompañarme todo el tiempo en el hospital por las restricciones.': {},
#  'Sin embargo, no soy de rendirme, y lo asumí como un nuevo reto que debía superar.': {},
#  'Con pocas probabilidades al inicio, después de 1,5 años de quimioterapia y radioterapia que me patearon el trasero, no necesité ni siquiera una operación de hígado.': {},
#  'El marcador iba 2-0 y cruzábamos los dedos para que no volviera nunca.': {},
#  'No volvió, pero un cáncer completamente distinto sería mi nuevo reto.': {},
#  'Los médicos sospecharon algo en mi tiroides durante otro escáner de rutina.': {},
#  'Tras pruebas y biopsias con aguja, resultó que ahora tengo cáncer de tiroides.': {},
#  'Pensé: “meh, este es fácil”.': {},
#  'Ayer me extirparon toda la tiroides en una operación.': {},
#  'El tumor ya medía 2 cm.': {},
#  'Ahora estamos 3-0.': {},
#  'No sé qué me espera, pero sea lo que sea, lo enfrentaré y lo combatiré.': {},
#  'Mientras tanto, recibiré quimioterapia preventiva cada 6 meses y seguiré disfrutando de criar a mis hijos.': {'disfrutando': ['E2+',
#    'E4.1+']},
#  'Así que, camarada, considera lo tuyo como un reto también.': {},
#  'Tienes la fuerza y el optimismo para enfrentarlo, no importa lo dura que sea la vida.': {},
#  'Mantén la cabeza en alto y sigue anotando.': {}}

# %% [markdown]
# ---
# ### **STEP 7: Sentiment Probability - Sentence-level**
# ---

# %%
# Defining the probability estimation function for sentiment classification at the sentence-level
def sentence_sentiment_prob(usas_emo_tag):
  sentiment_cls = {}
  for sent, emo_dict in usas_emo_tag.items():
    neg, pos, neu = 0, 0, 0
    if(emo_dict):
      for key, val_list in emo_dict.items():
        for val in val_list:
          if val.endswith('-'):
            neg+=1
          elif val.endswith('+'):
            pos+=1
          else:
            neu+=1
    else:
      neu+=1
    sentiment = f'positive={pos/(pos+neg+neu)}, negative={neg/(pos+neg+neu)}, neutral={neu/(pos+neg+neu)}'
    sentiment_cls[sent] = sentiment
    print(Fore.GREEN + Style.BRIGHT + "Sentence:", sent)
    print(Fore.CYAN + Style.BRIGHT + "class:", sentiment)
    print("\n")
    print(Fore.CYAN + Style.BRIGHT + "--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
  return sentiment_cls

# %%
# Text 1 sentence-level sentiment probability
sentiment_prob_text1 = (sentence_sentiment_prob(text1_emo_tags))
# Out:
# Sentence: Hola camaradas, solo quería compartir mi historia después de una operación en la que marqué otro gol contra el cáncer y lo puse 3-0.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Espero que pueda inspirar a alguien por ahí.
# class: positive=1.0, negative=0.0, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Fui diagnosticado con cáncer de colon en mayo de 2020, cuando tuve una hemorragia importante.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Antes de darme cuenta, los cirujanos me extirparon 30 cm de colon.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: La recuperación fue dura, pero manejable.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Lo bueno es que, aunque el tumor era grande, los ganglios linfáticos estaban limpios, colocándome en estadio 2.
# class: positive=0.5, negative=0.0, neutral=0.5
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Según los médicos, estaba libre y era uno de los afortunados que podía dejar el cáncer atrás y contar la historia en un bar.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: El marcador era 1-0 para mí.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Sin embargo, más tarde aprendí por las malas que esta mierda también puede viajar por la sangre.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: En enero de 2021, mi escáner de rutina mostró noticias desagradables.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Tenía varias lesiones en el hígado y mi mundo colapsó cuando el cirujano me dijo que era inoperable.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ahora era un estadio 4 de cáncer de colon con metástasis hepática inoperable y dos niños pequeños de 3 y 5 años que no podía dejar sin padre.
# class: positive=0.5, negative=0.0, neutral=0.5
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Esto fue durante los días de confinamiento por coronavirus, y mi familia e hijos no podían acompañarme todo el tiempo en el hospital por las restricciones.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Sin embargo, no soy de rendirme, y lo asumí como un nuevo reto que debía superar.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Con pocas probabilidades al inicio, después de 1,5 años de quimioterapia y radioterapia que me patearon el trasero, no necesité ni siquiera una operación de hígado.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: El marcador iba 2-0 y cruzábamos los dedos para que no volviera nunca.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: No volvió, pero un cáncer completamente distinto sería mi nuevo reto.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Los médicos sospecharon algo en mi tiroides durante otro escáner de rutina.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Tras pruebas y biopsias con aguja, resultó que ahora tengo cáncer de tiroides.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Pensé: “meh, este es fácil”.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ayer me extirparon toda la tiroides en una operación.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: El tumor ya medía 2 cm.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ahora estamos 3-0.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: No sé qué me espera, pero sea lo que sea, lo enfrentaré y lo combatiré.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Mientras tanto, recibiré quimioterapia preventiva cada 6 meses y seguiré disfrutando de criar a mis hijos.
# class: positive=1.0, negative=0.0, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Así que, camarada, considera lo tuyo como un reto también.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Tienes la fuerza y el optimismo para enfrentarlo, no importa lo dura que sea la vida.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Mantén la cabeza en alto y sigue anotando.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
sentiment_prob_text1
# Out:
# {'Hola camaradas, solo quería compartir mi historia después de una operación en la que marqué otro gol contra el cáncer y lo puse 3-0.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Espero que pueda inspirar a alguien por ahí.': 'positive=1.0, negative=0.0, neutral=0.0',
#  'Fui diagnosticado con cáncer de colon en mayo de 2020, cuando tuve una hemorragia importante.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Antes de darme cuenta, los cirujanos me extirparon 30 cm de colon.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'La recuperación fue dura, pero manejable.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Lo bueno es que, aunque el tumor era grande, los ganglios linfáticos estaban limpios, colocándome en estadio 2.': 'positive=0.5, negative=0.0, neutral=0.5',
#  'Según los médicos, estaba libre y era uno de los afortunados que podía dejar el cáncer atrás y contar la historia en un bar.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'El marcador era 1-0 para mí.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Sin embargo, más tarde aprendí por las malas que esta mierda también puede viajar por la sangre.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'En enero de 2021, mi escáner de rutina mostró noticias desagradables.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Tenía varias lesiones en el hígado y mi mundo colapsó cuando el cirujano me dijo que era inoperable.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Ahora era un estadio 4 de cáncer de colon con metástasis hepática inoperable y dos niños pequeños de 3 y 5 años que no podía dejar sin padre.': 'positive=0.5, negative=0.0, neutral=0.5',
#  'Esto fue durante los días de confinamiento por coronavirus, y mi familia e hijos no podían acompañarme todo el tiempo en el hospital por las restricciones.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Sin embargo, no soy de rendirme, y lo asumí como un nuevo reto que debía superar.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Con pocas probabilidades al inicio, después de 1,5 años de quimioterapia y radioterapia que me patearon el trasero, no necesité ni siquiera una operación de hígado.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'El marcador iba 2-0 y cruzábamos los dedos para que no volviera nunca.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'No volvió, pero un cáncer completamente distinto sería mi nuevo reto.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Los médicos sospecharon algo en mi tiroides durante otro escáner de rutina.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Tras pruebas y biopsias con aguja, resultó que ahora tengo cáncer de tiroides.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Pensé: “meh, este es fácil”.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Ayer me extirparon toda la tiroides en una operación.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'El tumor ya medía 2 cm.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Ahora estamos 3-0.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'No sé qué me espera, pero sea lo que sea, lo enfrentaré y lo combatiré.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Mientras tanto, recibiré quimioterapia preventiva cada 6 meses y seguiré disfrutando de criar a mis hijos.': 'positive=1.0, negative=0.0, neutral=0.0',
#  'Así que, camarada, considera lo tuyo como un reto también.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Tienes la fuerza y el optimismo para enfrentarlo, no importa lo dura que sea la vida.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Mantén la cabeza en alto y sigue anotando.': 'positive=0.0, negative=0.0, neutral=1.0'}

# %% [markdown]
# ---
# ### **STEP 8: Sentiment Probability -Text-level**
# ---

# %%
def text_sentiment_prob(text, pos, neg, neu):
  prob = f'positive={pos/(pos+neg+neu)}, negative={neg/(pos+neg+neu)}, neutral={neu/(pos+neg+neu)}'
  print(Fore.CYAN+ text)
  print(Fore.GREEN+ "----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
  print(prob)
  return prob

# %%
text1_prob = text_sentiment_prob(text_1, pos_text1, neg_text1, neu_text1)
# Out:
# Hola camaradas, solo quería compartir mi historia después de una operación en la que marqué otro gol contra el cáncer y lo puse 3-0. Espero que pueda inspirar a alguien por ahí.
#
# Fui diagnosticado con cáncer de colon en mayo de 2020, cuando tuve una hemorragia importante. Antes de darme cuenta, los cirujanos me extirparon 30 cm de colon. La recuperación fue dura, pero manejable. Lo bueno es que, aunque el tumor era grande, los ganglios linfáticos estaban limpios, colocándome en estadio 2. Según los médicos, estaba libre y era uno de los afortunados que podía dejar el cáncer atrás y contar la historia en un bar. El marcador era 1-0 para mí.
#
# Sin embargo, más tarde aprendí por las malas que esta mierda también puede viajar por la sangre. En enero de 2021, mi escáner de rutina mostró noticias desagradables. Tenía varias lesiones en el hígado y mi mundo colapsó cuando el cirujano me dijo que era inoperable. Ahora era un estadio 4 de cáncer de colon con metástasis hepática inoperable y dos niños pequeños de 3 y 5 años que no podía dejar sin padre.
#
# Esto fue durante los días de confinamiento por coronavirus, y mi familia e hijos no podían acompañarme todo el tiempo en el hospital por las restricciones.
#
# Sin embargo, no soy de rendirme, y lo asumí como un nuevo reto que debía superar. Con pocas probabilidades al inicio, después de 1,5 años de quimioterapia y radioterapia que me patearon el trasero, no necesité ni siquiera una operación de hígado. El marcador iba 2-0 y cruzábamos los dedos para que no volviera nunca.
#
# No volvió, pero un cáncer completamente distinto sería mi nuevo reto. Los médicos sospecharon algo en mi tiroides durante otro escáner de rutina. Tras pruebas y biopsias con aguja, resultó que ahora tengo cáncer de tiroides. Pensé: “meh, este es fácil”.
#
# Ayer me extirparon toda la tiroides en una operación. El tumor ya medía 2 cm. Ahora estamos 3-0. No sé qué me espera, pero sea lo que sea, lo enfrentaré y lo combatiré. Mientras tanto, recibiré quimioterapia preventiva cada 6 meses y seguiré disfrutando de criar a mis hijos.
#
# Así que, camarada, considera lo tuyo como un reto también. Tienes la fuerza y el optimismo para enfrentarlo, no importa lo dura que sea la vida. Mantén la cabeza en alto y sigue anotando.
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# positive=0.16129032258064516, negative=0.0, neutral=0.8387096774193549
