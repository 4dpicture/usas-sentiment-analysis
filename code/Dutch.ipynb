# %% [markdown]
# ---
# # **DUTCH**
# ---

# %% [markdown]
# ### **STEP 1: Downloading and installing the dependencies:**
# >>**English PyMUSAS RuleBasedTagger**
#
# >>**English spaCy pipeline**
#
# >>**colorama:** *Colorama is a Python module that displays colored output in consoles.*
# ---

# %%
# !pip install https://github.com/UCREL/pymusas-models/releases/download/nl_single_upos2usas_contextual-0.3.3/nl_single_upos2usas_contextual-0.3.3-py3-none-any.whl
# !python -m spacy download nl_core_news_sm
# Out:
# Collecting nl-single-upos2usas-contextual==0.3.3
#   Downloading https://github.com/UCREL/pymusas-models/releases/download/nl_single_upos2usas_contextual-0.3.3/nl_single_upos2usas_contextual-0.3.3-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<4.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from nl-single-upos2usas-contextual==0.3.3) (3.8.7)
# Collecting pymusas<0.4.0,>=0.3.0 (from nl-single-upos2usas-contextual==0.3.3)
#   Downloading pymusas-0.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from pymusas<0.4.0,>=0.3.0->nl-single-upos2usas-contextual==0.3.3) (2.5.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.50.0 in /usr/local/lib/python3.11/dist-packages (from pymusas<0.4.0,>=0.3.0->nl-single-upos2usas-contextual==0.3.3) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from pymusas<0.4.0,>=0.3.0->nl-single-upos2usas-contextual==0.3.3) (2.32.3)
# Collecting click<8.1.0 (from pymusas<0.4.0,>=0.3.0->nl-single-upos2usas-contextual==0.3.3)
#   Downloading click-8.0.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (1.1.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (0.16.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (2.0.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (2.11.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->pymusas<0.4.0,>=0.3.0->nl-single-upos2usas-contextual==0.3.3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->pymusas<0.4.0,>=0.3.0->nl-single-upos2usas-contextual==0.3.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->pymusas<0.4.0,>=0.3.0->nl-single-upos2usas-contextual==0.3.3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->pymusas<0.4.0,>=0.3.0->nl-single-upos2usas-contextual==0.3.3) (2025.6.15)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->nl-single-upos2usas-contextual==0.3.3) (0.1.2)
# Downloading pymusas-0.3.0-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 3.8 MB/s eta 0:00:00
# Downloading click-8.0.4-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: click, pymusas, nl-single-upos2usas-contextual
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 3.1.1 requires click>=8.1.3, but you have click 8.0.4 which is incompatible.
# dask 2024.12.1 requires click>=8.1, but you have click 8.0.4 which is incompatible.
# dask-cuda 25.2.0 requires click>=8.1, but you have click 8.0.4 which is incompatible.
# Successfully installed click-8.0.4 nl-single-upos2usas-contextual-0.3.3 pymusas-0.3.0
# Collecting nl-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/nl_core_news_sm-3.8.0/nl_core_news_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 95.5 MB/s eta 0:00:00
# Installing collected packages: nl-core-news-sm
# Successfully installed nl-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('nl_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !pip install colorama
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %% [markdown]
# ---
# ### **STEP 2: Creating the tagger**
#
# ---

# %%
import spacy

# We exclude the following components as we do not need them.
nlp = spacy.load('nl_core_news_sm', exclude=['parser', 'ner', 'tagger'])
# Load the Dutch PyMUSAS rule-based tagger in a separate spaCy pipeline
dutch_tagger_pipeline = spacy.load('nl_single_upos2usas_contextual')
# Adds the Dutch PyMUSAS rule-based tagger to the main spaCy pipeline
nlp.add_pipe('pymusas_rule_based_tagger', source=dutch_tagger_pipeline)

# %% [markdown]
# ---
#
# ### **STEP 3: Importing the libraries**
#
# ---

# %%
import re
import pandas as pd
import numpy as np
from colorama import Fore, Back, Style

import nltk
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %% [markdown]
# ---
# ### **STEP 4: Tagging text:** *tag_text function*
#
# >>**input:** piece of text
#
# >>**output:** python dictionary where *keys* represent the index of a sentence in the input text and *values* represent the usas semantic tags for that sentence
#
# ---

# %%
# Defining the tagging function
def tag_text(text):
  usas_eval_tags = {}
  usas_list = {}
  sentences = nltk.sent_tokenize(text)
  for i in range(len(sentences)):
    if(sentences[i]):
      print(Fore.GREEN + Style.BRIGHT + "------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
      print(Fore.CYAN + Style.BRIGHT + f"Sentence {i}:", sentences[i])
      print(Fore.CYAN + Style.BRIGHT + "------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
      sent = nlp(sentences[i])
      for token in sent:
        tags = token._.pymusas_tags
        print(Fore.CYAN + f'{token.text}:' + Fore.GREEN, tags)
        for tag in tags:
          usas_list[token.text] = token._.pymusas_tags
      usas_eval_tags[i] = usas_list
  return usas_eval_tags

# %%
# Input text 1
text_1 = """

Hallo kameraden, ik wil met jullie mijn ervaring delen over hoe ik na een operatie tegen kanker opnieuw een doelpunt scoorde en de stand op 3–0 bracht. Ik hoop dat dit verhaal iemand daarbuiten zal inspireren.

In mei 2020 kreeg ik de diagnose darmkanker toen ik ernstige bloedingen had, je weet wel waar. Voordat ik het doorhad, hadden de chirurgen al 30 cm van mijn dikke darm verwijderd. Het herstel was zwaar, maar te doen. Het goede nieuws was dat, ook al was mijn tumor groot, de lymfeklieren schoon waren, waardoor ik in stadium 2 zat. Volgens de artsen was ik schoon, en één van de gelukkigen die kanker nu achter zich had met een mooi verhaal om in de kroeg te vertellen. De stand was 1–0 in mijn voordeel.

Maar later leerde ik op de harde manier dat deze rotzooi ook via de bloedbaan kan reizen. In januari 2021 liet mijn routine-scan niet zulk goed nieuws zien. Ik had meerdere laesies in mijn lever, en toen de chirurg zei dat deze niet te opereren waren, stortte mijn wereld in. Ik had nu stadium 4 darmkanker met niet-operabele levermetastasen, en thuis had ik twee zoontjes van 3 en 5, die ik niet zonder vader wilde achterlaten.

Dit gebeurde allemaal tijdens de coronapandemie, toen mijn familie en kinderen door ziekenhuisbeperkingen niet altijd bij me konden zijn.

Toch ben ik geen opgever, en ik zag dit als een nieuwe uitdaging die ik moest overwinnen. Met lage overlevingskansen begon ik aan anderhalf jaar chemo- en radiotherapie, die me flink op mijn donder gaven, maar ervoor zorgden dat ik kankervrij werd. Ik had niet eens een leveroperatie nodig. De stand was nu 2–0, en we hoopten allemaal dat deze niet zou terugkeren.

Het kwam inderdaad niet terug, maar nu kreeg ik te maken met iets compleet nieuws. Bij een routineonderzoek verdachten de dokters iets in mijn schildklier. Na extra scans en een naaldbiopsie kreeg ik te horen dat ik schildklierkanker had. Ik dacht bij mezelf: “Ach, deze is gemakkelijk te tackelen.”

Gisteren is mijn hele schildklier verwijderd. De tumor was al 2 cm groot.

De stand staat nu op 3–0. Ik weet niet wat me hierna te wachten staat, maar wat er ook komt, ik zal tegen deze rotziekte blijven vechten. In de tussentijd krijg ik iedere zes maanden preventieve chemotherapie en geniet ik ervan samen met mijn kinderen te zijn.

Dus, kameraad, zie jouw situatie ook als een uitdaging. Wat het leven je ook brengt, je hebt de kracht en het optimisme in je om door te zetten. Houd je hoofd omhoog en blijf scoren! """

# %%
# Tagging input text 1
text1_tags = tag_text(text_1)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 0:
#
# Hallo kameraden, ik wil met jullie mijn ervaring delen over hoe ik na een operatie tegen kanker opnieuw een doelpunt scoorde en de stand op 3–0 bracht.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# : ['Z99']
# Hallo: ['S1.1.1', 'Z4']
# kameraden: ['S3.1/S2mf']
# ,: ['PUNCT']
# ik: ['Z8mf']
# wil: ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-']
# met: ['Z5']
# jullie: ['Z8mf']
# mijn: ['Z8']
# ervaring: ['A2.1+/A3+', 'X3', 'X2.2+', 'X9.1+', 'I3.2']
# delen: ['S1.1.2+']
# over: ['Z99']
# hoe: ['Z5', 'A13.3']
# ik: ['Z8mf']
# na: ['N4', 'Z5']
# een: ['Z5']
# operatie: ['A1.1.1', 'B3', 'G3']
# tegen: ['A5.1-', 'S8-', 'Z5']
# kanker: ['B2-']
# opnieuw: ['N6+', 'Z4']
# een: ['Z5']
# doelpunt: ['K5.1', 'X7+']
# scoorde: ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1']
# en: ['Z5']
# de: ['Z5']
# stand: ['Z99']
# op: ['A5.1+', 'G2.2+', 'A1.1.1', 'M6', 'Z5']
# 3–0: ['N1']
# bracht: ['M2', 'A2.2']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 1: Ik hoop dat dit verhaal iemand daarbuiten zal inspireren.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Ik: ['Z8mf']
# hoop: ['X2.6+', 'E4.1+', 'X9.2+', 'A5.1+']
# dat: ['A13.3', 'A6.1+', 'Z5', 'Z8']
# dit: ['A13.3', 'M6', 'Z5', 'Z8']
# verhaal: ['Q2.1', 'X4.1', 'Q4']
# iemand: ['Z8mfc']
# daarbuiten: ['M6', 'S1.1.3-', 'S5-', 'Z5']
# zal: ['T1.1.3', 'X7+', 'G2.1/Q1.2']
# inspireren: ['S8+']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 2: In mei 2020 kreeg ik de diagnose darmkanker toen ik ernstige bloedingen had, je weet wel waar.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# In: ['M6', 'O4.2+', 'Z5']
# mei: ['T1.3', 'Z1f']
# 2020: ['N1']
# kreeg: ['A9+', 'Z5', 'X9.2+', 'A2.1+', 'A2.2', 'M1', 'M2', 'X2.5+', 'E4.1-']
# ik: ['Z8mf']
# de: ['Z5']
# diagnose: ['B3', 'X4.1']
# darmkanker: ['Z99']
# toen: ['Z5']
# ik: ['Z8mf']
# ernstige: ['A11.1+', 'A15-', 'E4.1-']
# bloedingen: ['Z99']
# had: ['A9+', 'Z5', 'A2.2', 'S4']
# ,: ['PUNCT']
# je: ['Z8mf']
# weet: ['X2.2+', 'S3.2/B1%']
# wel: ['Z99']
# waar: ['A5.2+', 'A5.4+']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 3: Voordat ik het doorhad, hadden de chirurgen al 30 cm van mijn dikke darm verwijderd.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Voordat: ['N4', 'Z5']
# ik: ['Z8mf']
# het: ['Z99']
# doorhad: ['Z99']
# ,: ['PUNCT']
# hadden: ['A9+', 'Z5', 'A2.2', 'S4']
# de: ['Z5']
# chirurgen: ['Z99']
# al: ['T1.1.1']
# 30: ['N1']
# cm: ['N3.7', 'N3.3']
# van: ['Z5']
# mijn: ['Z8']
# dikke: ['N3.7', 'O4.5', 'N3.7+', 'N3.2+', 'N5+', 'X9.1-', 'A10-', 'A11.2+', 'O4.3@', 'O4.2-@']
# darm: ['Z99']
# verwijderd: ['M2']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 4: Het herstel was zwaar, maar te doen.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Het: ['Z99']
# herstel: ['B2+', 'A5.1+/A2.1', 'A9+']
# was: ['A3+', 'Z5']
# zwaar: ['N3.5+', 'N5+', 'S1.2.5+', 'O4.1', 'E4.1-', 'W4', 'A12-', 'A1.1.1', 'N3.2+', 'A1.1.2@', 'S1.2.5+/S2mf']
# ,: ['PUNCT']
# maar: ['A13.6', 'Z5']
# te: ['Z99']
# doen: ['A1.1.1', 'G2.2-', 'X9.2+', 'E3-', 'N5+', 'G2.1%', 'Z5']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 5: Het goede nieuws was dat, ook al was mijn tumor groot, de lymfeklieren schoon waren, waardoor ik in stadium 2 zat.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Het: ['Z99']
# goede: ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+']
# nieuws: ['X2.2+/T3-', 'X2.2+/Q4.2', 'X2.2+/Q4.3']
# was: ['A3+', 'Z5']
# dat: ['A13.3', 'A6.1+', 'Z5', 'Z8']
# ,: ['PUNCT']
# ook: ['N5++']
# al: ['A13.2', 'N5.1+']
# was: ['A3+', 'Z5']
# mijn: ['Z8']
# tumor: ['Z99']
# groot: ['Z99']
# ,: ['PUNCT']
# de: ['Z5']
# lymfeklieren: ['Z99']
# schoon: ['B4', 'O4.2+', 'G2.2+']
# waren: ['A3+', 'Z5']
# ,: ['PUNCT']
# waardoor: ['Z99']
# ik: ['Z8mf']
# in: ['M6', 'O4.2+', 'Z5']
# stadium: ['K4', 'A1.1.1', 'A5.4-', 'T1.2', 'N5.1-', 'H2/K4', 'A4.1']
# 2: ['N1']
# zat: ['M8', 'C1', 'P1', 'G1.1', 'G2.1', 'M6', 'A9+']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 6: Volgens de artsen was ik schoon, en één van de gelukkigen die kanker nu achter zich had met een mooi verhaal om in de kroeg te vertellen.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Volgens: ['Z99']
# de: ['Z5']
# artsen: ['B3/S2mf']
# was: ['A3+', 'Z5']
# ik: ['Z8mf']
# schoon: ['B4', 'O4.2+', 'G2.2+']
# ,: ['PUNCT']
# en: ['Z5']
# één: ['N1', 'T3', 'T1.2', 'Z8']
# van: ['Z5']
# de: ['Z5']
# gelukkigen: ['E4.1+', 'E4.2+']
# die: ['Z99']
# kanker: ['B2-']
# nu: ['T1.1.2', 'Z4', 'Z5']
# achter: ['B1', 'M6', 'A6.1-', 'Z5']
# zich: ['Z99']
# had: ['A9+', 'Z5', 'A2.2', 'S4']
# met: ['Z5']
# een: ['Z5']
# mooi: ['O4.2+', 'S1.2.1+']
# verhaal: ['Q2.1', 'X4.1', 'Q4']
# om: ['Z99']
# in: ['M6', 'O4.2+', 'Z5']
# de: ['Z5']
# kroeg: ['F2', 'F2/H1']
# te: ['Z99']
# vertellen: ['Q2.2', 'Q2.1', 'X3', 'A10+']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 7: De stand was 1–0 in mijn voordeel.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# De: ['Z5']
# stand: ['Z99']
# was: ['A3+', 'Z5']
# 1–0: ['Z99']
# in: ['M6', 'O4.2+', 'Z5']
# mijn: ['Z8']
# voordeel: ['A5.1+', 'K5.2']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 8: Maar later leerde ik op de harde manier dat deze rotzooi ook via de bloedbaan kan reizen.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Maar: ['A13.6', 'Z5']
# later: ['T4-', 'L1-', 'T1.1']
# leerde: ['X2.3+', 'P1']
# ik: ['Z8mf']
# op: ['A5.1+', 'G2.2+', 'A1.1.1', 'M6', 'Z5']
# de: ['Z5']
# harde: ['O4.1', 'X8+', 'X5.2+', 'N5+', 'A12-', 'O4.5', 'S1.2.5+']
# manier: ['A13.3', 'X4.2', 'M6', 'M3/H3', 'N3.3', 'A4.1', 'A1.1.1', 'T1.3']
# dat: ['A13.3', 'A6.1+', 'Z5', 'Z8']
# deze: ['Z99']
# rotzooi: ['Z99']
# ook: ['N5++']
# via: ['M6', 'Z5']
# de: ['Z5']
# bloedbaan: ['Z99']
# kan: ['Z99']
# reizen: ['M1']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 9: In januari 2021 liet mijn routine-scan niet zulk goed nieuws zien.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# In: ['M6', 'O4.2+', 'Z5']
# januari: ['T1.3']
# 2021: ['N1']
# liet: ['S7.4+', 'I2.2/H1', 'T2-']
# mijn: ['Z8']
# routine-scan: ['Z99']
# niet: ['Z6']
# zulk: ['Z5', 'Z8']
# goed: ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+']
# nieuws: ['X2.2+/T3-', 'X2.2+/Q4.2', 'X2.2+/Q4.3']
# zien: ['X3.4', 'X2.1', 'S1.1.1', 'X2.5+', 'X2.3+', 'X3', 'A7+', 'Z4', 'S3.2']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 10: Ik had meerdere laesies in mijn lever, en toen de chirurg zei dat deze niet te opereren waren, stortte mijn wereld in.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Ik: ['Z8mf']
# had: ['A9+', 'Z5', 'A2.2', 'S4']
# meerdere: ['Z99']
# laesies: ['Z99']
# in: ['M6', 'O4.2+', 'Z5']
# mijn: ['Z8']
# lever: ['Z99']
# ,: ['PUNCT']
# en: ['Z5']
# toen: ['Z5']
# de: ['Z5']
# chirurg: ['Z99']
# zei: ['Q2.1', 'Z4%']
# dat: ['A13.3', 'A6.1+', 'Z5', 'Z8']
# deze: ['Z99']
# niet: ['Z6']
# te: ['Z99']
# opereren: ['A1.1.1', 'B3']
# waren: ['A3+', 'Z5']
# ,: ['PUNCT']
# stortte: ['Z99']
# mijn: ['Z8']
# wereld: ['W1', 'S5+c', 'A4.1', 'N5+']
# in: ['M6', 'O4.2+', 'Z5']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 11: Ik had nu stadium 4 darmkanker met niet-operabele levermetastasen, en thuis had ik twee zoontjes van 3 en 5, die ik niet zonder vader wilde achterlaten.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Ik: ['Z8mf']
# had: ['A9+', 'Z5', 'A2.2', 'S4']
# nu: ['T1.1.2', 'Z4', 'Z5']
# stadium: ['K4', 'A1.1.1', 'A5.4-', 'T1.2', 'N5.1-', 'H2/K4', 'A4.1']
# 4: ['N1']
# darmkanker: ['Z99']
# met: ['Z5']
# niet-operabele: ['Z99']
# levermetastasen: ['Z99']
# ,: ['PUNCT']
# en: ['Z5']
# thuis: ['Z99']
# had: ['A9+', 'Z5', 'A2.2', 'S4']
# ik: ['Z8mf']
# twee: ['N1', 'T3', 'T1.2']
# zoontjes: ['Z99']
# van: ['Z5']
# 3: ['N1']
# en: ['Z5']
# 5: ['N1']
# ,: ['PUNCT']
# die: ['Z99']
# ik: ['Z8mf']
# niet: ['Z6']
# zonder: ['M6', 'Z5']
# vader: ['S4/B1', 'S4m', 'S9/S2.2m']
# wilde: ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-']
# achterlaten: ['M1', 'M2', 'A1.1.1', 'A1.9', 'A9-', 'T2-']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 12: Dit gebeurde allemaal tijdens de coronapandemie, toen mijn familie en kinderen door ziekenhuisbeperkingen niet altijd bij me konden zijn.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Dit: ['A13.3', 'M6', 'Z5', 'Z8']
# gebeurde: ['A2.1+', 'A3+', 'X7-']
# allemaal: ['Z8/N5.1+']
# tijdens: ['Z5']
# de: ['Z5']
# coronapandemie: ['Z99']
# ,: ['PUNCT']
# toen: ['Z5']
# mijn: ['Z8']
# familie: ['S4c', 'A4.1c']
# en: ['Z5']
# kinderen: ['S2mf/T3-', 'S4mf']
# door: ['M6', 'Z5']
# ziekenhuisbeperkingen: ['Z99']
# niet: ['Z6']
# altijd: ['N6+++']
# bij: ['Z99']
# me: ['Z8mf']
# konden: ['Z99']
# zijn: ['A3+', 'Z5']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 13: Toch ben ik geen opgever, en ik zag dit als een nieuwe uitdaging die ik moest overwinnen.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Toch: ['T1.1.2', 'Z5']
# ben: ['A3+', 'Z5']
# ik: ['Z8mf']
# geen: ['S8-', 'Z4', 'Z6']
# opgever: ['Z99']
# ,: ['PUNCT']
# en: ['Z5']
# ik: ['Z8mf']
# zag: ['X3.4', 'X2.1', 'S1.1.1', 'X2.5+', 'X2.3+', 'X3', 'A7+', 'Z4', 'S3.2']
# dit: ['A13.3', 'M6', 'Z5', 'Z8']
# als: ['Z5']
# een: ['Z5']
# nieuwe: ['T3-']
# uitdaging: ['A12-', 'A6.1-', 'S7.3+', 'E3-', 'Q2.2']
# die: ['Z99']
# ik: ['Z8mf']
# moest: ['Z99']
# overwinnen: ['X9.2+/S7.3', 'X9.2+/G3', 'A2.2/E1', 'B2-']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 14: Met lage overlevingskansen begon ik aan anderhalf jaar chemo- en radiotherapie, die me flink op mijn donder gaven, maar ervoor zorgden dat ik kankervrij werd.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Met: ['Z5']
# lage: ['A5.1-', 'L2/Q2.1', 'N3.7-', 'N5-', 'A11.1-', 'E4.1-', 'X3.2-', 'G2.2-', 'S7.1-']
# overlevingskansen: ['Z99']
# begon: ['T2+', 'E5-', 'E3-']
# ik: ['Z8mf']
# aan: ['Z99']
# anderhalf: ['Z99']
# jaar: ['T1.3', 'P1c']
# chemo-: ['Z99']
# en: ['Z5']
# radiotherapie: ['Z99']
# ,: ['PUNCT']
# die: ['Z99']
# me: ['Z8mf']
# flink: ['A11.1+', 'N5+']
# op: ['A5.1+', 'G2.2+', 'A1.1.1', 'M6', 'Z5']
# mijn: ['Z8']
# donder: ['Z99']
# gaven: ['A9-', 'A1.1.1']
# ,: ['PUNCT']
# maar: ['A13.6', 'Z5']
# ervoor: ['Z99']
# zorgden: ['A9-', 'S6+']
# dat: ['A13.3', 'A6.1+', 'Z5', 'Z8']
# ik: ['Z8mf']
# kankervrij: ['Z99']
# werd: ['A3+', 'Z5']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 15: Ik had niet eens een leveroperatie nodig.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Ik: ['Z8mf']
# had: ['A9+', 'Z5', 'A2.2', 'S4']
# niet: ['Z6']
# eens: ['A13.1', 'A6.1+', 'O4.4', 'A1.4', 'N1', 'T1.3', 'Z5']
# een: ['Z5']
# leveroperatie: ['Z99']
# nodig: ['S6+', 'A11.1+']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 16: De stand was nu 2–0, en we hoopten allemaal dat deze niet zou terugkeren.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# De: ['Z5']
# stand: ['Z99']
# was: ['A3+', 'Z5']
# nu: ['T1.1.2', 'Z4', 'Z5']
# 2–0: ['Z99']
# ,: ['PUNCT']
# en: ['Z5']
# we: ['Z8']
# hoopten: ['Z99']
# allemaal: ['Z8/N5.1+']
# dat: ['A13.3', 'A6.1+', 'Z5', 'Z8']
# deze: ['Z99']
# niet: ['Z6']
# zou: ['T1.1.3', 'X7+', 'G2.1/Q1.2']
# terugkeren: ['M1', 'A9-', 'N6']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 17: Het kwam inderdaad niet terug, maar nu kreeg ik te maken met iets compleet nieuws.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Het: ['Z99']
# kwam: ['M1', 'N3.1', 'A2.2', 'A3+', 'X2.1', 'A9+', 'S4', 'N4', 'S3.2', 'T1', 'A1.1.1', 'N5']
# inderdaad: ['A13.3']
# niet: ['Z6']
# terug: ['B1', 'M6', 'N6+', 'T1.1.1', 'S1.1.2+', 'T3+', 'S8+', 'K5.1/I1', 'M1', 'K2']
# ,: ['PUNCT']
# maar: ['A13.6', 'Z5']
# nu: ['T1.1.2', 'Z4', 'Z5']
# kreeg: ['A9+', 'Z5', 'X9.2+', 'A2.1+', 'A2.2', 'M1', 'M2', 'X2.5+', 'E4.1-']
# ik: ['Z8mf']
# te: ['Z99']
# maken: ['Z99']
# met: ['Z5']
# iets: ['Z8']
# compleet: ['N5.1+', 'T2-', 'N3.2+', 'Q1.2']
# nieuws: ['X2.2+/T3-', 'X2.2+/Q4.2', 'X2.2+/Q4.3']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 18: Bij een routineonderzoek verdachten de dokters iets in mijn schildklier.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bij: ['Z99']
# een: ['Z5']
# routineonderzoek: ['Z99']
# verdachten: ['Z99']
# de: ['Z5']
# dokters: ['Z99']
# iets: ['Z8']
# in: ['M6', 'O4.2+', 'Z5']
# mijn: ['Z8']
# schildklier: ['Z99']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 19: Na extra scans en een naaldbiopsie kreeg ik te horen dat ik schildklierkanker had.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Na: ['N4', 'Z5']
# extra: ['N5++']
# scans: ['Z99']
# en: ['Z5']
# een: ['Z5']
# naaldbiopsie: ['Z99']
# kreeg: ['A9+', 'Z5', 'X9.2+', 'A2.1+', 'A2.2', 'M1', 'M2', 'X2.5+', 'E4.1-']
# ik: ['Z8mf']
# te: ['Z99']
# horen: ['X3.2', 'X2.3+', 'G2.1@']
# dat: ['A13.3', 'A6.1+', 'Z5', 'Z8']
# ik: ['Z8mf']
# schildklierkanker: ['Z99']
# had: ['A9+', 'Z5', 'A2.2', 'S4']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 20: Ik dacht bij mezelf: “Ach, deze is gemakkelijk te tackelen.”
#
# Gisteren is mijn hele schildklier verwijderd.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Ik: ['Z8mf']
# dacht: ['X2.1']
# bij: ['Z99']
# mezelf: ['Z8mf']
# :: ['PUNCT']
# “: ['N1']
# Ach: ['Z4']
# ,: ['PUNCT']
# deze: ['Z99']
# is: ['A3+', 'Z5']
# gemakkelijk: ['A12+']
# te: ['Z99']
# tackelen: ['Z99']
# .: ['PUNCT']
# ”: ['Z99']
#
#
# : ['Z99']
# Gisteren: ['T1.1.1']
# is: ['A3+', 'Z5']
# mijn: ['Z8']
# hele: ['N5.1+']
# schildklier: ['Z99']
# verwijderd: ['M2']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 21: De tumor was al 2 cm groot.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# De: ['Z5']
# tumor: ['Z99']
# was: ['A3+', 'Z5']
# al: ['T1.1.1']
# 2: ['N1']
# cm: ['N3.7', 'N3.3']
# groot: ['Z99']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 22: De stand staat nu op 3–0.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# De: ['Z5']
# stand: ['Z99']
# staat: ['M6', 'M2', 'M8', 'M1', 'T2++', 'N3', 'A3+', 'X2.1', 'A7', 'G1.2', 'S8+', 'S7.4+', 'I2.2', 'S1.2.5+']
# nu: ['T1.1.2', 'Z4', 'Z5']
# op: ['A5.1+', 'G2.2+', 'A1.1.1', 'M6', 'Z5']
# 3–0: ['N1']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 23: Ik weet niet wat me hierna te wachten staat, maar wat er ook komt, ik zal tegen deze rotziekte blijven vechten.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Ik: ['Z8mf']
# weet: ['X2.2+', 'S3.2/B1%']
# niet: ['Z6']
# wat: ['Z8', 'Z5']
# me: ['Z8mf']
# hierna: ['Z99']
# te: ['Z99']
# wachten: ['T1.3', 'A3+', 'A11.1+', 'S1.1.1%']
# staat: ['M6', 'M2', 'M8', 'M1', 'T2++', 'N3', 'A3+', 'X2.1', 'A7', 'G1.2', 'S8+', 'S7.4+', 'I2.2', 'S1.2.5+']
# ,: ['PUNCT']
# maar: ['A13.6', 'Z5']
# wat: ['Z8', 'Z5']
# er: ['M6', 'T1.2', 'Z5']
# ook: ['N5++']
# komt: ['M1', 'N3.1', 'A2.2', 'A3+', 'X2.1', 'A9+', 'S4', 'N4', 'S3.2', 'T1', 'A1.1.1', 'N5']
# ,: ['PUNCT']
# ik: ['Z8mf']
# zal: ['T1.1.3', 'X7+', 'G2.1/Q1.2']
# tegen: ['A5.1-', 'S8-', 'Z5']
# deze: ['Z99']
# rotziekte: ['Z99']
# blijven: ['T2++', 'M8', 'N5.2+']
# vechten: ['S8-', 'X8+', 'E3-', 'G1.2']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 24: In de tussentijd krijg ik iedere zes maanden preventieve chemotherapie en geniet ik ervan samen met mijn kinderen te zijn.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# In: ['M6', 'O4.2+', 'Z5']
# de: ['Z5']
# tussentijd: ['Z99']
# krijg: ['A9+', 'Z5', 'X9.2+', 'A2.1+', 'A2.2', 'M1', 'M2', 'X2.5+', 'E4.1-']
# ik: ['Z8mf']
# iedere: ['N5.1+', 'S1.1.2+']
# zes: ['N1', 'T3', 'T1.2']
# maanden: ['T1.3']
# preventieve: ['Z99']
# chemotherapie: ['Z99']
# en: ['Z5']
# geniet: ['E2+', 'A9+', 'E4.1+']
# ik: ['Z8mf']
# ervan: ['Z99']
# samen: ['Z99']
# met: ['Z5']
# mijn: ['Z8']
# kinderen: ['S2mf/T3-', 'S4mf']
# te: ['Z99']
# zijn: ['A3+', 'Z5']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 25: Dus, kameraad, zie jouw situatie ook als een uitdaging.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Dus: ['A13.3', 'Z5']
# ,: ['PUNCT']
# kameraad: ['S3.1/S2mf']
# ,: ['PUNCT']
# zie: ['X3.4', 'X2.1', 'S1.1.1', 'X2.5+', 'X2.3+', 'X3', 'A7+', 'Z4', 'S3.2']
# jouw: ['Z8']
# situatie: ['A3+', 'O4.1', 'M6', 'I3.1@']
# ook: ['N5++']
# als: ['Z5']
# een: ['Z5']
# uitdaging: ['A12-', 'A6.1-', 'S7.3+', 'E3-', 'Q2.2']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 26: Wat het leven je ook brengt, je hebt de kracht en het optimisme in je om door te zetten.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Wat: ['Z8', 'Z5']
# het: ['Z99']
# leven: ['L1+', 'A3+', 'T1.3', 'S1.1.1', 'A1.1.1', 'X5.2+', 'Q4.1', 'A11.1+++', 'A5.4+/C1']
# je: ['Z8mf']
# ook: ['N5++']
# brengt: ['M2', 'A2.2']
# ,: ['PUNCT']
# je: ['Z8mf']
# hebt: ['A9+', 'Z5', 'A2.2', 'S4']
# de: ['Z5']
# kracht: ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2@']
# en: ['Z5']
# het: ['Z99']
# optimisme: ['Z99']
# in: ['M6', 'O4.2+', 'Z5']
# je: ['Z8mf']
# om: ['Z99']
# door: ['M6', 'Z5']
# te: ['Z99']
# zetten: ['M2', 'Q2.1', 'Q2.2', 'A1.1.1']
# .: ['PUNCT']
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 27: Houd je hoofd omhoog en blijf scoren!
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Houd: ['Z99']
# je: ['Z8mf']
# hoofd: ['B1', 'S7.1+/S2mf', 'P1/S2mf', 'X1', 'M6', 'A4.1', 'S2mf', 'F2', 'H5/M4%', 'S7.1+', 'K5.1', 'M1', 'N5', 'A2.1+', 'A11.1+', 'Q1.2', 'T1.1.3']
# omhoog: ['M6', 'N4', 'N5++', 'T2-', 'X9.1+', 'A1.1.1', 'N5+/A2.1', 'Z5']
# en: ['Z5']
# blijf: ['Z99']
# scoren: ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1']
# !: ['PUNCT']

# %%
# Output tags text 1
text1_tags
# Out:
# {0: {'\n\n': ['Z99'],
#   'Hallo': ['S1.1.1', 'Z4'],
#   'kameraden': ['S3.1/S2mf'],
#   ',': ['PUNCT'],
#   'ik': ['Z8mf'],
#   'wil': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'met': ['Z5'],
#   'jullie': ['Z8mf'],
#   'mijn': ['Z8'],
#   'ervaring': ['A2.1+/A3+', 'X3', 'X2.2+', 'X9.1+', 'I3.2'],
#   'delen': ['S1.1.2+'],
#   'over': ['Z99'],
#   'hoe': ['Z5', 'A13.3'],
#   'na': ['N4', 'Z5'],
#   'een': ['Z5'],
#   'operatie': ['A1.1.1', 'B3', 'G3'],
#   'tegen': ['A5.1-', 'S8-', 'Z5'],
#   'kanker': ['B2-'],
#   'opnieuw': ['N6+', 'Z4'],
#   'doelpunt': ['K5.1', 'X7+'],
#   'scoorde': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   'en': ['Z5'],
#   'de': ['Z5'],
#   'stand': ['Z99'],
#   'op': ['A5.1+', 'G2.2+', 'A1.1.1', 'M6', 'Z5'],
#   '3–0': ['N1'],
#   'bracht': ['M2', 'A2.2'],
#   '.': ['PUNCT'],
#   'Ik': ['Z8mf'],
#   'hoop': ['X2.6+', 'E4.1+', 'X9.2+', 'A5.1+'],
#   'dat': ['A13.3', 'A6.1+', 'Z5', 'Z8'],
#   'dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'verhaal': ['Q2.1', 'X4.1', 'Q4'],
#   'iemand': ['Z8mfc'],
#   'daarbuiten': ['M6', 'S1.1.3-', 'S5-', 'Z5'],
#   'zal': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'inspireren': ['S8+'],
#   'In': ['M6', 'O4.2+', 'Z5'],
#   'mei': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'kreeg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'diagnose': ['B3', 'X4.1'],
#   'darmkanker': ['Z99'],
#   'toen': ['Z5'],
#   'ernstige': ['A11.1+', 'A15-', 'E4.1-'],
#   'bloedingen': ['Z99'],
#   'had': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'je': ['Z8mf'],
#   'weet': ['X2.2+', 'S3.2/B1%'],
#   'wel': ['Z99'],
#   'waar': ['A5.2+', 'A5.4+'],
#   'Voordat': ['N4', 'Z5'],
#   'het': ['Z99'],
#   'doorhad': ['Z99'],
#   'hadden': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'chirurgen': ['Z99'],
#   'al': ['T1.1.1'],
#   '30': ['N1'],
#   'cm': ['N3.7', 'N3.3'],
#   'van': ['Z5'],
#   'dikke': ['N3.7',
#    'O4.5',
#    'N3.7+',
#    'N3.2+',
#    'N5+',
#    'X9.1-',
#    'A10-',
#    'A11.2+',
#    'O4.3@',
#    'O4.2-@'],
#   'darm': ['Z99'],
#   'verwijderd': ['M2'],
#   'Het': ['Z99'],
#   'herstel': ['B2+', 'A5.1+/A2.1', 'A9+'],
#   'was': ['A3+', 'Z5'],
#   'zwaar': ['N3.5+',
#    'N5+',
#    'S1.2.5+',
#    'O4.1',
#    'E4.1-',
#    'W4',
#    'A12-',
#    'A1.1.1',
#    'N3.2+',
#    'A1.1.2@',
#    'S1.2.5+/S2mf'],
#   'maar': ['A13.6', 'Z5'],
#   'te': ['Z99'],
#   'doen': ['A1.1.1', 'G2.2-', 'X9.2+', 'E3-', 'N5+', 'G2.1%', 'Z5'],
#   'goede': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'nieuws': ['X2.2+/T3-', 'X2.2+/Q4.2', 'X2.2+/Q4.3'],
#   'ook': ['N5++'],
#   'tumor': ['Z99'],
#   'groot': ['Z99'],
#   'lymfeklieren': ['Z99'],
#   'schoon': ['B4', 'O4.2+', 'G2.2+'],
#   'waren': ['A3+', 'Z5'],
#   'waardoor': ['Z99'],
#   'in': ['M6', 'O4.2+', 'Z5'],
#   'stadium': ['K4', 'A1.1.1', 'A5.4-', 'T1.2', 'N5.1-', 'H2/K4', 'A4.1'],
#   '2': ['N1'],
#   'zat': ['M8', 'C1', 'P1', 'G1.1', 'G2.1', 'M6', 'A9+'],
#   'Volgens': ['Z99'],
#   'artsen': ['B3/S2mf'],
#   'één': ['N1', 'T3', 'T1.2', 'Z8'],
#   'gelukkigen': ['E4.1+', 'E4.2+'],
#   'die': ['Z99'],
#   'nu': ['T1.1.2', 'Z4', 'Z5'],
#   'achter': ['B1', 'M6', 'A6.1-', 'Z5'],
#   'zich': ['Z99'],
#   'mooi': ['O4.2+', 'S1.2.1+'],
#   'om': ['Z99'],
#   'kroeg': ['F2', 'F2/H1'],
#   'vertellen': ['Q2.2', 'Q2.1', 'X3', 'A10+'],
#   'De': ['Z5'],
#   '1–0': ['Z99'],
#   'voordeel': ['A5.1+', 'K5.2'],
#   'Maar': ['A13.6', 'Z5'],
#   'later': ['T4-', 'L1-', 'T1.1'],
#   'leerde': ['X2.3+', 'P1'],
#   'harde': ['O4.1', 'X8+', 'X5.2+', 'N5+', 'A12-', 'O4.5', 'S1.2.5+'],
#   'manier': ['A13.3', 'X4.2', 'M6', 'M3/H3', 'N3.3', 'A4.1', 'A1.1.1', 'T1.3'],
#   'deze': ['Z99'],
#   'rotzooi': ['Z99'],
#   'via': ['M6', 'Z5'],
#   'bloedbaan': ['Z99'],
#   'kan': ['Z99'],
#   'reizen': ['M1'],
#   'januari': ['T1.3'],
#   '2021': ['N1'],
#   'liet': ['S7.4+', 'I2.2/H1', 'T2-'],
#   'routine-scan': ['Z99'],
#   'niet': ['Z6'],
#   'zulk': ['Z5', 'Z8'],
#   'goed': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'zien': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'meerdere': ['Z99'],
#   'laesies': ['Z99'],
#   'lever': ['Z99'],
#   'chirurg': ['Z99'],
#   'zei': ['Q2.1', 'Z4%'],
#   'opereren': ['A1.1.1', 'B3'],
#   'stortte': ['Z99'],
#   'wereld': ['W1', 'S5+c', 'A4.1', 'N5+'],
#   '4': ['N1'],
#   'niet-operabele': ['Z99'],
#   'levermetastasen': ['Z99'],
#   'thuis': ['Z99'],
#   'twee': ['N1', 'T3', 'T1.2'],
#   'zoontjes': ['Z99'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'zonder': ['M6', 'Z5'],
#   'vader': ['S4/B1', 'S4m', 'S9/S2.2m'],
#   'wilde': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'achterlaten': ['M1', 'M2', 'A1.1.1', 'A1.9', 'A9-', 'T2-'],
#   'Dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'gebeurde': ['A2.1+', 'A3+', 'X7-'],
#   'allemaal': ['Z8/N5.1+'],
#   'tijdens': ['Z5'],
#   'coronapandemie': ['Z99'],
#   'familie': ['S4c', 'A4.1c'],
#   'kinderen': ['S2mf/T3-', 'S4mf'],
#   'door': ['M6', 'Z5'],
#   'ziekenhuisbeperkingen': ['Z99'],
#   'altijd': ['N6+++'],
#   'bij': ['Z99'],
#   'me': ['Z8mf'],
#   'konden': ['Z99'],
#   'zijn': ['A3+', 'Z5'],
#   'Toch': ['T1.1.2', 'Z5'],
#   'ben': ['A3+', 'Z5'],
#   'geen': ['S8-', 'Z4', 'Z6'],
#   'opgever': ['Z99'],
#   'zag': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'als': ['Z5'],
#   'nieuwe': ['T3-'],
#   'uitdaging': ['A12-', 'A6.1-', 'S7.3+', 'E3-', 'Q2.2'],
#   'moest': ['Z99'],
#   'overwinnen': ['X9.2+/S7.3', 'X9.2+/G3', 'A2.2/E1', 'B2-'],
#   'Met': ['Z5'],
#   'lage': ['A5.1-',
#    'L2/Q2.1',
#    'N3.7-',
#    'N5-',
#    'A11.1-',
#    'E4.1-',
#    'X3.2-',
#    'G2.2-',
#    'S7.1-'],
#   'overlevingskansen': ['Z99'],
#   'begon': ['T2+', 'E5-', 'E3-'],
#   'aan': ['Z99'],
#   'anderhalf': ['Z99'],
#   'jaar': ['T1.3', 'P1c'],
#   'chemo-': ['Z99'],
#   'radiotherapie': ['Z99'],
#   'flink': ['A11.1+', 'N5+'],
#   'donder': ['Z99'],
#   'gaven': ['A9-', 'A1.1.1'],
#   'ervoor': ['Z99'],
#   'zorgden': ['A9-', 'S6+'],
#   'kankervrij': ['Z99'],
#   'werd': ['A3+', 'Z5'],
#   'eens': ['A13.1', 'A6.1+', 'O4.4', 'A1.4', 'N1', 'T1.3', 'Z5'],
#   'leveroperatie': ['Z99'],
#   'nodig': ['S6+', 'A11.1+'],
#   '2–0': ['Z99'],
#   'we': ['Z8'],
#   'hoopten': ['Z99'],
#   'zou': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'terugkeren': ['M1', 'A9-', 'N6'],
#   'kwam': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'inderdaad': ['A13.3'],
#   'terug': ['B1',
#    'M6',
#    'N6+',
#    'T1.1.1',
#    'S1.1.2+',
#    'T3+',
#    'S8+',
#    'K5.1/I1',
#    'M1',
#    'K2'],
#   'maken': ['Z99'],
#   'iets': ['Z8'],
#   'compleet': ['N5.1+', 'T2-', 'N3.2+', 'Q1.2'],
#   'Bij': ['Z99'],
#   'routineonderzoek': ['Z99'],
#   'verdachten': ['Z99'],
#   'dokters': ['Z99'],
#   'schildklier': ['Z99'],
#   'Na': ['N4', 'Z5'],
#   'extra': ['N5++'],
#   'scans': ['Z99'],
#   'naaldbiopsie': ['Z99'],
#   'horen': ['X3.2', 'X2.3+', 'G2.1@'],
#   'schildklierkanker': ['Z99'],
#   'dacht': ['X2.1'],
#   'mezelf': ['Z8mf'],
#   ':': ['PUNCT'],
#   '“': ['N1'],
#   'Ach': ['Z4'],
#   'is': ['A3+', 'Z5'],
#   'gemakkelijk': ['A12+'],
#   'tackelen': ['Z99'],
#   '”': ['Z99'],
#   'Gisteren': ['T1.1.1'],
#   'hele': ['N5.1+'],
#   'staat': ['M6',
#    'M2',
#    'M8',
#    'M1',
#    'T2++',
#    'N3',
#    'A3+',
#    'X2.1',
#    'A7',
#    'G1.2',
#    'S8+',
#    'S7.4+',
#    'I2.2',
#    'S1.2.5+'],
#   'wat': ['Z8', 'Z5'],
#   'hierna': ['Z99'],
#   'wachten': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1%'],
#   'er': ['M6', 'T1.2', 'Z5'],
#   'komt': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'rotziekte': ['Z99'],
#   'blijven': ['T2++', 'M8', 'N5.2+'],
#   'vechten': ['S8-', 'X8+', 'E3-', 'G1.2'],
#   'tussentijd': ['Z99'],
#   'krijg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'iedere': ['N5.1+', 'S1.1.2+'],
#   'zes': ['N1', 'T3', 'T1.2'],
#   'maanden': ['T1.3'],
#   'preventieve': ['Z99'],
#   'chemotherapie': ['Z99'],
#   'geniet': ['E2+', 'A9+', 'E4.1+'],
#   'ervan': ['Z99'],
#   'samen': ['Z99'],
#   'Dus': ['A13.3', 'Z5'],
#   'kameraad': ['S3.1/S2mf'],
#   'zie': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'jouw': ['Z8'],
#   'situatie': ['A3+', 'O4.1', 'M6', 'I3.1@'],
#   'Wat': ['Z8', 'Z5'],
#   'leven': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'brengt': ['M2', 'A2.2'],
#   'hebt': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'kracht': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2@'],
#   'optimisme': ['Z99'],
#   'zetten': ['M2', 'Q2.1', 'Q2.2', 'A1.1.1'],
#   'Houd': ['Z99'],
#   'hoofd': ['B1',
#    'S7.1+/S2mf',
#    'P1/S2mf',
#    'X1',
#    'M6',
#    'A4.1',
#    'S2mf',
#    'F2',
#    'H5/M4%',
#    'S7.1+',
#    'K5.1',
#    'M1',
#    'N5',
#    'A2.1+',
#    'A11.1+',
#    'Q1.2',
#    'T1.1.3'],
#   'omhoog': ['M6', 'N4', 'N5++', 'T2-', 'X9.1+', 'A1.1.1', 'N5+/A2.1', 'Z5'],
#   'blijf': ['Z99'],
#   'scoren': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   '!': ['PUNCT']},
#  1: {'\n\n': ['Z99'],
#   'Hallo': ['S1.1.1', 'Z4'],
#   'kameraden': ['S3.1/S2mf'],
#   ',': ['PUNCT'],
#   'ik': ['Z8mf'],
#   'wil': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'met': ['Z5'],
#   'jullie': ['Z8mf'],
#   'mijn': ['Z8'],
#   'ervaring': ['A2.1+/A3+', 'X3', 'X2.2+', 'X9.1+', 'I3.2'],
#   'delen': ['S1.1.2+'],
#   'over': ['Z99'],
#   'hoe': ['Z5', 'A13.3'],
#   'na': ['N4', 'Z5'],
#   'een': ['Z5'],
#   'operatie': ['A1.1.1', 'B3', 'G3'],
#   'tegen': ['A5.1-', 'S8-', 'Z5'],
#   'kanker': ['B2-'],
#   'opnieuw': ['N6+', 'Z4'],
#   'doelpunt': ['K5.1', 'X7+'],
#   'scoorde': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   'en': ['Z5'],
#   'de': ['Z5'],
#   'stand': ['Z99'],
#   'op': ['A5.1+', 'G2.2+', 'A1.1.1', 'M6', 'Z5'],
#   '3–0': ['N1'],
#   'bracht': ['M2', 'A2.2'],
#   '.': ['PUNCT'],
#   'Ik': ['Z8mf'],
#   'hoop': ['X2.6+', 'E4.1+', 'X9.2+', 'A5.1+'],
#   'dat': ['A13.3', 'A6.1+', 'Z5', 'Z8'],
#   'dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'verhaal': ['Q2.1', 'X4.1', 'Q4'],
#   'iemand': ['Z8mfc'],
#   'daarbuiten': ['M6', 'S1.1.3-', 'S5-', 'Z5'],
#   'zal': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'inspireren': ['S8+'],
#   'In': ['M6', 'O4.2+', 'Z5'],
#   'mei': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'kreeg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'diagnose': ['B3', 'X4.1'],
#   'darmkanker': ['Z99'],
#   'toen': ['Z5'],
#   'ernstige': ['A11.1+', 'A15-', 'E4.1-'],
#   'bloedingen': ['Z99'],
#   'had': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'je': ['Z8mf'],
#   'weet': ['X2.2+', 'S3.2/B1%'],
#   'wel': ['Z99'],
#   'waar': ['A5.2+', 'A5.4+'],
#   'Voordat': ['N4', 'Z5'],
#   'het': ['Z99'],
#   'doorhad': ['Z99'],
#   'hadden': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'chirurgen': ['Z99'],
#   'al': ['T1.1.1'],
#   '30': ['N1'],
#   'cm': ['N3.7', 'N3.3'],
#   'van': ['Z5'],
#   'dikke': ['N3.7',
#    'O4.5',
#    'N3.7+',
#    'N3.2+',
#    'N5+',
#    'X9.1-',
#    'A10-',
#    'A11.2+',
#    'O4.3@',
#    'O4.2-@'],
#   'darm': ['Z99'],
#   'verwijderd': ['M2'],
#   'Het': ['Z99'],
#   'herstel': ['B2+', 'A5.1+/A2.1', 'A9+'],
#   'was': ['A3+', 'Z5'],
#   'zwaar': ['N3.5+',
#    'N5+',
#    'S1.2.5+',
#    'O4.1',
#    'E4.1-',
#    'W4',
#    'A12-',
#    'A1.1.1',
#    'N3.2+',
#    'A1.1.2@',
#    'S1.2.5+/S2mf'],
#   'maar': ['A13.6', 'Z5'],
#   'te': ['Z99'],
#   'doen': ['A1.1.1', 'G2.2-', 'X9.2+', 'E3-', 'N5+', 'G2.1%', 'Z5'],
#   'goede': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'nieuws': ['X2.2+/T3-', 'X2.2+/Q4.2', 'X2.2+/Q4.3'],
#   'ook': ['N5++'],
#   'tumor': ['Z99'],
#   'groot': ['Z99'],
#   'lymfeklieren': ['Z99'],
#   'schoon': ['B4', 'O4.2+', 'G2.2+'],
#   'waren': ['A3+', 'Z5'],
#   'waardoor': ['Z99'],
#   'in': ['M6', 'O4.2+', 'Z5'],
#   'stadium': ['K4', 'A1.1.1', 'A5.4-', 'T1.2', 'N5.1-', 'H2/K4', 'A4.1'],
#   '2': ['N1'],
#   'zat': ['M8', 'C1', 'P1', 'G1.1', 'G2.1', 'M6', 'A9+'],
#   'Volgens': ['Z99'],
#   'artsen': ['B3/S2mf'],
#   'één': ['N1', 'T3', 'T1.2', 'Z8'],
#   'gelukkigen': ['E4.1+', 'E4.2+'],
#   'die': ['Z99'],
#   'nu': ['T1.1.2', 'Z4', 'Z5'],
#   'achter': ['B1', 'M6', 'A6.1-', 'Z5'],
#   'zich': ['Z99'],
#   'mooi': ['O4.2+', 'S1.2.1+'],
#   'om': ['Z99'],
#   'kroeg': ['F2', 'F2/H1'],
#   'vertellen': ['Q2.2', 'Q2.1', 'X3', 'A10+'],
#   'De': ['Z5'],
#   '1–0': ['Z99'],
#   'voordeel': ['A5.1+', 'K5.2'],
#   'Maar': ['A13.6', 'Z5'],
#   'later': ['T4-', 'L1-', 'T1.1'],
#   'leerde': ['X2.3+', 'P1'],
#   'harde': ['O4.1', 'X8+', 'X5.2+', 'N5+', 'A12-', 'O4.5', 'S1.2.5+'],
#   'manier': ['A13.3', 'X4.2', 'M6', 'M3/H3', 'N3.3', 'A4.1', 'A1.1.1', 'T1.3'],
#   'deze': ['Z99'],
#   'rotzooi': ['Z99'],
#   'via': ['M6', 'Z5'],
#   'bloedbaan': ['Z99'],
#   'kan': ['Z99'],
#   'reizen': ['M1'],
#   'januari': ['T1.3'],
#   '2021': ['N1'],
#   'liet': ['S7.4+', 'I2.2/H1', 'T2-'],
#   'routine-scan': ['Z99'],
#   'niet': ['Z6'],
#   'zulk': ['Z5', 'Z8'],
#   'goed': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'zien': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'meerdere': ['Z99'],
#   'laesies': ['Z99'],
#   'lever': ['Z99'],
#   'chirurg': ['Z99'],
#   'zei': ['Q2.1', 'Z4%'],
#   'opereren': ['A1.1.1', 'B3'],
#   'stortte': ['Z99'],
#   'wereld': ['W1', 'S5+c', 'A4.1', 'N5+'],
#   '4': ['N1'],
#   'niet-operabele': ['Z99'],
#   'levermetastasen': ['Z99'],
#   'thuis': ['Z99'],
#   'twee': ['N1', 'T3', 'T1.2'],
#   'zoontjes': ['Z99'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'zonder': ['M6', 'Z5'],
#   'vader': ['S4/B1', 'S4m', 'S9/S2.2m'],
#   'wilde': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'achterlaten': ['M1', 'M2', 'A1.1.1', 'A1.9', 'A9-', 'T2-'],
#   'Dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'gebeurde': ['A2.1+', 'A3+', 'X7-'],
#   'allemaal': ['Z8/N5.1+'],
#   'tijdens': ['Z5'],
#   'coronapandemie': ['Z99'],
#   'familie': ['S4c', 'A4.1c'],
#   'kinderen': ['S2mf/T3-', 'S4mf'],
#   'door': ['M6', 'Z5'],
#   'ziekenhuisbeperkingen': ['Z99'],
#   'altijd': ['N6+++'],
#   'bij': ['Z99'],
#   'me': ['Z8mf'],
#   'konden': ['Z99'],
#   'zijn': ['A3+', 'Z5'],
#   'Toch': ['T1.1.2', 'Z5'],
#   'ben': ['A3+', 'Z5'],
#   'geen': ['S8-', 'Z4', 'Z6'],
#   'opgever': ['Z99'],
#   'zag': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'als': ['Z5'],
#   'nieuwe': ['T3-'],
#   'uitdaging': ['A12-', 'A6.1-', 'S7.3+', 'E3-', 'Q2.2'],
#   'moest': ['Z99'],
#   'overwinnen': ['X9.2+/S7.3', 'X9.2+/G3', 'A2.2/E1', 'B2-'],
#   'Met': ['Z5'],
#   'lage': ['A5.1-',
#    'L2/Q2.1',
#    'N3.7-',
#    'N5-',
#    'A11.1-',
#    'E4.1-',
#    'X3.2-',
#    'G2.2-',
#    'S7.1-'],
#   'overlevingskansen': ['Z99'],
#   'begon': ['T2+', 'E5-', 'E3-'],
#   'aan': ['Z99'],
#   'anderhalf': ['Z99'],
#   'jaar': ['T1.3', 'P1c'],
#   'chemo-': ['Z99'],
#   'radiotherapie': ['Z99'],
#   'flink': ['A11.1+', 'N5+'],
#   'donder': ['Z99'],
#   'gaven': ['A9-', 'A1.1.1'],
#   'ervoor': ['Z99'],
#   'zorgden': ['A9-', 'S6+'],
#   'kankervrij': ['Z99'],
#   'werd': ['A3+', 'Z5'],
#   'eens': ['A13.1', 'A6.1+', 'O4.4', 'A1.4', 'N1', 'T1.3', 'Z5'],
#   'leveroperatie': ['Z99'],
#   'nodig': ['S6+', 'A11.1+'],
#   '2–0': ['Z99'],
#   'we': ['Z8'],
#   'hoopten': ['Z99'],
#   'zou': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'terugkeren': ['M1', 'A9-', 'N6'],
#   'kwam': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'inderdaad': ['A13.3'],
#   'terug': ['B1',
#    'M6',
#    'N6+',
#    'T1.1.1',
#    'S1.1.2+',
#    'T3+',
#    'S8+',
#    'K5.1/I1',
#    'M1',
#    'K2'],
#   'maken': ['Z99'],
#   'iets': ['Z8'],
#   'compleet': ['N5.1+', 'T2-', 'N3.2+', 'Q1.2'],
#   'Bij': ['Z99'],
#   'routineonderzoek': ['Z99'],
#   'verdachten': ['Z99'],
#   'dokters': ['Z99'],
#   'schildklier': ['Z99'],
#   'Na': ['N4', 'Z5'],
#   'extra': ['N5++'],
#   'scans': ['Z99'],
#   'naaldbiopsie': ['Z99'],
#   'horen': ['X3.2', 'X2.3+', 'G2.1@'],
#   'schildklierkanker': ['Z99'],
#   'dacht': ['X2.1'],
#   'mezelf': ['Z8mf'],
#   ':': ['PUNCT'],
#   '“': ['N1'],
#   'Ach': ['Z4'],
#   'is': ['A3+', 'Z5'],
#   'gemakkelijk': ['A12+'],
#   'tackelen': ['Z99'],
#   '”': ['Z99'],
#   'Gisteren': ['T1.1.1'],
#   'hele': ['N5.1+'],
#   'staat': ['M6',
#    'M2',
#    'M8',
#    'M1',
#    'T2++',
#    'N3',
#    'A3+',
#    'X2.1',
#    'A7',
#    'G1.2',
#    'S8+',
#    'S7.4+',
#    'I2.2',
#    'S1.2.5+'],
#   'wat': ['Z8', 'Z5'],
#   'hierna': ['Z99'],
#   'wachten': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1%'],
#   'er': ['M6', 'T1.2', 'Z5'],
#   'komt': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'rotziekte': ['Z99'],
#   'blijven': ['T2++', 'M8', 'N5.2+'],
#   'vechten': ['S8-', 'X8+', 'E3-', 'G1.2'],
#   'tussentijd': ['Z99'],
#   'krijg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'iedere': ['N5.1+', 'S1.1.2+'],
#   'zes': ['N1', 'T3', 'T1.2'],
#   'maanden': ['T1.3'],
#   'preventieve': ['Z99'],
#   'chemotherapie': ['Z99'],
#   'geniet': ['E2+', 'A9+', 'E4.1+'],
#   'ervan': ['Z99'],
#   'samen': ['Z99'],
#   'Dus': ['A13.3', 'Z5'],
#   'kameraad': ['S3.1/S2mf'],
#   'zie': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'jouw': ['Z8'],
#   'situatie': ['A3+', 'O4.1', 'M6', 'I3.1@'],
#   'Wat': ['Z8', 'Z5'],
#   'leven': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'brengt': ['M2', 'A2.2'],
#   'hebt': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'kracht': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2@'],
#   'optimisme': ['Z99'],
#   'zetten': ['M2', 'Q2.1', 'Q2.2', 'A1.1.1'],
#   'Houd': ['Z99'],
#   'hoofd': ['B1',
#    'S7.1+/S2mf',
#    'P1/S2mf',
#    'X1',
#    'M6',
#    'A4.1',
#    'S2mf',
#    'F2',
#    'H5/M4%',
#    'S7.1+',
#    'K5.1',
#    'M1',
#    'N5',
#    'A2.1+',
#    'A11.1+',
#    'Q1.2',
#    'T1.1.3'],
#   'omhoog': ['M6', 'N4', 'N5++', 'T2-', 'X9.1+', 'A1.1.1', 'N5+/A2.1', 'Z5'],
#   'blijf': ['Z99'],
#   'scoren': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   '!': ['PUNCT']},
#  2: {'\n\n': ['Z99'],
#   'Hallo': ['S1.1.1', 'Z4'],
#   'kameraden': ['S3.1/S2mf'],
#   ',': ['PUNCT'],
#   'ik': ['Z8mf'],
#   'wil': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'met': ['Z5'],
#   'jullie': ['Z8mf'],
#   'mijn': ['Z8'],
#   'ervaring': ['A2.1+/A3+', 'X3', 'X2.2+', 'X9.1+', 'I3.2'],
#   'delen': ['S1.1.2+'],
#   'over': ['Z99'],
#   'hoe': ['Z5', 'A13.3'],
#   'na': ['N4', 'Z5'],
#   'een': ['Z5'],
#   'operatie': ['A1.1.1', 'B3', 'G3'],
#   'tegen': ['A5.1-', 'S8-', 'Z5'],
#   'kanker': ['B2-'],
#   'opnieuw': ['N6+', 'Z4'],
#   'doelpunt': ['K5.1', 'X7+'],
#   'scoorde': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   'en': ['Z5'],
#   'de': ['Z5'],
#   'stand': ['Z99'],
#   'op': ['A5.1+', 'G2.2+', 'A1.1.1', 'M6', 'Z5'],
#   '3–0': ['N1'],
#   'bracht': ['M2', 'A2.2'],
#   '.': ['PUNCT'],
#   'Ik': ['Z8mf'],
#   'hoop': ['X2.6+', 'E4.1+', 'X9.2+', 'A5.1+'],
#   'dat': ['A13.3', 'A6.1+', 'Z5', 'Z8'],
#   'dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'verhaal': ['Q2.1', 'X4.1', 'Q4'],
#   'iemand': ['Z8mfc'],
#   'daarbuiten': ['M6', 'S1.1.3-', 'S5-', 'Z5'],
#   'zal': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'inspireren': ['S8+'],
#   'In': ['M6', 'O4.2+', 'Z5'],
#   'mei': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'kreeg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'diagnose': ['B3', 'X4.1'],
#   'darmkanker': ['Z99'],
#   'toen': ['Z5'],
#   'ernstige': ['A11.1+', 'A15-', 'E4.1-'],
#   'bloedingen': ['Z99'],
#   'had': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'je': ['Z8mf'],
#   'weet': ['X2.2+', 'S3.2/B1%'],
#   'wel': ['Z99'],
#   'waar': ['A5.2+', 'A5.4+'],
#   'Voordat': ['N4', 'Z5'],
#   'het': ['Z99'],
#   'doorhad': ['Z99'],
#   'hadden': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'chirurgen': ['Z99'],
#   'al': ['T1.1.1'],
#   '30': ['N1'],
#   'cm': ['N3.7', 'N3.3'],
#   'van': ['Z5'],
#   'dikke': ['N3.7',
#    'O4.5',
#    'N3.7+',
#    'N3.2+',
#    'N5+',
#    'X9.1-',
#    'A10-',
#    'A11.2+',
#    'O4.3@',
#    'O4.2-@'],
#   'darm': ['Z99'],
#   'verwijderd': ['M2'],
#   'Het': ['Z99'],
#   'herstel': ['B2+', 'A5.1+/A2.1', 'A9+'],
#   'was': ['A3+', 'Z5'],
#   'zwaar': ['N3.5+',
#    'N5+',
#    'S1.2.5+',
#    'O4.1',
#    'E4.1-',
#    'W4',
#    'A12-',
#    'A1.1.1',
#    'N3.2+',
#    'A1.1.2@',
#    'S1.2.5+/S2mf'],
#   'maar': ['A13.6', 'Z5'],
#   'te': ['Z99'],
#   'doen': ['A1.1.1', 'G2.2-', 'X9.2+', 'E3-', 'N5+', 'G2.1%', 'Z5'],
#   'goede': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'nieuws': ['X2.2+/T3-', 'X2.2+/Q4.2', 'X2.2+/Q4.3'],
#   'ook': ['N5++'],
#   'tumor': ['Z99'],
#   'groot': ['Z99'],
#   'lymfeklieren': ['Z99'],
#   'schoon': ['B4', 'O4.2+', 'G2.2+'],
#   'waren': ['A3+', 'Z5'],
#   'waardoor': ['Z99'],
#   'in': ['M6', 'O4.2+', 'Z5'],
#   'stadium': ['K4', 'A1.1.1', 'A5.4-', 'T1.2', 'N5.1-', 'H2/K4', 'A4.1'],
#   '2': ['N1'],
#   'zat': ['M8', 'C1', 'P1', 'G1.1', 'G2.1', 'M6', 'A9+'],
#   'Volgens': ['Z99'],
#   'artsen': ['B3/S2mf'],
#   'één': ['N1', 'T3', 'T1.2', 'Z8'],
#   'gelukkigen': ['E4.1+', 'E4.2+'],
#   'die': ['Z99'],
#   'nu': ['T1.1.2', 'Z4', 'Z5'],
#   'achter': ['B1', 'M6', 'A6.1-', 'Z5'],
#   'zich': ['Z99'],
#   'mooi': ['O4.2+', 'S1.2.1+'],
#   'om': ['Z99'],
#   'kroeg': ['F2', 'F2/H1'],
#   'vertellen': ['Q2.2', 'Q2.1', 'X3', 'A10+'],
#   'De': ['Z5'],
#   '1–0': ['Z99'],
#   'voordeel': ['A5.1+', 'K5.2'],
#   'Maar': ['A13.6', 'Z5'],
#   'later': ['T4-', 'L1-', 'T1.1'],
#   'leerde': ['X2.3+', 'P1'],
#   'harde': ['O4.1', 'X8+', 'X5.2+', 'N5+', 'A12-', 'O4.5', 'S1.2.5+'],
#   'manier': ['A13.3', 'X4.2', 'M6', 'M3/H3', 'N3.3', 'A4.1', 'A1.1.1', 'T1.3'],
#   'deze': ['Z99'],
#   'rotzooi': ['Z99'],
#   'via': ['M6', 'Z5'],
#   'bloedbaan': ['Z99'],
#   'kan': ['Z99'],
#   'reizen': ['M1'],
#   'januari': ['T1.3'],
#   '2021': ['N1'],
#   'liet': ['S7.4+', 'I2.2/H1', 'T2-'],
#   'routine-scan': ['Z99'],
#   'niet': ['Z6'],
#   'zulk': ['Z5', 'Z8'],
#   'goed': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'zien': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'meerdere': ['Z99'],
#   'laesies': ['Z99'],
#   'lever': ['Z99'],
#   'chirurg': ['Z99'],
#   'zei': ['Q2.1', 'Z4%'],
#   'opereren': ['A1.1.1', 'B3'],
#   'stortte': ['Z99'],
#   'wereld': ['W1', 'S5+c', 'A4.1', 'N5+'],
#   '4': ['N1'],
#   'niet-operabele': ['Z99'],
#   'levermetastasen': ['Z99'],
#   'thuis': ['Z99'],
#   'twee': ['N1', 'T3', 'T1.2'],
#   'zoontjes': ['Z99'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'zonder': ['M6', 'Z5'],
#   'vader': ['S4/B1', 'S4m', 'S9/S2.2m'],
#   'wilde': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'achterlaten': ['M1', 'M2', 'A1.1.1', 'A1.9', 'A9-', 'T2-'],
#   'Dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'gebeurde': ['A2.1+', 'A3+', 'X7-'],
#   'allemaal': ['Z8/N5.1+'],
#   'tijdens': ['Z5'],
#   'coronapandemie': ['Z99'],
#   'familie': ['S4c', 'A4.1c'],
#   'kinderen': ['S2mf/T3-', 'S4mf'],
#   'door': ['M6', 'Z5'],
#   'ziekenhuisbeperkingen': ['Z99'],
#   'altijd': ['N6+++'],
#   'bij': ['Z99'],
#   'me': ['Z8mf'],
#   'konden': ['Z99'],
#   'zijn': ['A3+', 'Z5'],
#   'Toch': ['T1.1.2', 'Z5'],
#   'ben': ['A3+', 'Z5'],
#   'geen': ['S8-', 'Z4', 'Z6'],
#   'opgever': ['Z99'],
#   'zag': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'als': ['Z5'],
#   'nieuwe': ['T3-'],
#   'uitdaging': ['A12-', 'A6.1-', 'S7.3+', 'E3-', 'Q2.2'],
#   'moest': ['Z99'],
#   'overwinnen': ['X9.2+/S7.3', 'X9.2+/G3', 'A2.2/E1', 'B2-'],
#   'Met': ['Z5'],
#   'lage': ['A5.1-',
#    'L2/Q2.1',
#    'N3.7-',
#    'N5-',
#    'A11.1-',
#    'E4.1-',
#    'X3.2-',
#    'G2.2-',
#    'S7.1-'],
#   'overlevingskansen': ['Z99'],
#   'begon': ['T2+', 'E5-', 'E3-'],
#   'aan': ['Z99'],
#   'anderhalf': ['Z99'],
#   'jaar': ['T1.3', 'P1c'],
#   'chemo-': ['Z99'],
#   'radiotherapie': ['Z99'],
#   'flink': ['A11.1+', 'N5+'],
#   'donder': ['Z99'],
#   'gaven': ['A9-', 'A1.1.1'],
#   'ervoor': ['Z99'],
#   'zorgden': ['A9-', 'S6+'],
#   'kankervrij': ['Z99'],
#   'werd': ['A3+', 'Z5'],
#   'eens': ['A13.1', 'A6.1+', 'O4.4', 'A1.4', 'N1', 'T1.3', 'Z5'],
#   'leveroperatie': ['Z99'],
#   'nodig': ['S6+', 'A11.1+'],
#   '2–0': ['Z99'],
#   'we': ['Z8'],
#   'hoopten': ['Z99'],
#   'zou': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'terugkeren': ['M1', 'A9-', 'N6'],
#   'kwam': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'inderdaad': ['A13.3'],
#   'terug': ['B1',
#    'M6',
#    'N6+',
#    'T1.1.1',
#    'S1.1.2+',
#    'T3+',
#    'S8+',
#    'K5.1/I1',
#    'M1',
#    'K2'],
#   'maken': ['Z99'],
#   'iets': ['Z8'],
#   'compleet': ['N5.1+', 'T2-', 'N3.2+', 'Q1.2'],
#   'Bij': ['Z99'],
#   'routineonderzoek': ['Z99'],
#   'verdachten': ['Z99'],
#   'dokters': ['Z99'],
#   'schildklier': ['Z99'],
#   'Na': ['N4', 'Z5'],
#   'extra': ['N5++'],
#   'scans': ['Z99'],
#   'naaldbiopsie': ['Z99'],
#   'horen': ['X3.2', 'X2.3+', 'G2.1@'],
#   'schildklierkanker': ['Z99'],
#   'dacht': ['X2.1'],
#   'mezelf': ['Z8mf'],
#   ':': ['PUNCT'],
#   '“': ['N1'],
#   'Ach': ['Z4'],
#   'is': ['A3+', 'Z5'],
#   'gemakkelijk': ['A12+'],
#   'tackelen': ['Z99'],
#   '”': ['Z99'],
#   'Gisteren': ['T1.1.1'],
#   'hele': ['N5.1+'],
#   'staat': ['M6',
#    'M2',
#    'M8',
#    'M1',
#    'T2++',
#    'N3',
#    'A3+',
#    'X2.1',
#    'A7',
#    'G1.2',
#    'S8+',
#    'S7.4+',
#    'I2.2',
#    'S1.2.5+'],
#   'wat': ['Z8', 'Z5'],
#   'hierna': ['Z99'],
#   'wachten': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1%'],
#   'er': ['M6', 'T1.2', 'Z5'],
#   'komt': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'rotziekte': ['Z99'],
#   'blijven': ['T2++', 'M8', 'N5.2+'],
#   'vechten': ['S8-', 'X8+', 'E3-', 'G1.2'],
#   'tussentijd': ['Z99'],
#   'krijg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'iedere': ['N5.1+', 'S1.1.2+'],
#   'zes': ['N1', 'T3', 'T1.2'],
#   'maanden': ['T1.3'],
#   'preventieve': ['Z99'],
#   'chemotherapie': ['Z99'],
#   'geniet': ['E2+', 'A9+', 'E4.1+'],
#   'ervan': ['Z99'],
#   'samen': ['Z99'],
#   'Dus': ['A13.3', 'Z5'],
#   'kameraad': ['S3.1/S2mf'],
#   'zie': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'jouw': ['Z8'],
#   'situatie': ['A3+', 'O4.1', 'M6', 'I3.1@'],
#   'Wat': ['Z8', 'Z5'],
#   'leven': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'brengt': ['M2', 'A2.2'],
#   'hebt': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'kracht': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2@'],
#   'optimisme': ['Z99'],
#   'zetten': ['M2', 'Q2.1', 'Q2.2', 'A1.1.1'],
#   'Houd': ['Z99'],
#   'hoofd': ['B1',
#    'S7.1+/S2mf',
#    'P1/S2mf',
#    'X1',
#    'M6',
#    'A4.1',
#    'S2mf',
#    'F2',
#    'H5/M4%',
#    'S7.1+',
#    'K5.1',
#    'M1',
#    'N5',
#    'A2.1+',
#    'A11.1+',
#    'Q1.2',
#    'T1.1.3'],
#   'omhoog': ['M6', 'N4', 'N5++', 'T2-', 'X9.1+', 'A1.1.1', 'N5+/A2.1', 'Z5'],
#   'blijf': ['Z99'],
#   'scoren': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   '!': ['PUNCT']},
#  3: {'\n\n': ['Z99'],
#   'Hallo': ['S1.1.1', 'Z4'],
#   'kameraden': ['S3.1/S2mf'],
#   ',': ['PUNCT'],
#   'ik': ['Z8mf'],
#   'wil': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'met': ['Z5'],
#   'jullie': ['Z8mf'],
#   'mijn': ['Z8'],
#   'ervaring': ['A2.1+/A3+', 'X3', 'X2.2+', 'X9.1+', 'I3.2'],
#   'delen': ['S1.1.2+'],
#   'over': ['Z99'],
#   'hoe': ['Z5', 'A13.3'],
#   'na': ['N4', 'Z5'],
#   'een': ['Z5'],
#   'operatie': ['A1.1.1', 'B3', 'G3'],
#   'tegen': ['A5.1-', 'S8-', 'Z5'],
#   'kanker': ['B2-'],
#   'opnieuw': ['N6+', 'Z4'],
#   'doelpunt': ['K5.1', 'X7+'],
#   'scoorde': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   'en': ['Z5'],
#   'de': ['Z5'],
#   'stand': ['Z99'],
#   'op': ['A5.1+', 'G2.2+', 'A1.1.1', 'M6', 'Z5'],
#   '3–0': ['N1'],
#   'bracht': ['M2', 'A2.2'],
#   '.': ['PUNCT'],
#   'Ik': ['Z8mf'],
#   'hoop': ['X2.6+', 'E4.1+', 'X9.2+', 'A5.1+'],
#   'dat': ['A13.3', 'A6.1+', 'Z5', 'Z8'],
#   'dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'verhaal': ['Q2.1', 'X4.1', 'Q4'],
#   'iemand': ['Z8mfc'],
#   'daarbuiten': ['M6', 'S1.1.3-', 'S5-', 'Z5'],
#   'zal': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'inspireren': ['S8+'],
#   'In': ['M6', 'O4.2+', 'Z5'],
#   'mei': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'kreeg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'diagnose': ['B3', 'X4.1'],
#   'darmkanker': ['Z99'],
#   'toen': ['Z5'],
#   'ernstige': ['A11.1+', 'A15-', 'E4.1-'],
#   'bloedingen': ['Z99'],
#   'had': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'je': ['Z8mf'],
#   'weet': ['X2.2+', 'S3.2/B1%'],
#   'wel': ['Z99'],
#   'waar': ['A5.2+', 'A5.4+'],
#   'Voordat': ['N4', 'Z5'],
#   'het': ['Z99'],
#   'doorhad': ['Z99'],
#   'hadden': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'chirurgen': ['Z99'],
#   'al': ['T1.1.1'],
#   '30': ['N1'],
#   'cm': ['N3.7', 'N3.3'],
#   'van': ['Z5'],
#   'dikke': ['N3.7',
#    'O4.5',
#    'N3.7+',
#    'N3.2+',
#    'N5+',
#    'X9.1-',
#    'A10-',
#    'A11.2+',
#    'O4.3@',
#    'O4.2-@'],
#   'darm': ['Z99'],
#   'verwijderd': ['M2'],
#   'Het': ['Z99'],
#   'herstel': ['B2+', 'A5.1+/A2.1', 'A9+'],
#   'was': ['A3+', 'Z5'],
#   'zwaar': ['N3.5+',
#    'N5+',
#    'S1.2.5+',
#    'O4.1',
#    'E4.1-',
#    'W4',
#    'A12-',
#    'A1.1.1',
#    'N3.2+',
#    'A1.1.2@',
#    'S1.2.5+/S2mf'],
#   'maar': ['A13.6', 'Z5'],
#   'te': ['Z99'],
#   'doen': ['A1.1.1', 'G2.2-', 'X9.2+', 'E3-', 'N5+', 'G2.1%', 'Z5'],
#   'goede': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'nieuws': ['X2.2+/T3-', 'X2.2+/Q4.2', 'X2.2+/Q4.3'],
#   'ook': ['N5++'],
#   'tumor': ['Z99'],
#   'groot': ['Z99'],
#   'lymfeklieren': ['Z99'],
#   'schoon': ['B4', 'O4.2+', 'G2.2+'],
#   'waren': ['A3+', 'Z5'],
#   'waardoor': ['Z99'],
#   'in': ['M6', 'O4.2+', 'Z5'],
#   'stadium': ['K4', 'A1.1.1', 'A5.4-', 'T1.2', 'N5.1-', 'H2/K4', 'A4.1'],
#   '2': ['N1'],
#   'zat': ['M8', 'C1', 'P1', 'G1.1', 'G2.1', 'M6', 'A9+'],
#   'Volgens': ['Z99'],
#   'artsen': ['B3/S2mf'],
#   'één': ['N1', 'T3', 'T1.2', 'Z8'],
#   'gelukkigen': ['E4.1+', 'E4.2+'],
#   'die': ['Z99'],
#   'nu': ['T1.1.2', 'Z4', 'Z5'],
#   'achter': ['B1', 'M6', 'A6.1-', 'Z5'],
#   'zich': ['Z99'],
#   'mooi': ['O4.2+', 'S1.2.1+'],
#   'om': ['Z99'],
#   'kroeg': ['F2', 'F2/H1'],
#   'vertellen': ['Q2.2', 'Q2.1', 'X3', 'A10+'],
#   'De': ['Z5'],
#   '1–0': ['Z99'],
#   'voordeel': ['A5.1+', 'K5.2'],
#   'Maar': ['A13.6', 'Z5'],
#   'later': ['T4-', 'L1-', 'T1.1'],
#   'leerde': ['X2.3+', 'P1'],
#   'harde': ['O4.1', 'X8+', 'X5.2+', 'N5+', 'A12-', 'O4.5', 'S1.2.5+'],
#   'manier': ['A13.3', 'X4.2', 'M6', 'M3/H3', 'N3.3', 'A4.1', 'A1.1.1', 'T1.3'],
#   'deze': ['Z99'],
#   'rotzooi': ['Z99'],
#   'via': ['M6', 'Z5'],
#   'bloedbaan': ['Z99'],
#   'kan': ['Z99'],
#   'reizen': ['M1'],
#   'januari': ['T1.3'],
#   '2021': ['N1'],
#   'liet': ['S7.4+', 'I2.2/H1', 'T2-'],
#   'routine-scan': ['Z99'],
#   'niet': ['Z6'],
#   'zulk': ['Z5', 'Z8'],
#   'goed': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'zien': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'meerdere': ['Z99'],
#   'laesies': ['Z99'],
#   'lever': ['Z99'],
#   'chirurg': ['Z99'],
#   'zei': ['Q2.1', 'Z4%'],
#   'opereren': ['A1.1.1', 'B3'],
#   'stortte': ['Z99'],
#   'wereld': ['W1', 'S5+c', 'A4.1', 'N5+'],
#   '4': ['N1'],
#   'niet-operabele': ['Z99'],
#   'levermetastasen': ['Z99'],
#   'thuis': ['Z99'],
#   'twee': ['N1', 'T3', 'T1.2'],
#   'zoontjes': ['Z99'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'zonder': ['M6', 'Z5'],
#   'vader': ['S4/B1', 'S4m', 'S9/S2.2m'],
#   'wilde': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'achterlaten': ['M1', 'M2', 'A1.1.1', 'A1.9', 'A9-', 'T2-'],
#   'Dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'gebeurde': ['A2.1+', 'A3+', 'X7-'],
#   'allemaal': ['Z8/N5.1+'],
#   'tijdens': ['Z5'],
#   'coronapandemie': ['Z99'],
#   'familie': ['S4c', 'A4.1c'],
#   'kinderen': ['S2mf/T3-', 'S4mf'],
#   'door': ['M6', 'Z5'],
#   'ziekenhuisbeperkingen': ['Z99'],
#   'altijd': ['N6+++'],
#   'bij': ['Z99'],
#   'me': ['Z8mf'],
#   'konden': ['Z99'],
#   'zijn': ['A3+', 'Z5'],
#   'Toch': ['T1.1.2', 'Z5'],
#   'ben': ['A3+', 'Z5'],
#   'geen': ['S8-', 'Z4', 'Z6'],
#   'opgever': ['Z99'],
#   'zag': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'als': ['Z5'],
#   'nieuwe': ['T3-'],
#   'uitdaging': ['A12-', 'A6.1-', 'S7.3+', 'E3-', 'Q2.2'],
#   'moest': ['Z99'],
#   'overwinnen': ['X9.2+/S7.3', 'X9.2+/G3', 'A2.2/E1', 'B2-'],
#   'Met': ['Z5'],
#   'lage': ['A5.1-',
#    'L2/Q2.1',
#    'N3.7-',
#    'N5-',
#    'A11.1-',
#    'E4.1-',
#    'X3.2-',
#    'G2.2-',
#    'S7.1-'],
#   'overlevingskansen': ['Z99'],
#   'begon': ['T2+', 'E5-', 'E3-'],
#   'aan': ['Z99'],
#   'anderhalf': ['Z99'],
#   'jaar': ['T1.3', 'P1c'],
#   'chemo-': ['Z99'],
#   'radiotherapie': ['Z99'],
#   'flink': ['A11.1+', 'N5+'],
#   'donder': ['Z99'],
#   'gaven': ['A9-', 'A1.1.1'],
#   'ervoor': ['Z99'],
#   'zorgden': ['A9-', 'S6+'],
#   'kankervrij': ['Z99'],
#   'werd': ['A3+', 'Z5'],
#   'eens': ['A13.1', 'A6.1+', 'O4.4', 'A1.4', 'N1', 'T1.3', 'Z5'],
#   'leveroperatie': ['Z99'],
#   'nodig': ['S6+', 'A11.1+'],
#   '2–0': ['Z99'],
#   'we': ['Z8'],
#   'hoopten': ['Z99'],
#   'zou': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'terugkeren': ['M1', 'A9-', 'N6'],
#   'kwam': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'inderdaad': ['A13.3'],
#   'terug': ['B1',
#    'M6',
#    'N6+',
#    'T1.1.1',
#    'S1.1.2+',
#    'T3+',
#    'S8+',
#    'K5.1/I1',
#    'M1',
#    'K2'],
#   'maken': ['Z99'],
#   'iets': ['Z8'],
#   'compleet': ['N5.1+', 'T2-', 'N3.2+', 'Q1.2'],
#   'Bij': ['Z99'],
#   'routineonderzoek': ['Z99'],
#   'verdachten': ['Z99'],
#   'dokters': ['Z99'],
#   'schildklier': ['Z99'],
#   'Na': ['N4', 'Z5'],
#   'extra': ['N5++'],
#   'scans': ['Z99'],
#   'naaldbiopsie': ['Z99'],
#   'horen': ['X3.2', 'X2.3+', 'G2.1@'],
#   'schildklierkanker': ['Z99'],
#   'dacht': ['X2.1'],
#   'mezelf': ['Z8mf'],
#   ':': ['PUNCT'],
#   '“': ['N1'],
#   'Ach': ['Z4'],
#   'is': ['A3+', 'Z5'],
#   'gemakkelijk': ['A12+'],
#   'tackelen': ['Z99'],
#   '”': ['Z99'],
#   'Gisteren': ['T1.1.1'],
#   'hele': ['N5.1+'],
#   'staat': ['M6',
#    'M2',
#    'M8',
#    'M1',
#    'T2++',
#    'N3',
#    'A3+',
#    'X2.1',
#    'A7',
#    'G1.2',
#    'S8+',
#    'S7.4+',
#    'I2.2',
#    'S1.2.5+'],
#   'wat': ['Z8', 'Z5'],
#   'hierna': ['Z99'],
#   'wachten': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1%'],
#   'er': ['M6', 'T1.2', 'Z5'],
#   'komt': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'rotziekte': ['Z99'],
#   'blijven': ['T2++', 'M8', 'N5.2+'],
#   'vechten': ['S8-', 'X8+', 'E3-', 'G1.2'],
#   'tussentijd': ['Z99'],
#   'krijg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'iedere': ['N5.1+', 'S1.1.2+'],
#   'zes': ['N1', 'T3', 'T1.2'],
#   'maanden': ['T1.3'],
#   'preventieve': ['Z99'],
#   'chemotherapie': ['Z99'],
#   'geniet': ['E2+', 'A9+', 'E4.1+'],
#   'ervan': ['Z99'],
#   'samen': ['Z99'],
#   'Dus': ['A13.3', 'Z5'],
#   'kameraad': ['S3.1/S2mf'],
#   'zie': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'jouw': ['Z8'],
#   'situatie': ['A3+', 'O4.1', 'M6', 'I3.1@'],
#   'Wat': ['Z8', 'Z5'],
#   'leven': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'brengt': ['M2', 'A2.2'],
#   'hebt': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'kracht': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2@'],
#   'optimisme': ['Z99'],
#   'zetten': ['M2', 'Q2.1', 'Q2.2', 'A1.1.1'],
#   'Houd': ['Z99'],
#   'hoofd': ['B1',
#    'S7.1+/S2mf',
#    'P1/S2mf',
#    'X1',
#    'M6',
#    'A4.1',
#    'S2mf',
#    'F2',
#    'H5/M4%',
#    'S7.1+',
#    'K5.1',
#    'M1',
#    'N5',
#    'A2.1+',
#    'A11.1+',
#    'Q1.2',
#    'T1.1.3'],
#   'omhoog': ['M6', 'N4', 'N5++', 'T2-', 'X9.1+', 'A1.1.1', 'N5+/A2.1', 'Z5'],
#   'blijf': ['Z99'],
#   'scoren': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   '!': ['PUNCT']},
#  4: {'\n\n': ['Z99'],
#   'Hallo': ['S1.1.1', 'Z4'],
#   'kameraden': ['S3.1/S2mf'],
#   ',': ['PUNCT'],
#   'ik': ['Z8mf'],
#   'wil': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'met': ['Z5'],
#   'jullie': ['Z8mf'],
#   'mijn': ['Z8'],
#   'ervaring': ['A2.1+/A3+', 'X3', 'X2.2+', 'X9.1+', 'I3.2'],
#   'delen': ['S1.1.2+'],
#   'over': ['Z99'],
#   'hoe': ['Z5', 'A13.3'],
#   'na': ['N4', 'Z5'],
#   'een': ['Z5'],
#   'operatie': ['A1.1.1', 'B3', 'G3'],
#   'tegen': ['A5.1-', 'S8-', 'Z5'],
#   'kanker': ['B2-'],
#   'opnieuw': ['N6+', 'Z4'],
#   'doelpunt': ['K5.1', 'X7+'],
#   'scoorde': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   'en': ['Z5'],
#   'de': ['Z5'],
#   'stand': ['Z99'],
#   'op': ['A5.1+', 'G2.2+', 'A1.1.1', 'M6', 'Z5'],
#   '3–0': ['N1'],
#   'bracht': ['M2', 'A2.2'],
#   '.': ['PUNCT'],
#   'Ik': ['Z8mf'],
#   'hoop': ['X2.6+', 'E4.1+', 'X9.2+', 'A5.1+'],
#   'dat': ['A13.3', 'A6.1+', 'Z5', 'Z8'],
#   'dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'verhaal': ['Q2.1', 'X4.1', 'Q4'],
#   'iemand': ['Z8mfc'],
#   'daarbuiten': ['M6', 'S1.1.3-', 'S5-', 'Z5'],
#   'zal': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'inspireren': ['S8+'],
#   'In': ['M6', 'O4.2+', 'Z5'],
#   'mei': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'kreeg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'diagnose': ['B3', 'X4.1'],
#   'darmkanker': ['Z99'],
#   'toen': ['Z5'],
#   'ernstige': ['A11.1+', 'A15-', 'E4.1-'],
#   'bloedingen': ['Z99'],
#   'had': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'je': ['Z8mf'],
#   'weet': ['X2.2+', 'S3.2/B1%'],
#   'wel': ['Z99'],
#   'waar': ['A5.2+', 'A5.4+'],
#   'Voordat': ['N4', 'Z5'],
#   'het': ['Z99'],
#   'doorhad': ['Z99'],
#   'hadden': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'chirurgen': ['Z99'],
#   'al': ['T1.1.1'],
#   '30': ['N1'],
#   'cm': ['N3.7', 'N3.3'],
#   'van': ['Z5'],
#   'dikke': ['N3.7',
#    'O4.5',
#    'N3.7+',
#    'N3.2+',
#    'N5+',
#    'X9.1-',
#    'A10-',
#    'A11.2+',
#    'O4.3@',
#    'O4.2-@'],
#   'darm': ['Z99'],
#   'verwijderd': ['M2'],
#   'Het': ['Z99'],
#   'herstel': ['B2+', 'A5.1+/A2.1', 'A9+'],
#   'was': ['A3+', 'Z5'],
#   'zwaar': ['N3.5+',
#    'N5+',
#    'S1.2.5+',
#    'O4.1',
#    'E4.1-',
#    'W4',
#    'A12-',
#    'A1.1.1',
#    'N3.2+',
#    'A1.1.2@',
#    'S1.2.5+/S2mf'],
#   'maar': ['A13.6', 'Z5'],
#   'te': ['Z99'],
#   'doen': ['A1.1.1', 'G2.2-', 'X9.2+', 'E3-', 'N5+', 'G2.1%', 'Z5'],
#   'goede': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'nieuws': ['X2.2+/T3-', 'X2.2+/Q4.2', 'X2.2+/Q4.3'],
#   'ook': ['N5++'],
#   'tumor': ['Z99'],
#   'groot': ['Z99'],
#   'lymfeklieren': ['Z99'],
#   'schoon': ['B4', 'O4.2+', 'G2.2+'],
#   'waren': ['A3+', 'Z5'],
#   'waardoor': ['Z99'],
#   'in': ['M6', 'O4.2+', 'Z5'],
#   'stadium': ['K4', 'A1.1.1', 'A5.4-', 'T1.2', 'N5.1-', 'H2/K4', 'A4.1'],
#   '2': ['N1'],
#   'zat': ['M8', 'C1', 'P1', 'G1.1', 'G2.1', 'M6', 'A9+'],
#   'Volgens': ['Z99'],
#   'artsen': ['B3/S2mf'],
#   'één': ['N1', 'T3', 'T1.2', 'Z8'],
#   'gelukkigen': ['E4.1+', 'E4.2+'],
#   'die': ['Z99'],
#   'nu': ['T1.1.2', 'Z4', 'Z5'],
#   'achter': ['B1', 'M6', 'A6.1-', 'Z5'],
#   'zich': ['Z99'],
#   'mooi': ['O4.2+', 'S1.2.1+'],
#   'om': ['Z99'],
#   'kroeg': ['F2', 'F2/H1'],
#   'vertellen': ['Q2.2', 'Q2.1', 'X3', 'A10+'],
#   'De': ['Z5'],
#   '1–0': ['Z99'],
#   'voordeel': ['A5.1+', 'K5.2'],
#   'Maar': ['A13.6', 'Z5'],
#   'later': ['T4-', 'L1-', 'T1.1'],
#   'leerde': ['X2.3+', 'P1'],
#   'harde': ['O4.1', 'X8+', 'X5.2+', 'N5+', 'A12-', 'O4.5', 'S1.2.5+'],
#   'manier': ['A13.3', 'X4.2', 'M6', 'M3/H3', 'N3.3', 'A4.1', 'A1.1.1', 'T1.3'],
#   'deze': ['Z99'],
#   'rotzooi': ['Z99'],
#   'via': ['M6', 'Z5'],
#   'bloedbaan': ['Z99'],
#   'kan': ['Z99'],
#   'reizen': ['M1'],
#   'januari': ['T1.3'],
#   '2021': ['N1'],
#   'liet': ['S7.4+', 'I2.2/H1', 'T2-'],
#   'routine-scan': ['Z99'],
#   'niet': ['Z6'],
#   'zulk': ['Z5', 'Z8'],
#   'goed': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'zien': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'meerdere': ['Z99'],
#   'laesies': ['Z99'],
#   'lever': ['Z99'],
#   'chirurg': ['Z99'],
#   'zei': ['Q2.1', 'Z4%'],
#   'opereren': ['A1.1.1', 'B3'],
#   'stortte': ['Z99'],
#   'wereld': ['W1', 'S5+c', 'A4.1', 'N5+'],
#   '4': ['N1'],
#   'niet-operabele': ['Z99'],
#   'levermetastasen': ['Z99'],
#   'thuis': ['Z99'],
#   'twee': ['N1', 'T3', 'T1.2'],
#   'zoontjes': ['Z99'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'zonder': ['M6', 'Z5'],
#   'vader': ['S4/B1', 'S4m', 'S9/S2.2m'],
#   'wilde': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'achterlaten': ['M1', 'M2', 'A1.1.1', 'A1.9', 'A9-', 'T2-'],
#   'Dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'gebeurde': ['A2.1+', 'A3+', 'X7-'],
#   'allemaal': ['Z8/N5.1+'],
#   'tijdens': ['Z5'],
#   'coronapandemie': ['Z99'],
#   'familie': ['S4c', 'A4.1c'],
#   'kinderen': ['S2mf/T3-', 'S4mf'],
#   'door': ['M6', 'Z5'],
#   'ziekenhuisbeperkingen': ['Z99'],
#   'altijd': ['N6+++'],
#   'bij': ['Z99'],
#   'me': ['Z8mf'],
#   'konden': ['Z99'],
#   'zijn': ['A3+', 'Z5'],
#   'Toch': ['T1.1.2', 'Z5'],
#   'ben': ['A3+', 'Z5'],
#   'geen': ['S8-', 'Z4', 'Z6'],
#   'opgever': ['Z99'],
#   'zag': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'als': ['Z5'],
#   'nieuwe': ['T3-'],
#   'uitdaging': ['A12-', 'A6.1-', 'S7.3+', 'E3-', 'Q2.2'],
#   'moest': ['Z99'],
#   'overwinnen': ['X9.2+/S7.3', 'X9.2+/G3', 'A2.2/E1', 'B2-'],
#   'Met': ['Z5'],
#   'lage': ['A5.1-',
#    'L2/Q2.1',
#    'N3.7-',
#    'N5-',
#    'A11.1-',
#    'E4.1-',
#    'X3.2-',
#    'G2.2-',
#    'S7.1-'],
#   'overlevingskansen': ['Z99'],
#   'begon': ['T2+', 'E5-', 'E3-'],
#   'aan': ['Z99'],
#   'anderhalf': ['Z99'],
#   'jaar': ['T1.3', 'P1c'],
#   'chemo-': ['Z99'],
#   'radiotherapie': ['Z99'],
#   'flink': ['A11.1+', 'N5+'],
#   'donder': ['Z99'],
#   'gaven': ['A9-', 'A1.1.1'],
#   'ervoor': ['Z99'],
#   'zorgden': ['A9-', 'S6+'],
#   'kankervrij': ['Z99'],
#   'werd': ['A3+', 'Z5'],
#   'eens': ['A13.1', 'A6.1+', 'O4.4', 'A1.4', 'N1', 'T1.3', 'Z5'],
#   'leveroperatie': ['Z99'],
#   'nodig': ['S6+', 'A11.1+'],
#   '2–0': ['Z99'],
#   'we': ['Z8'],
#   'hoopten': ['Z99'],
#   'zou': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'terugkeren': ['M1', 'A9-', 'N6'],
#   'kwam': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'inderdaad': ['A13.3'],
#   'terug': ['B1',
#    'M6',
#    'N6+',
#    'T1.1.1',
#    'S1.1.2+',
#    'T3+',
#    'S8+',
#    'K5.1/I1',
#    'M1',
#    'K2'],
#   'maken': ['Z99'],
#   'iets': ['Z8'],
#   'compleet': ['N5.1+', 'T2-', 'N3.2+', 'Q1.2'],
#   'Bij': ['Z99'],
#   'routineonderzoek': ['Z99'],
#   'verdachten': ['Z99'],
#   'dokters': ['Z99'],
#   'schildklier': ['Z99'],
#   'Na': ['N4', 'Z5'],
#   'extra': ['N5++'],
#   'scans': ['Z99'],
#   'naaldbiopsie': ['Z99'],
#   'horen': ['X3.2', 'X2.3+', 'G2.1@'],
#   'schildklierkanker': ['Z99'],
#   'dacht': ['X2.1'],
#   'mezelf': ['Z8mf'],
#   ':': ['PUNCT'],
#   '“': ['N1'],
#   'Ach': ['Z4'],
#   'is': ['A3+', 'Z5'],
#   'gemakkelijk': ['A12+'],
#   'tackelen': ['Z99'],
#   '”': ['Z99'],
#   'Gisteren': ['T1.1.1'],
#   'hele': ['N5.1+'],
#   'staat': ['M6',
#    'M2',
#    'M8',
#    'M1',
#    'T2++',
#    'N3',
#    'A3+',
#    'X2.1',
#    'A7',
#    'G1.2',
#    'S8+',
#    'S7.4+',
#    'I2.2',
#    'S1.2.5+'],
#   'wat': ['Z8', 'Z5'],
#   'hierna': ['Z99'],
#   'wachten': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1%'],
#   'er': ['M6', 'T1.2', 'Z5'],
#   'komt': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'rotziekte': ['Z99'],
#   'blijven': ['T2++', 'M8', 'N5.2+'],
#   'vechten': ['S8-', 'X8+', 'E3-', 'G1.2'],
#   'tussentijd': ['Z99'],
#   'krijg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'iedere': ['N5.1+', 'S1.1.2+'],
#   'zes': ['N1', 'T3', 'T1.2'],
#   'maanden': ['T1.3'],
#   'preventieve': ['Z99'],
#   'chemotherapie': ['Z99'],
#   'geniet': ['E2+', 'A9+', 'E4.1+'],
#   'ervan': ['Z99'],
#   'samen': ['Z99'],
#   'Dus': ['A13.3', 'Z5'],
#   'kameraad': ['S3.1/S2mf'],
#   'zie': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'jouw': ['Z8'],
#   'situatie': ['A3+', 'O4.1', 'M6', 'I3.1@'],
#   'Wat': ['Z8', 'Z5'],
#   'leven': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'brengt': ['M2', 'A2.2'],
#   'hebt': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'kracht': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2@'],
#   'optimisme': ['Z99'],
#   'zetten': ['M2', 'Q2.1', 'Q2.2', 'A1.1.1'],
#   'Houd': ['Z99'],
#   'hoofd': ['B1',
#    'S7.1+/S2mf',
#    'P1/S2mf',
#    'X1',
#    'M6',
#    'A4.1',
#    'S2mf',
#    'F2',
#    'H5/M4%',
#    'S7.1+',
#    'K5.1',
#    'M1',
#    'N5',
#    'A2.1+',
#    'A11.1+',
#    'Q1.2',
#    'T1.1.3'],
#   'omhoog': ['M6', 'N4', 'N5++', 'T2-', 'X9.1+', 'A1.1.1', 'N5+/A2.1', 'Z5'],
#   'blijf': ['Z99'],
#   'scoren': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   '!': ['PUNCT']},
#  5: {'\n\n': ['Z99'],
#   'Hallo': ['S1.1.1', 'Z4'],
#   'kameraden': ['S3.1/S2mf'],
#   ',': ['PUNCT'],
#   'ik': ['Z8mf'],
#   'wil': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'met': ['Z5'],
#   'jullie': ['Z8mf'],
#   'mijn': ['Z8'],
#   'ervaring': ['A2.1+/A3+', 'X3', 'X2.2+', 'X9.1+', 'I3.2'],
#   'delen': ['S1.1.2+'],
#   'over': ['Z99'],
#   'hoe': ['Z5', 'A13.3'],
#   'na': ['N4', 'Z5'],
#   'een': ['Z5'],
#   'operatie': ['A1.1.1', 'B3', 'G3'],
#   'tegen': ['A5.1-', 'S8-', 'Z5'],
#   'kanker': ['B2-'],
#   'opnieuw': ['N6+', 'Z4'],
#   'doelpunt': ['K5.1', 'X7+'],
#   'scoorde': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   'en': ['Z5'],
#   'de': ['Z5'],
#   'stand': ['Z99'],
#   'op': ['A5.1+', 'G2.2+', 'A1.1.1', 'M6', 'Z5'],
#   '3–0': ['N1'],
#   'bracht': ['M2', 'A2.2'],
#   '.': ['PUNCT'],
#   'Ik': ['Z8mf'],
#   'hoop': ['X2.6+', 'E4.1+', 'X9.2+', 'A5.1+'],
#   'dat': ['A13.3', 'A6.1+', 'Z5', 'Z8'],
#   'dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'verhaal': ['Q2.1', 'X4.1', 'Q4'],
#   'iemand': ['Z8mfc'],
#   'daarbuiten': ['M6', 'S1.1.3-', 'S5-', 'Z5'],
#   'zal': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'inspireren': ['S8+'],
#   'In': ['M6', 'O4.2+', 'Z5'],
#   'mei': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'kreeg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'diagnose': ['B3', 'X4.1'],
#   'darmkanker': ['Z99'],
#   'toen': ['Z5'],
#   'ernstige': ['A11.1+', 'A15-', 'E4.1-'],
#   'bloedingen': ['Z99'],
#   'had': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'je': ['Z8mf'],
#   'weet': ['X2.2+', 'S3.2/B1%'],
#   'wel': ['Z99'],
#   'waar': ['A5.2+', 'A5.4+'],
#   'Voordat': ['N4', 'Z5'],
#   'het': ['Z99'],
#   'doorhad': ['Z99'],
#   'hadden': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'chirurgen': ['Z99'],
#   'al': ['T1.1.1'],
#   '30': ['N1'],
#   'cm': ['N3.7', 'N3.3'],
#   'van': ['Z5'],
#   'dikke': ['N3.7',
#    'O4.5',
#    'N3.7+',
#    'N3.2+',
#    'N5+',
#    'X9.1-',
#    'A10-',
#    'A11.2+',
#    'O4.3@',
#    'O4.2-@'],
#   'darm': ['Z99'],
#   'verwijderd': ['M2'],
#   'Het': ['Z99'],
#   'herstel': ['B2+', 'A5.1+/A2.1', 'A9+'],
#   'was': ['A3+', 'Z5'],
#   'zwaar': ['N3.5+',
#    'N5+',
#    'S1.2.5+',
#    'O4.1',
#    'E4.1-',
#    'W4',
#    'A12-',
#    'A1.1.1',
#    'N3.2+',
#    'A1.1.2@',
#    'S1.2.5+/S2mf'],
#   'maar': ['A13.6', 'Z5'],
#   'te': ['Z99'],
#   'doen': ['A1.1.1', 'G2.2-', 'X9.2+', 'E3-', 'N5+', 'G2.1%', 'Z5'],
#   'goede': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'nieuws': ['X2.2+/T3-', 'X2.2+/Q4.2', 'X2.2+/Q4.3'],
#   'ook': ['N5++'],
#   'tumor': ['Z99'],
#   'groot': ['Z99'],
#   'lymfeklieren': ['Z99'],
#   'schoon': ['B4', 'O4.2+', 'G2.2+'],
#   'waren': ['A3+', 'Z5'],
#   'waardoor': ['Z99'],
#   'in': ['M6', 'O4.2+', 'Z5'],
#   'stadium': ['K4', 'A1.1.1', 'A5.4-', 'T1.2', 'N5.1-', 'H2/K4', 'A4.1'],
#   '2': ['N1'],
#   'zat': ['M8', 'C1', 'P1', 'G1.1', 'G2.1', 'M6', 'A9+'],
#   'Volgens': ['Z99'],
#   'artsen': ['B3/S2mf'],
#   'één': ['N1', 'T3', 'T1.2', 'Z8'],
#   'gelukkigen': ['E4.1+', 'E4.2+'],
#   'die': ['Z99'],
#   'nu': ['T1.1.2', 'Z4', 'Z5'],
#   'achter': ['B1', 'M6', 'A6.1-', 'Z5'],
#   'zich': ['Z99'],
#   'mooi': ['O4.2+', 'S1.2.1+'],
#   'om': ['Z99'],
#   'kroeg': ['F2', 'F2/H1'],
#   'vertellen': ['Q2.2', 'Q2.1', 'X3', 'A10+'],
#   'De': ['Z5'],
#   '1–0': ['Z99'],
#   'voordeel': ['A5.1+', 'K5.2'],
#   'Maar': ['A13.6', 'Z5'],
#   'later': ['T4-', 'L1-', 'T1.1'],
#   'leerde': ['X2.3+', 'P1'],
#   'harde': ['O4.1', 'X8+', 'X5.2+', 'N5+', 'A12-', 'O4.5', 'S1.2.5+'],
#   'manier': ['A13.3', 'X4.2', 'M6', 'M3/H3', 'N3.3', 'A4.1', 'A1.1.1', 'T1.3'],
#   'deze': ['Z99'],
#   'rotzooi': ['Z99'],
#   'via': ['M6', 'Z5'],
#   'bloedbaan': ['Z99'],
#   'kan': ['Z99'],
#   'reizen': ['M1'],
#   'januari': ['T1.3'],
#   '2021': ['N1'],
#   'liet': ['S7.4+', 'I2.2/H1', 'T2-'],
#   'routine-scan': ['Z99'],
#   'niet': ['Z6'],
#   'zulk': ['Z5', 'Z8'],
#   'goed': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'zien': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'meerdere': ['Z99'],
#   'laesies': ['Z99'],
#   'lever': ['Z99'],
#   'chirurg': ['Z99'],
#   'zei': ['Q2.1', 'Z4%'],
#   'opereren': ['A1.1.1', 'B3'],
#   'stortte': ['Z99'],
#   'wereld': ['W1', 'S5+c', 'A4.1', 'N5+'],
#   '4': ['N1'],
#   'niet-operabele': ['Z99'],
#   'levermetastasen': ['Z99'],
#   'thuis': ['Z99'],
#   'twee': ['N1', 'T3', 'T1.2'],
#   'zoontjes': ['Z99'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'zonder': ['M6', 'Z5'],
#   'vader': ['S4/B1', 'S4m', 'S9/S2.2m'],
#   'wilde': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'achterlaten': ['M1', 'M2', 'A1.1.1', 'A1.9', 'A9-', 'T2-'],
#   'Dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'gebeurde': ['A2.1+', 'A3+', 'X7-'],
#   'allemaal': ['Z8/N5.1+'],
#   'tijdens': ['Z5'],
#   'coronapandemie': ['Z99'],
#   'familie': ['S4c', 'A4.1c'],
#   'kinderen': ['S2mf/T3-', 'S4mf'],
#   'door': ['M6', 'Z5'],
#   'ziekenhuisbeperkingen': ['Z99'],
#   'altijd': ['N6+++'],
#   'bij': ['Z99'],
#   'me': ['Z8mf'],
#   'konden': ['Z99'],
#   'zijn': ['A3+', 'Z5'],
#   'Toch': ['T1.1.2', 'Z5'],
# ...
#   'darmkanker': ['Z99'],
#   'toen': ['Z5'],
#   'ernstige': ['A11.1+', 'A15-', 'E4.1-'],
#   'bloedingen': ['Z99'],
#   'had': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'je': ['Z8mf'],
#   'weet': ['X2.2+', 'S3.2/B1%'],
#   'wel': ['Z99'],
#   'waar': ['A5.2+', 'A5.4+'],
#   'Voordat': ['N4', 'Z5'],
#   'het': ['Z99'],
#   'doorhad': ['Z99'],
#   'hadden': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'chirurgen': ['Z99'],
#   'al': ['T1.1.1'],
#   '30': ['N1'],
#   'cm': ['N3.7', 'N3.3'],
#   'van': ['Z5'],
#   'dikke': ['N3.7',
#    'O4.5',
#    'N3.7+',
#    'N3.2+',
#    'N5+',
#    'X9.1-',
#    'A10-',
#    'A11.2+',
#    'O4.3@',
#    'O4.2-@'],
#   'darm': ['Z99'],
#   'verwijderd': ['M2'],
#   'Het': ['Z99'],
#   'herstel': ['B2+', 'A5.1+/A2.1', 'A9+'],
#   'was': ['A3+', 'Z5'],
#   'zwaar': ['N3.5+',
#    'N5+',
#    'S1.2.5+',
#    'O4.1',
#    'E4.1-',
#    'W4',
#    'A12-',
#    'A1.1.1',
#    'N3.2+',
#    'A1.1.2@',
#    'S1.2.5+/S2mf'],
#   'maar': ['A13.6', 'Z5'],
#   'te': ['Z99'],
#   'doen': ['A1.1.1', 'G2.2-', 'X9.2+', 'E3-', 'N5+', 'G2.1%', 'Z5'],
#   'goede': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'nieuws': ['X2.2+/T3-', 'X2.2+/Q4.2', 'X2.2+/Q4.3'],
#   'ook': ['N5++'],
#   'tumor': ['Z99'],
#   'groot': ['Z99'],
#   'lymfeklieren': ['Z99'],
#   'schoon': ['B4', 'O4.2+', 'G2.2+'],
#   'waren': ['A3+', 'Z5'],
#   'waardoor': ['Z99'],
#   'in': ['M6', 'O4.2+', 'Z5'],
#   'stadium': ['K4', 'A1.1.1', 'A5.4-', 'T1.2', 'N5.1-', 'H2/K4', 'A4.1'],
#   '2': ['N1'],
#   'zat': ['M8', 'C1', 'P1', 'G1.1', 'G2.1', 'M6', 'A9+'],
#   'Volgens': ['Z99'],
#   'artsen': ['B3/S2mf'],
#   'één': ['N1', 'T3', 'T1.2', 'Z8'],
#   'gelukkigen': ['E4.1+', 'E4.2+'],
#   'die': ['Z99'],
#   'nu': ['T1.1.2', 'Z4', 'Z5'],
#   'achter': ['B1', 'M6', 'A6.1-', 'Z5'],
#   'zich': ['Z99'],
#   'mooi': ['O4.2+', 'S1.2.1+'],
#   'om': ['Z99'],
#   'kroeg': ['F2', 'F2/H1'],
#   'vertellen': ['Q2.2', 'Q2.1', 'X3', 'A10+'],
#   'De': ['Z5'],
#   '1–0': ['Z99'],
#   'voordeel': ['A5.1+', 'K5.2'],
#   'Maar': ['A13.6', 'Z5'],
#   'later': ['T4-', 'L1-', 'T1.1'],
#   'leerde': ['X2.3+', 'P1'],
#   'harde': ['O4.1', 'X8+', 'X5.2+', 'N5+', 'A12-', 'O4.5', 'S1.2.5+'],
#   'manier': ['A13.3', 'X4.2', 'M6', 'M3/H3', 'N3.3', 'A4.1', 'A1.1.1', 'T1.3'],
#   'deze': ['Z99'],
#   'rotzooi': ['Z99'],
#   'via': ['M6', 'Z5'],
#   'bloedbaan': ['Z99'],
#   'kan': ['Z99'],
#   'reizen': ['M1'],
#   'januari': ['T1.3'],
#   '2021': ['N1'],
#   'liet': ['S7.4+', 'I2.2/H1', 'T2-'],
#   'routine-scan': ['Z99'],
#   'niet': ['Z6'],
#   'zulk': ['Z5', 'Z8'],
#   'goed': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'zien': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'meerdere': ['Z99'],
#   'laesies': ['Z99'],
#   'lever': ['Z99'],
#   'chirurg': ['Z99'],
#   'zei': ['Q2.1', 'Z4%'],
#   'opereren': ['A1.1.1', 'B3'],
#   'stortte': ['Z99'],
#   'wereld': ['W1', 'S5+c', 'A4.1', 'N5+'],
#   '4': ['N1'],
#   'niet-operabele': ['Z99'],
#   'levermetastasen': ['Z99'],
#   'thuis': ['Z99'],
#   'twee': ['N1', 'T3', 'T1.2'],
#   'zoontjes': ['Z99'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'zonder': ['M6', 'Z5'],
#   'vader': ['S4/B1', 'S4m', 'S9/S2.2m'],
#   'wilde': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'achterlaten': ['M1', 'M2', 'A1.1.1', 'A1.9', 'A9-', 'T2-'],
#   'Dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'gebeurde': ['A2.1+', 'A3+', 'X7-'],
#   'allemaal': ['Z8/N5.1+'],
#   'tijdens': ['Z5'],
#   'coronapandemie': ['Z99'],
#   'familie': ['S4c', 'A4.1c'],
#   'kinderen': ['S2mf/T3-', 'S4mf'],
#   'door': ['M6', 'Z5'],
#   'ziekenhuisbeperkingen': ['Z99'],
#   'altijd': ['N6+++'],
#   'bij': ['Z99'],
#   'me': ['Z8mf'],
#   'konden': ['Z99'],
#   'zijn': ['A3+', 'Z5'],
#   'Toch': ['T1.1.2', 'Z5'],
#   'ben': ['A3+', 'Z5'],
#   'geen': ['S8-', 'Z4', 'Z6'],
#   'opgever': ['Z99'],
#   'zag': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'als': ['Z5'],
#   'nieuwe': ['T3-'],
#   'uitdaging': ['A12-', 'A6.1-', 'S7.3+', 'E3-', 'Q2.2'],
#   'moest': ['Z99'],
#   'overwinnen': ['X9.2+/S7.3', 'X9.2+/G3', 'A2.2/E1', 'B2-'],
#   'Met': ['Z5'],
#   'lage': ['A5.1-',
#    'L2/Q2.1',
#    'N3.7-',
#    'N5-',
#    'A11.1-',
#    'E4.1-',
#    'X3.2-',
#    'G2.2-',
#    'S7.1-'],
#   'overlevingskansen': ['Z99'],
#   'begon': ['T2+', 'E5-', 'E3-'],
#   'aan': ['Z99'],
#   'anderhalf': ['Z99'],
#   'jaar': ['T1.3', 'P1c'],
#   'chemo-': ['Z99'],
#   'radiotherapie': ['Z99'],
#   'flink': ['A11.1+', 'N5+'],
#   'donder': ['Z99'],
#   'gaven': ['A9-', 'A1.1.1'],
#   'ervoor': ['Z99'],
#   'zorgden': ['A9-', 'S6+'],
#   'kankervrij': ['Z99'],
#   'werd': ['A3+', 'Z5'],
#   'eens': ['A13.1', 'A6.1+', 'O4.4', 'A1.4', 'N1', 'T1.3', 'Z5'],
#   'leveroperatie': ['Z99'],
#   'nodig': ['S6+', 'A11.1+'],
#   '2–0': ['Z99'],
#   'we': ['Z8'],
#   'hoopten': ['Z99'],
#   'zou': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'terugkeren': ['M1', 'A9-', 'N6'],
#   'kwam': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'inderdaad': ['A13.3'],
#   'terug': ['B1',
#    'M6',
#    'N6+',
#    'T1.1.1',
#    'S1.1.2+',
#    'T3+',
#    'S8+',
#    'K5.1/I1',
#    'M1',
#    'K2'],
#   'maken': ['Z99'],
#   'iets': ['Z8'],
#   'compleet': ['N5.1+', 'T2-', 'N3.2+', 'Q1.2'],
#   'Bij': ['Z99'],
#   'routineonderzoek': ['Z99'],
#   'verdachten': ['Z99'],
#   'dokters': ['Z99'],
#   'schildklier': ['Z99'],
#   'Na': ['N4', 'Z5'],
#   'extra': ['N5++'],
#   'scans': ['Z99'],
#   'naaldbiopsie': ['Z99'],
#   'horen': ['X3.2', 'X2.3+', 'G2.1@'],
#   'schildklierkanker': ['Z99'],
#   'dacht': ['X2.1'],
#   'mezelf': ['Z8mf'],
#   ':': ['PUNCT'],
#   '“': ['N1'],
#   'Ach': ['Z4'],
#   'is': ['A3+', 'Z5'],
#   'gemakkelijk': ['A12+'],
#   'tackelen': ['Z99'],
#   '”': ['Z99'],
#   'Gisteren': ['T1.1.1'],
#   'hele': ['N5.1+'],
#   'staat': ['M6',
#    'M2',
#    'M8',
#    'M1',
#    'T2++',
#    'N3',
#    'A3+',
#    'X2.1',
#    'A7',
#    'G1.2',
#    'S8+',
#    'S7.4+',
#    'I2.2',
#    'S1.2.5+'],
#   'wat': ['Z8', 'Z5'],
#   'hierna': ['Z99'],
#   'wachten': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1%'],
#   'er': ['M6', 'T1.2', 'Z5'],
#   'komt': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'rotziekte': ['Z99'],
#   'blijven': ['T2++', 'M8', 'N5.2+'],
#   'vechten': ['S8-', 'X8+', 'E3-', 'G1.2'],
#   'tussentijd': ['Z99'],
#   'krijg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'iedere': ['N5.1+', 'S1.1.2+'],
#   'zes': ['N1', 'T3', 'T1.2'],
#   'maanden': ['T1.3'],
#   'preventieve': ['Z99'],
#   'chemotherapie': ['Z99'],
#   'geniet': ['E2+', 'A9+', 'E4.1+'],
#   'ervan': ['Z99'],
#   'samen': ['Z99'],
#   'Dus': ['A13.3', 'Z5'],
#   'kameraad': ['S3.1/S2mf'],
#   'zie': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'jouw': ['Z8'],
#   'situatie': ['A3+', 'O4.1', 'M6', 'I3.1@'],
#   'Wat': ['Z8', 'Z5'],
#   'leven': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'brengt': ['M2', 'A2.2'],
#   'hebt': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'kracht': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2@'],
#   'optimisme': ['Z99'],
#   'zetten': ['M2', 'Q2.1', 'Q2.2', 'A1.1.1'],
#   'Houd': ['Z99'],
#   'hoofd': ['B1',
#    'S7.1+/S2mf',
#    'P1/S2mf',
#    'X1',
#    'M6',
#    'A4.1',
#    'S2mf',
#    'F2',
#    'H5/M4%',
#    'S7.1+',
#    'K5.1',
#    'M1',
#    'N5',
#    'A2.1+',
#    'A11.1+',
#    'Q1.2',
#    'T1.1.3'],
#   'omhoog': ['M6', 'N4', 'N5++', 'T2-', 'X9.1+', 'A1.1.1', 'N5+/A2.1', 'Z5'],
#   'blijf': ['Z99'],
#   'scoren': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   '!': ['PUNCT']},
#  27: {'\n\n': ['Z99'],
#   'Hallo': ['S1.1.1', 'Z4'],
#   'kameraden': ['S3.1/S2mf'],
#   ',': ['PUNCT'],
#   'ik': ['Z8mf'],
#   'wil': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'met': ['Z5'],
#   'jullie': ['Z8mf'],
#   'mijn': ['Z8'],
#   'ervaring': ['A2.1+/A3+', 'X3', 'X2.2+', 'X9.1+', 'I3.2'],
#   'delen': ['S1.1.2+'],
#   'over': ['Z99'],
#   'hoe': ['Z5', 'A13.3'],
#   'na': ['N4', 'Z5'],
#   'een': ['Z5'],
#   'operatie': ['A1.1.1', 'B3', 'G3'],
#   'tegen': ['A5.1-', 'S8-', 'Z5'],
#   'kanker': ['B2-'],
#   'opnieuw': ['N6+', 'Z4'],
#   'doelpunt': ['K5.1', 'X7+'],
#   'scoorde': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   'en': ['Z5'],
#   'de': ['Z5'],
#   'stand': ['Z99'],
#   'op': ['A5.1+', 'G2.2+', 'A1.1.1', 'M6', 'Z5'],
#   '3–0': ['N1'],
#   'bracht': ['M2', 'A2.2'],
#   '.': ['PUNCT'],
#   'Ik': ['Z8mf'],
#   'hoop': ['X2.6+', 'E4.1+', 'X9.2+', 'A5.1+'],
#   'dat': ['A13.3', 'A6.1+', 'Z5', 'Z8'],
#   'dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'verhaal': ['Q2.1', 'X4.1', 'Q4'],
#   'iemand': ['Z8mfc'],
#   'daarbuiten': ['M6', 'S1.1.3-', 'S5-', 'Z5'],
#   'zal': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'inspireren': ['S8+'],
#   'In': ['M6', 'O4.2+', 'Z5'],
#   'mei': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'kreeg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'diagnose': ['B3', 'X4.1'],
#   'darmkanker': ['Z99'],
#   'toen': ['Z5'],
#   'ernstige': ['A11.1+', 'A15-', 'E4.1-'],
#   'bloedingen': ['Z99'],
#   'had': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'je': ['Z8mf'],
#   'weet': ['X2.2+', 'S3.2/B1%'],
#   'wel': ['Z99'],
#   'waar': ['A5.2+', 'A5.4+'],
#   'Voordat': ['N4', 'Z5'],
#   'het': ['Z99'],
#   'doorhad': ['Z99'],
#   'hadden': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'chirurgen': ['Z99'],
#   'al': ['T1.1.1'],
#   '30': ['N1'],
#   'cm': ['N3.7', 'N3.3'],
#   'van': ['Z5'],
#   'dikke': ['N3.7',
#    'O4.5',
#    'N3.7+',
#    'N3.2+',
#    'N5+',
#    'X9.1-',
#    'A10-',
#    'A11.2+',
#    'O4.3@',
#    'O4.2-@'],
#   'darm': ['Z99'],
#   'verwijderd': ['M2'],
#   'Het': ['Z99'],
#   'herstel': ['B2+', 'A5.1+/A2.1', 'A9+'],
#   'was': ['A3+', 'Z5'],
#   'zwaar': ['N3.5+',
#    'N5+',
#    'S1.2.5+',
#    'O4.1',
#    'E4.1-',
#    'W4',
#    'A12-',
#    'A1.1.1',
#    'N3.2+',
#    'A1.1.2@',
#    'S1.2.5+/S2mf'],
#   'maar': ['A13.6', 'Z5'],
#   'te': ['Z99'],
#   'doen': ['A1.1.1', 'G2.2-', 'X9.2+', 'E3-', 'N5+', 'G2.1%', 'Z5'],
#   'goede': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'nieuws': ['X2.2+/T3-', 'X2.2+/Q4.2', 'X2.2+/Q4.3'],
#   'ook': ['N5++'],
#   'tumor': ['Z99'],
#   'groot': ['Z99'],
#   'lymfeklieren': ['Z99'],
#   'schoon': ['B4', 'O4.2+', 'G2.2+'],
#   'waren': ['A3+', 'Z5'],
#   'waardoor': ['Z99'],
#   'in': ['M6', 'O4.2+', 'Z5'],
#   'stadium': ['K4', 'A1.1.1', 'A5.4-', 'T1.2', 'N5.1-', 'H2/K4', 'A4.1'],
#   '2': ['N1'],
#   'zat': ['M8', 'C1', 'P1', 'G1.1', 'G2.1', 'M6', 'A9+'],
#   'Volgens': ['Z99'],
#   'artsen': ['B3/S2mf'],
#   'één': ['N1', 'T3', 'T1.2', 'Z8'],
#   'gelukkigen': ['E4.1+', 'E4.2+'],
#   'die': ['Z99'],
#   'nu': ['T1.1.2', 'Z4', 'Z5'],
#   'achter': ['B1', 'M6', 'A6.1-', 'Z5'],
#   'zich': ['Z99'],
#   'mooi': ['O4.2+', 'S1.2.1+'],
#   'om': ['Z99'],
#   'kroeg': ['F2', 'F2/H1'],
#   'vertellen': ['Q2.2', 'Q2.1', 'X3', 'A10+'],
#   'De': ['Z5'],
#   '1–0': ['Z99'],
#   'voordeel': ['A5.1+', 'K5.2'],
#   'Maar': ['A13.6', 'Z5'],
#   'later': ['T4-', 'L1-', 'T1.1'],
#   'leerde': ['X2.3+', 'P1'],
#   'harde': ['O4.1', 'X8+', 'X5.2+', 'N5+', 'A12-', 'O4.5', 'S1.2.5+'],
#   'manier': ['A13.3', 'X4.2', 'M6', 'M3/H3', 'N3.3', 'A4.1', 'A1.1.1', 'T1.3'],
#   'deze': ['Z99'],
#   'rotzooi': ['Z99'],
#   'via': ['M6', 'Z5'],
#   'bloedbaan': ['Z99'],
#   'kan': ['Z99'],
#   'reizen': ['M1'],
#   'januari': ['T1.3'],
#   '2021': ['N1'],
#   'liet': ['S7.4+', 'I2.2/H1', 'T2-'],
#   'routine-scan': ['Z99'],
#   'niet': ['Z6'],
#   'zulk': ['Z5', 'Z8'],
#   'goed': ['A5.1+', 'G2.2+', 'A1.5.2+', 'O4.2+', 'N3.2+'],
#   'zien': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'meerdere': ['Z99'],
#   'laesies': ['Z99'],
#   'lever': ['Z99'],
#   'chirurg': ['Z99'],
#   'zei': ['Q2.1', 'Z4%'],
#   'opereren': ['A1.1.1', 'B3'],
#   'stortte': ['Z99'],
#   'wereld': ['W1', 'S5+c', 'A4.1', 'N5+'],
#   '4': ['N1'],
#   'niet-operabele': ['Z99'],
#   'levermetastasen': ['Z99'],
#   'thuis': ['Z99'],
#   'twee': ['N1', 'T3', 'T1.2'],
#   'zoontjes': ['Z99'],
#   '3': ['N1'],
#   '5': ['N1'],
#   'zonder': ['M6', 'Z5'],
#   'vader': ['S4/B1', 'S4m', 'S9/S2.2m'],
#   'wilde': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'achterlaten': ['M1', 'M2', 'A1.1.1', 'A1.9', 'A9-', 'T2-'],
#   'Dit': ['A13.3', 'M6', 'Z5', 'Z8'],
#   'gebeurde': ['A2.1+', 'A3+', 'X7-'],
#   'allemaal': ['Z8/N5.1+'],
#   'tijdens': ['Z5'],
#   'coronapandemie': ['Z99'],
#   'familie': ['S4c', 'A4.1c'],
#   'kinderen': ['S2mf/T3-', 'S4mf'],
#   'door': ['M6', 'Z5'],
#   'ziekenhuisbeperkingen': ['Z99'],
#   'altijd': ['N6+++'],
#   'bij': ['Z99'],
#   'me': ['Z8mf'],
#   'konden': ['Z99'],
#   'zijn': ['A3+', 'Z5'],
#   'Toch': ['T1.1.2', 'Z5'],
#   'ben': ['A3+', 'Z5'],
#   'geen': ['S8-', 'Z4', 'Z6'],
#   'opgever': ['Z99'],
#   'zag': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'als': ['Z5'],
#   'nieuwe': ['T3-'],
#   'uitdaging': ['A12-', 'A6.1-', 'S7.3+', 'E3-', 'Q2.2'],
#   'moest': ['Z99'],
#   'overwinnen': ['X9.2+/S7.3', 'X9.2+/G3', 'A2.2/E1', 'B2-'],
#   'Met': ['Z5'],
#   'lage': ['A5.1-',
#    'L2/Q2.1',
#    'N3.7-',
#    'N5-',
#    'A11.1-',
#    'E4.1-',
#    'X3.2-',
#    'G2.2-',
#    'S7.1-'],
#   'overlevingskansen': ['Z99'],
#   'begon': ['T2+', 'E5-', 'E3-'],
#   'aan': ['Z99'],
#   'anderhalf': ['Z99'],
#   'jaar': ['T1.3', 'P1c'],
#   'chemo-': ['Z99'],
#   'radiotherapie': ['Z99'],
#   'flink': ['A11.1+', 'N5+'],
#   'donder': ['Z99'],
#   'gaven': ['A9-', 'A1.1.1'],
#   'ervoor': ['Z99'],
#   'zorgden': ['A9-', 'S6+'],
#   'kankervrij': ['Z99'],
#   'werd': ['A3+', 'Z5'],
#   'eens': ['A13.1', 'A6.1+', 'O4.4', 'A1.4', 'N1', 'T1.3', 'Z5'],
#   'leveroperatie': ['Z99'],
#   'nodig': ['S6+', 'A11.1+'],
#   '2–0': ['Z99'],
#   'we': ['Z8'],
#   'hoopten': ['Z99'],
#   'zou': ['T1.1.3', 'X7+', 'G2.1/Q1.2'],
#   'terugkeren': ['M1', 'A9-', 'N6'],
#   'kwam': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'inderdaad': ['A13.3'],
#   'terug': ['B1',
#    'M6',
#    'N6+',
#    'T1.1.1',
#    'S1.1.2+',
#    'T3+',
#    'S8+',
#    'K5.1/I1',
#    'M1',
#    'K2'],
#   'maken': ['Z99'],
#   'iets': ['Z8'],
#   'compleet': ['N5.1+', 'T2-', 'N3.2+', 'Q1.2'],
#   'Bij': ['Z99'],
#   'routineonderzoek': ['Z99'],
#   'verdachten': ['Z99'],
#   'dokters': ['Z99'],
#   'schildklier': ['Z99'],
#   'Na': ['N4', 'Z5'],
#   'extra': ['N5++'],
#   'scans': ['Z99'],
#   'naaldbiopsie': ['Z99'],
#   'horen': ['X3.2', 'X2.3+', 'G2.1@'],
#   'schildklierkanker': ['Z99'],
#   'dacht': ['X2.1'],
#   'mezelf': ['Z8mf'],
#   ':': ['PUNCT'],
#   '“': ['N1'],
#   'Ach': ['Z4'],
#   'is': ['A3+', 'Z5'],
#   'gemakkelijk': ['A12+'],
#   'tackelen': ['Z99'],
#   '”': ['Z99'],
#   'Gisteren': ['T1.1.1'],
#   'hele': ['N5.1+'],
#   'staat': ['M6',
#    'M2',
#    'M8',
#    'M1',
#    'T2++',
#    'N3',
#    'A3+',
#    'X2.1',
#    'A7',
#    'G1.2',
#    'S8+',
#    'S7.4+',
#    'I2.2',
#    'S1.2.5+'],
#   'wat': ['Z8', 'Z5'],
#   'hierna': ['Z99'],
#   'wachten': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1%'],
#   'er': ['M6', 'T1.2', 'Z5'],
#   'komt': ['M1',
#    'N3.1',
#    'A2.2',
#    'A3+',
#    'X2.1',
#    'A9+',
#    'S4',
#    'N4',
#    'S3.2',
#    'T1',
#    'A1.1.1',
#    'N5'],
#   'rotziekte': ['Z99'],
#   'blijven': ['T2++', 'M8', 'N5.2+'],
#   'vechten': ['S8-', 'X8+', 'E3-', 'G1.2'],
#   'tussentijd': ['Z99'],
#   'krijg': ['A9+',
#    'Z5',
#    'X9.2+',
#    'A2.1+',
#    'A2.2',
#    'M1',
#    'M2',
#    'X2.5+',
#    'E4.1-'],
#   'iedere': ['N5.1+', 'S1.1.2+'],
#   'zes': ['N1', 'T3', 'T1.2'],
#   'maanden': ['T1.3'],
#   'preventieve': ['Z99'],
#   'chemotherapie': ['Z99'],
#   'geniet': ['E2+', 'A9+', 'E4.1+'],
#   'ervan': ['Z99'],
#   'samen': ['Z99'],
#   'Dus': ['A13.3', 'Z5'],
#   'kameraad': ['S3.1/S2mf'],
#   'zie': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'jouw': ['Z8'],
#   'situatie': ['A3+', 'O4.1', 'M6', 'I3.1@'],
#   'Wat': ['Z8', 'Z5'],
#   'leven': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'brengt': ['M2', 'A2.2'],
#   'hebt': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'kracht': ['A1.1.1', 'S7.1+', 'O3', 'S1.2.5+', 'N2@'],
#   'optimisme': ['Z99'],
#   'zetten': ['M2', 'Q2.1', 'Q2.2', 'A1.1.1'],
#   'Houd': ['Z99'],
#   'hoofd': ['B1',
#    'S7.1+/S2mf',
#    'P1/S2mf',
#    'X1',
#    'M6',
#    'A4.1',
#    'S2mf',
#    'F2',
#    'H5/M4%',
#    'S7.1+',
#    'K5.1',
#    'M1',
#    'N5',
#    'A2.1+',
#    'A11.1+',
#    'Q1.2',
#    'T1.1.3'],
#   'omhoog': ['M6', 'N4', 'N5++', 'T2-', 'X9.1+', 'A1.1.1', 'N5+/A2.1', 'Z5'],
#   'blijf': ['Z99'],
#   'scoren': ['K5', 'A5.1', 'N3.1', 'X9.2+', 'A1.1.1'],
#   '!': ['PUNCT']}}

# %% [markdown]
# ---
#
# ### **STEP 5: Extracting emotion words using USAS emotion tags:** *usas_emotion_tags function*
#
# >>**input:** piece of text
#
# >>**output:** python dictionary where *keys* represent a sentence in the input text and *values* represent a dictionary of usas tagged emotion words and tags for that sentence
#
# ---

# %%
usas_emo_cls_dict = {'E1': 'Emotional Actions, States And Processes General',
 'E1+': 'Emotional',
 'E1-': 'Unemotional',
 'E2': 'Liking',
 'E2+': 'Like',
 'E2-': 'Dislike',
 'E3': 'Calm/Violent/Angry',
 'E3+': 'Calm',
 'E3-': 'Violent/Angry',
 'E4': 'Happiness and Contentment',
 'E4.1': 'Happy/sad',
 'E4.1+': 'Happy',
 'E4.1-': 'Sad',
 'E4.2': 'Contentment',
 'E4.2+': 'Content',
 'E4.2-': 'Discontent',
 'E5': 'Bravery and Fear',
 'E5+': 'Bravery',
 'E5-': 'Fear/shock',
 'E6': 'Worry and confidence',
 'E6+': 'Confident',
 'E6-': 'Worry'}

# %%
# Defining the emotion tag extraction function
def usas_emotion_tags(text):
  usas_eval_tags = {}
  sentences = nltk.sent_tokenize(text)
  for i in range(len(sentences)):
    if(sentences[i]):
      usas_list = {}
      sent = nlp(sentences[i])
      print("\n")
      print(Fore.MAGENTA + Style.BRIGHT + "--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
      print(Fore.BLUE + Style.BRIGHT + f"Sentence {i}:", sentences[i])
      for token in sent:
        tags = token._.pymusas_tags
        emo_tags = [x for x in tags if x.startswith('E')]
        if emo_tags:
          usas_list[token.text] = emo_tags
          print(Fore.MAGENTA + f'{token.text}:' + Fore.GREEN, emo_tags)
      usas_eval_tags[sentences[i]] = usas_list
  return usas_eval_tags

# %%
# Text 1 emotion tag extraction
text1_emo_tags = usas_emotion_tags(text_1)
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 0:
#
# Hallo kameraden, ik wil met jullie mijn ervaring delen over hoe ik na een operatie tegen kanker opnieuw een doelpunt scoorde en de stand op 3–0 bracht.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 1: Ik hoop dat dit verhaal iemand daarbuiten zal inspireren.
# hoop: ['E4.1+']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 2: In mei 2020 kreeg ik de diagnose darmkanker toen ik ernstige bloedingen had, je weet wel waar.
# kreeg: ['E4.1-']
# ernstige: ['E4.1-']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 3: Voordat ik het doorhad, hadden de chirurgen al 30 cm van mijn dikke darm verwijderd.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 4: Het herstel was zwaar, maar te doen.
# zwaar: ['E4.1-']
# doen: ['E3-']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 5: Het goede nieuws was dat, ook al was mijn tumor groot, de lymfeklieren schoon waren, waardoor ik in stadium 2 zat.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 6: Volgens de artsen was ik schoon, en één van de gelukkigen die kanker nu achter zich had met een mooi verhaal om in de kroeg te vertellen.
# gelukkigen: ['E4.1+', 'E4.2+']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 7: De stand was 1–0 in mijn voordeel.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 8: Maar later leerde ik op de harde manier dat deze rotzooi ook via de bloedbaan kan reizen.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 9: In januari 2021 liet mijn routine-scan niet zulk goed nieuws zien.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 10: Ik had meerdere laesies in mijn lever, en toen de chirurg zei dat deze niet te opereren waren, stortte mijn wereld in.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 11: Ik had nu stadium 4 darmkanker met niet-operabele levermetastasen, en thuis had ik twee zoontjes van 3 en 5, die ik niet zonder vader wilde achterlaten.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 12: Dit gebeurde allemaal tijdens de coronapandemie, toen mijn familie en kinderen door ziekenhuisbeperkingen niet altijd bij me konden zijn.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 13: Toch ben ik geen opgever, en ik zag dit als een nieuwe uitdaging die ik moest overwinnen.
# uitdaging: ['E3-']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 14: Met lage overlevingskansen begon ik aan anderhalf jaar chemo- en radiotherapie, die me flink op mijn donder gaven, maar ervoor zorgden dat ik kankervrij werd.
# lage: ['E4.1-']
# begon: ['E5-', 'E3-']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 15: Ik had niet eens een leveroperatie nodig.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 16: De stand was nu 2–0, en we hoopten allemaal dat deze niet zou terugkeren.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 17: Het kwam inderdaad niet terug, maar nu kreeg ik te maken met iets compleet nieuws.
# kreeg: ['E4.1-']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 18: Bij een routineonderzoek verdachten de dokters iets in mijn schildklier.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 19: Na extra scans en een naaldbiopsie kreeg ik te horen dat ik schildklierkanker had.
# kreeg: ['E4.1-']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 20: Ik dacht bij mezelf: “Ach, deze is gemakkelijk te tackelen.”
#
# Gisteren is mijn hele schildklier verwijderd.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 21: De tumor was al 2 cm groot.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 22: De stand staat nu op 3–0.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 23: Ik weet niet wat me hierna te wachten staat, maar wat er ook komt, ik zal tegen deze rotziekte blijven vechten.
# vechten: ['E3-']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 24: In de tussentijd krijg ik iedere zes maanden preventieve chemotherapie en geniet ik ervan samen met mijn kinderen te zijn.
# krijg: ['E4.1-']
# geniet: ['E2+', 'E4.1+']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 25: Dus, kameraad, zie jouw situatie ook als een uitdaging.
# uitdaging: ['E3-']
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 26: Wat het leven je ook brengt, je hebt de kracht en het optimisme in je om door te zetten.
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 27: Houd je hoofd omhoog en blijf scoren!

# %%
text1_emo_tags
# Out:
# {'\n\nHallo kameraden, ik wil met jullie mijn ervaring delen over hoe ik na een operatie tegen kanker opnieuw een doelpunt scoorde en de stand op 3–0 bracht.': {},
#  'Ik hoop dat dit verhaal iemand daarbuiten zal inspireren.': {'hoop': ['E4.1+']},
#  'In mei 2020 kreeg ik de diagnose darmkanker toen ik ernstige bloedingen had, je weet wel waar.': {'kreeg': ['E4.1-'],
#   'ernstige': ['E4.1-']},
#  'Voordat ik het doorhad, hadden de chirurgen al 30 cm van mijn dikke darm verwijderd.': {},
#  'Het herstel was zwaar, maar te doen.': {'zwaar': ['E4.1-'], 'doen': ['E3-']},
#  'Het goede nieuws was dat, ook al was mijn tumor groot, de lymfeklieren schoon waren, waardoor ik in stadium 2 zat.': {},
#  'Volgens de artsen was ik schoon, en één van de gelukkigen die kanker nu achter zich had met een mooi verhaal om in de kroeg te vertellen.': {'gelukkigen': ['E4.1+',
#    'E4.2+']},
#  'De stand was 1–0 in mijn voordeel.': {},
#  'Maar later leerde ik op de harde manier dat deze rotzooi ook via de bloedbaan kan reizen.': {},
#  'In januari 2021 liet mijn routine-scan niet zulk goed nieuws zien.': {},
#  'Ik had meerdere laesies in mijn lever, en toen de chirurg zei dat deze niet te opereren waren, stortte mijn wereld in.': {},
#  'Ik had nu stadium 4 darmkanker met niet-operabele levermetastasen, en thuis had ik twee zoontjes van 3 en 5, die ik niet zonder vader wilde achterlaten.': {},
#  'Dit gebeurde allemaal tijdens de coronapandemie, toen mijn familie en kinderen door ziekenhuisbeperkingen niet altijd bij me konden zijn.': {},
#  'Toch ben ik geen opgever, en ik zag dit als een nieuwe uitdaging die ik moest overwinnen.': {'uitdaging': ['E3-']},
#  'Met lage overlevingskansen begon ik aan anderhalf jaar chemo- en radiotherapie, die me flink op mijn donder gaven, maar ervoor zorgden dat ik kankervrij werd.': {'lage': ['E4.1-'],
#   'begon': ['E5-', 'E3-']},
#  'Ik had niet eens een leveroperatie nodig.': {},
#  'De stand was nu 2–0, en we hoopten allemaal dat deze niet zou terugkeren.': {},
#  'Het kwam inderdaad niet terug, maar nu kreeg ik te maken met iets compleet nieuws.': {'kreeg': ['E4.1-']},
#  'Bij een routineonderzoek verdachten de dokters iets in mijn schildklier.': {},
#  'Na extra scans en een naaldbiopsie kreeg ik te horen dat ik schildklierkanker had.': {'kreeg': ['E4.1-']},
#  'Ik dacht bij mezelf: “Ach, deze is gemakkelijk te tackelen.”\n\nGisteren is mijn hele schildklier verwijderd.': {},
#  'De tumor was al 2 cm groot.': {},
#  'De stand staat nu op 3–0.': {},
#  'Ik weet niet wat me hierna te wachten staat, maar wat er ook komt, ik zal tegen deze rotziekte blijven vechten.': {'vechten': ['E3-']},
#  'In de tussentijd krijg ik iedere zes maanden preventieve chemotherapie en geniet ik ervan samen met mijn kinderen te zijn.': {'krijg': ['E4.1-'],
#   'geniet': ['E2+', 'E4.1+']},
#  'Dus, kameraad, zie jouw situatie ook als een uitdaging.': {'uitdaging': ['E3-']},
#  'Wat het leven je ook brengt, je hebt de kracht en het optimisme in je om door te zetten.': {},
#  'Houd je hoofd omhoog en blijf scoren!': {}}

# %% [markdown]
# ---
#
# ### **STEP 6: USAS Sentiment Classification:** *usas_sentiment_classifier function*
#
# >>**input:** dictionary of sentence and emotion word tags
#
# >>**output:** sentiment class *positive*, *negative*, *neutral* with counts per class
#
# ---

# %%
# Defining the sentiment classifier
def usas_sentiment_classifier(usas_emo_tag, positive, negative, neutral):
  sentiment_cls = {}
  for sent, emo_dict in usas_emo_tag.items():
    neg, pos, neu = 0, 0, 0
    if(emo_dict):
      for key, val_list in emo_dict.items():
        for val in val_list:
          if val.endswith('-'):
            neg+=1
            negative+=1
          elif  val.endswith('+'):
            pos+=1
            positive+=1
          else:
            neu+=1
            neutral+=1
    else:
      neu+=1
      neutral+=1
    if neg==max(pos, neg, neu):
          sentiment = 'negative'
          sentiment_cls[sent] = sentiment
    elif pos==max(pos, neg, neu):
          sentiment = 'positive'
          sentiment_cls[sent] = sentiment
    else:
          sentiment = 'neutral'
          sentiment_cls[sent] = sentiment
    print(Fore.MAGENTA + Style.BRIGHT + "Sentence:", sent)
    print(Fore.GREEN + Style.BRIGHT + "class:", sentiment)
    print("\n")
    print(Fore.GREEN + Style.BRIGHT + "--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
  return sentiment_cls, positive, negative, neutral

# %%
# Sentiment counts and tagging
sentiments_text1, pos_text1, neg_text1, neu_text1 = usas_sentiment_classifier(text1_emo_tags, 0, 0, 0)
# Out:
# Sentence:
#
# Hallo kameraden, ik wil met jullie mijn ervaring delen over hoe ik na een operatie tegen kanker opnieuw een doelpunt scoorde en de stand op 3–0 bracht.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ik hoop dat dit verhaal iemand daarbuiten zal inspireren.
# class: positive
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: In mei 2020 kreeg ik de diagnose darmkanker toen ik ernstige bloedingen had, je weet wel waar.
# class: negative
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Voordat ik het doorhad, hadden de chirurgen al 30 cm van mijn dikke darm verwijderd.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Het herstel was zwaar, maar te doen.
# class: negative
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Het goede nieuws was dat, ook al was mijn tumor groot, de lymfeklieren schoon waren, waardoor ik in stadium 2 zat.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Volgens de artsen was ik schoon, en één van de gelukkigen die kanker nu achter zich had met een mooi verhaal om in de kroeg te vertellen.
# class: positive
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: De stand was 1–0 in mijn voordeel.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Maar later leerde ik op de harde manier dat deze rotzooi ook via de bloedbaan kan reizen.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: In januari 2021 liet mijn routine-scan niet zulk goed nieuws zien.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ik had meerdere laesies in mijn lever, en toen de chirurg zei dat deze niet te opereren waren, stortte mijn wereld in.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ik had nu stadium 4 darmkanker met niet-operabele levermetastasen, en thuis had ik twee zoontjes van 3 en 5, die ik niet zonder vader wilde achterlaten.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Dit gebeurde allemaal tijdens de coronapandemie, toen mijn familie en kinderen door ziekenhuisbeperkingen niet altijd bij me konden zijn.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Toch ben ik geen opgever, en ik zag dit als een nieuwe uitdaging die ik moest overwinnen.
# class: negative
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Met lage overlevingskansen begon ik aan anderhalf jaar chemo- en radiotherapie, die me flink op mijn donder gaven, maar ervoor zorgden dat ik kankervrij werd.
# class: negative
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ik had niet eens een leveroperatie nodig.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: De stand was nu 2–0, en we hoopten allemaal dat deze niet zou terugkeren.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Het kwam inderdaad niet terug, maar nu kreeg ik te maken met iets compleet nieuws.
# class: negative
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Bij een routineonderzoek verdachten de dokters iets in mijn schildklier.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Na extra scans en een naaldbiopsie kreeg ik te horen dat ik schildklierkanker had.
# class: negative
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ik dacht bij mezelf: “Ach, deze is gemakkelijk te tackelen.”
#
# Gisteren is mijn hele schildklier verwijderd.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: De tumor was al 2 cm groot.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: De stand staat nu op 3–0.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ik weet niet wat me hierna te wachten staat, maar wat er ook komt, ik zal tegen deze rotziekte blijven vechten.
# class: negative
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: In de tussentijd krijg ik iedere zes maanden preventieve chemotherapie en geniet ik ervan samen met mijn kinderen te zijn.
# class: positive
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Dus, kameraad, zie jouw situatie ook als een uitdaging.
# class: negative
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Wat het leven je ook brengt, je hebt de kracht en het optimisme in je om door te zetten.
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Houd je hoofd omhoog en blijf scoren!
# class: neutral
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Text 1 sentiment tags per sentence
sentiments_text1
# Out:
# {'\n\nHallo kameraden, ik wil met jullie mijn ervaring delen over hoe ik na een operatie tegen kanker opnieuw een doelpunt scoorde en de stand op 3–0 bracht.': 'neutral',
#  'Ik hoop dat dit verhaal iemand daarbuiten zal inspireren.': 'positive',
#  'In mei 2020 kreeg ik de diagnose darmkanker toen ik ernstige bloedingen had, je weet wel waar.': 'negative',
#  'Voordat ik het doorhad, hadden de chirurgen al 30 cm van mijn dikke darm verwijderd.': 'neutral',
#  'Het herstel was zwaar, maar te doen.': 'negative',
#  'Het goede nieuws was dat, ook al was mijn tumor groot, de lymfeklieren schoon waren, waardoor ik in stadium 2 zat.': 'neutral',
#  'Volgens de artsen was ik schoon, en één van de gelukkigen die kanker nu achter zich had met een mooi verhaal om in de kroeg te vertellen.': 'positive',
#  'De stand was 1–0 in mijn voordeel.': 'neutral',
#  'Maar later leerde ik op de harde manier dat deze rotzooi ook via de bloedbaan kan reizen.': 'neutral',
#  'In januari 2021 liet mijn routine-scan niet zulk goed nieuws zien.': 'neutral',
#  'Ik had meerdere laesies in mijn lever, en toen de chirurg zei dat deze niet te opereren waren, stortte mijn wereld in.': 'neutral',
#  'Ik had nu stadium 4 darmkanker met niet-operabele levermetastasen, en thuis had ik twee zoontjes van 3 en 5, die ik niet zonder vader wilde achterlaten.': 'neutral',
#  'Dit gebeurde allemaal tijdens de coronapandemie, toen mijn familie en kinderen door ziekenhuisbeperkingen niet altijd bij me konden zijn.': 'neutral',
#  'Toch ben ik geen opgever, en ik zag dit als een nieuwe uitdaging die ik moest overwinnen.': 'negative',
#  'Met lage overlevingskansen begon ik aan anderhalf jaar chemo- en radiotherapie, die me flink op mijn donder gaven, maar ervoor zorgden dat ik kankervrij werd.': 'negative',
#  'Ik had niet eens een leveroperatie nodig.': 'neutral',
#  'De stand was nu 2–0, en we hoopten allemaal dat deze niet zou terugkeren.': 'neutral',
#  'Het kwam inderdaad niet terug, maar nu kreeg ik te maken met iets compleet nieuws.': 'negative',
#  'Bij een routineonderzoek verdachten de dokters iets in mijn schildklier.': 'neutral',
#  'Na extra scans en een naaldbiopsie kreeg ik te horen dat ik schildklierkanker had.': 'negative',
#  'Ik dacht bij mezelf: “Ach, deze is gemakkelijk te tackelen.”\n\nGisteren is mijn hele schildklier verwijderd.': 'neutral',
#  'De tumor was al 2 cm groot.': 'neutral',
#  'De stand staat nu op 3–0.': 'neutral',
#  'Ik weet niet wat me hierna te wachten staat, maar wat er ook komt, ik zal tegen deze rotziekte blijven vechten.': 'negative',
#  'In de tussentijd krijg ik iedere zes maanden preventieve chemotherapie en geniet ik ervan samen met mijn kinderen te zijn.': 'positive',
#  'Dus, kameraad, zie jouw situatie ook als een uitdaging.': 'negative',
#  'Wat het leven je ook brengt, je hebt de kracht en het optimisme in je om door te zetten.': 'neutral',
#  'Houd je hoofd omhoog en blijf scoren!': 'neutral'}

# %%
# Text 1 sentiment counts for per class
print(f'Text 1: positive = {pos_text1}, negative = {neg_text1}, neutral = {neu_text1}')
# Out:
# Text 1: positive = 5, negative = 13, neutral = 17

# %%
text1_emo_tags
# Out:
# {'\n\nHallo kameraden, ik wil met jullie mijn ervaring delen over hoe ik na een operatie tegen kanker opnieuw een doelpunt scoorde en de stand op 3–0 bracht.': {},
#  'Ik hoop dat dit verhaal iemand daarbuiten zal inspireren.': {'hoop': ['E4.1+']},
#  'In mei 2020 kreeg ik de diagnose darmkanker toen ik ernstige bloedingen had, je weet wel waar.': {'kreeg': ['E4.1-'],
#   'ernstige': ['E4.1-']},
#  'Voordat ik het doorhad, hadden de chirurgen al 30 cm van mijn dikke darm verwijderd.': {},
#  'Het herstel was zwaar, maar te doen.': {'zwaar': ['E4.1-'], 'doen': ['E3-']},
#  'Het goede nieuws was dat, ook al was mijn tumor groot, de lymfeklieren schoon waren, waardoor ik in stadium 2 zat.': {},
#  'Volgens de artsen was ik schoon, en één van de gelukkigen die kanker nu achter zich had met een mooi verhaal om in de kroeg te vertellen.': {'gelukkigen': ['E4.1+',
#    'E4.2+']},
#  'De stand was 1–0 in mijn voordeel.': {},
#  'Maar later leerde ik op de harde manier dat deze rotzooi ook via de bloedbaan kan reizen.': {},
#  'In januari 2021 liet mijn routine-scan niet zulk goed nieuws zien.': {},
#  'Ik had meerdere laesies in mijn lever, en toen de chirurg zei dat deze niet te opereren waren, stortte mijn wereld in.': {},
#  'Ik had nu stadium 4 darmkanker met niet-operabele levermetastasen, en thuis had ik twee zoontjes van 3 en 5, die ik niet zonder vader wilde achterlaten.': {},
#  'Dit gebeurde allemaal tijdens de coronapandemie, toen mijn familie en kinderen door ziekenhuisbeperkingen niet altijd bij me konden zijn.': {},
#  'Toch ben ik geen opgever, en ik zag dit als een nieuwe uitdaging die ik moest overwinnen.': {'uitdaging': ['E3-']},
#  'Met lage overlevingskansen begon ik aan anderhalf jaar chemo- en radiotherapie, die me flink op mijn donder gaven, maar ervoor zorgden dat ik kankervrij werd.': {'lage': ['E4.1-'],
#   'begon': ['E5-', 'E3-']},
#  'Ik had niet eens een leveroperatie nodig.': {},
#  'De stand was nu 2–0, en we hoopten allemaal dat deze niet zou terugkeren.': {},
#  'Het kwam inderdaad niet terug, maar nu kreeg ik te maken met iets compleet nieuws.': {'kreeg': ['E4.1-']},
#  'Bij een routineonderzoek verdachten de dokters iets in mijn schildklier.': {},
#  'Na extra scans en een naaldbiopsie kreeg ik te horen dat ik schildklierkanker had.': {'kreeg': ['E4.1-']},
#  'Ik dacht bij mezelf: “Ach, deze is gemakkelijk te tackelen.”\n\nGisteren is mijn hele schildklier verwijderd.': {},
#  'De tumor was al 2 cm groot.': {},
#  'De stand staat nu op 3–0.': {},
#  'Ik weet niet wat me hierna te wachten staat, maar wat er ook komt, ik zal tegen deze rotziekte blijven vechten.': {'vechten': ['E3-']},
#  'In de tussentijd krijg ik iedere zes maanden preventieve chemotherapie en geniet ik ervan samen met mijn kinderen te zijn.': {'krijg': ['E4.1-'],
#   'geniet': ['E2+', 'E4.1+']},
#  'Dus, kameraad, zie jouw situatie ook als een uitdaging.': {'uitdaging': ['E3-']},
#  'Wat het leven je ook brengt, je hebt de kracht en het optimisme in je om door te zetten.': {},
#  'Houd je hoofd omhoog en blijf scoren!': {}}

# %% [markdown]
# ---
# ### **STEP 7: Sentiment Probability - Sentence-level**
# ---

# %%
# Defining the probability estimation function for sentiment classification at the sentence-level
def sentence_sentiment_prob(usas_emo_tag):
  sentiment_cls = {}
  for sent, emo_dict in usas_emo_tag.items():
    neg, pos, neu = 0, 0, 0
    if(emo_dict):
      for key, val_list in emo_dict.items():
        for val in val_list:
          if val.endswith('-'):
            neg+=1
          elif val.endswith('+'):
            pos+=1
          else:
            neu+=1
    else:
      neu+=1
    sentiment = f'positive={pos/(pos+neg+neu)}, negative={neg/(pos+neg+neu)}, neutral={neu/(pos+neg+neu)}'
    sentiment_cls[sent] = sentiment
    print(Fore.GREEN + Style.BRIGHT + "Sentence:", sent)
    print(Fore.CYAN + Style.BRIGHT + "class:", sentiment)
    print("\n")
    print(Fore.CYAN + Style.BRIGHT + "--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
  return sentiment_cls

# %%
# Text 1 sentence-level sentiment probability
sentiment_prob_text1 = (sentence_sentiment_prob(text1_emo_tags))
# Out:
# Sentence:
#
# Hallo kameraden, ik wil met jullie mijn ervaring delen over hoe ik na een operatie tegen kanker opnieuw een doelpunt scoorde en de stand op 3–0 bracht.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ik hoop dat dit verhaal iemand daarbuiten zal inspireren.
# class: positive=1.0, negative=0.0, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: In mei 2020 kreeg ik de diagnose darmkanker toen ik ernstige bloedingen had, je weet wel waar.
# class: positive=0.0, negative=1.0, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Voordat ik het doorhad, hadden de chirurgen al 30 cm van mijn dikke darm verwijderd.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Het herstel was zwaar, maar te doen.
# class: positive=0.0, negative=1.0, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Het goede nieuws was dat, ook al was mijn tumor groot, de lymfeklieren schoon waren, waardoor ik in stadium 2 zat.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Volgens de artsen was ik schoon, en één van de gelukkigen die kanker nu achter zich had met een mooi verhaal om in de kroeg te vertellen.
# class: positive=1.0, negative=0.0, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: De stand was 1–0 in mijn voordeel.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Maar later leerde ik op de harde manier dat deze rotzooi ook via de bloedbaan kan reizen.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: In januari 2021 liet mijn routine-scan niet zulk goed nieuws zien.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ik had meerdere laesies in mijn lever, en toen de chirurg zei dat deze niet te opereren waren, stortte mijn wereld in.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ik had nu stadium 4 darmkanker met niet-operabele levermetastasen, en thuis had ik twee zoontjes van 3 en 5, die ik niet zonder vader wilde achterlaten.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Dit gebeurde allemaal tijdens de coronapandemie, toen mijn familie en kinderen door ziekenhuisbeperkingen niet altijd bij me konden zijn.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Toch ben ik geen opgever, en ik zag dit als een nieuwe uitdaging die ik moest overwinnen.
# class: positive=0.0, negative=1.0, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Met lage overlevingskansen begon ik aan anderhalf jaar chemo- en radiotherapie, die me flink op mijn donder gaven, maar ervoor zorgden dat ik kankervrij werd.
# class: positive=0.0, negative=1.0, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ik had niet eens een leveroperatie nodig.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: De stand was nu 2–0, en we hoopten allemaal dat deze niet zou terugkeren.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Het kwam inderdaad niet terug, maar nu kreeg ik te maken met iets compleet nieuws.
# class: positive=0.0, negative=1.0, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Bij een routineonderzoek verdachten de dokters iets in mijn schildklier.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Na extra scans en een naaldbiopsie kreeg ik te horen dat ik schildklierkanker had.
# class: positive=0.0, negative=1.0, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ik dacht bij mezelf: “Ach, deze is gemakkelijk te tackelen.”
#
# Gisteren is mijn hele schildklier verwijderd.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: De tumor was al 2 cm groot.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: De stand staat nu op 3–0.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Ik weet niet wat me hierna te wachten staat, maar wat er ook komt, ik zal tegen deze rotziekte blijven vechten.
# class: positive=0.0, negative=1.0, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: In de tussentijd krijg ik iedere zes maanden preventieve chemotherapie en geniet ik ervan samen met mijn kinderen te zijn.
# class: positive=0.6666666666666666, negative=0.3333333333333333, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Dus, kameraad, zie jouw situatie ook als een uitdaging.
# class: positive=0.0, negative=1.0, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Wat het leven je ook brengt, je hebt de kracht en het optimisme in je om door te zetten.
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence: Houd je hoofd omhoog en blijf scoren!
# class: positive=0.0, negative=0.0, neutral=1.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
sentiment_prob_text1
# Out:
# {'\n\nHallo kameraden, ik wil met jullie mijn ervaring delen over hoe ik na een operatie tegen kanker opnieuw een doelpunt scoorde en de stand op 3–0 bracht.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Ik hoop dat dit verhaal iemand daarbuiten zal inspireren.': 'positive=1.0, negative=0.0, neutral=0.0',
#  'In mei 2020 kreeg ik de diagnose darmkanker toen ik ernstige bloedingen had, je weet wel waar.': 'positive=0.0, negative=1.0, neutral=0.0',
#  'Voordat ik het doorhad, hadden de chirurgen al 30 cm van mijn dikke darm verwijderd.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Het herstel was zwaar, maar te doen.': 'positive=0.0, negative=1.0, neutral=0.0',
#  'Het goede nieuws was dat, ook al was mijn tumor groot, de lymfeklieren schoon waren, waardoor ik in stadium 2 zat.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Volgens de artsen was ik schoon, en één van de gelukkigen die kanker nu achter zich had met een mooi verhaal om in de kroeg te vertellen.': 'positive=1.0, negative=0.0, neutral=0.0',
#  'De stand was 1–0 in mijn voordeel.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Maar later leerde ik op de harde manier dat deze rotzooi ook via de bloedbaan kan reizen.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'In januari 2021 liet mijn routine-scan niet zulk goed nieuws zien.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Ik had meerdere laesies in mijn lever, en toen de chirurg zei dat deze niet te opereren waren, stortte mijn wereld in.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Ik had nu stadium 4 darmkanker met niet-operabele levermetastasen, en thuis had ik twee zoontjes van 3 en 5, die ik niet zonder vader wilde achterlaten.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Dit gebeurde allemaal tijdens de coronapandemie, toen mijn familie en kinderen door ziekenhuisbeperkingen niet altijd bij me konden zijn.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Toch ben ik geen opgever, en ik zag dit als een nieuwe uitdaging die ik moest overwinnen.': 'positive=0.0, negative=1.0, neutral=0.0',
#  'Met lage overlevingskansen begon ik aan anderhalf jaar chemo- en radiotherapie, die me flink op mijn donder gaven, maar ervoor zorgden dat ik kankervrij werd.': 'positive=0.0, negative=1.0, neutral=0.0',
#  'Ik had niet eens een leveroperatie nodig.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'De stand was nu 2–0, en we hoopten allemaal dat deze niet zou terugkeren.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Het kwam inderdaad niet terug, maar nu kreeg ik te maken met iets compleet nieuws.': 'positive=0.0, negative=1.0, neutral=0.0',
#  'Bij een routineonderzoek verdachten de dokters iets in mijn schildklier.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Na extra scans en een naaldbiopsie kreeg ik te horen dat ik schildklierkanker had.': 'positive=0.0, negative=1.0, neutral=0.0',
#  'Ik dacht bij mezelf: “Ach, deze is gemakkelijk te tackelen.”\n\nGisteren is mijn hele schildklier verwijderd.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'De tumor was al 2 cm groot.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'De stand staat nu op 3–0.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Ik weet niet wat me hierna te wachten staat, maar wat er ook komt, ik zal tegen deze rotziekte blijven vechten.': 'positive=0.0, negative=1.0, neutral=0.0',
#  'In de tussentijd krijg ik iedere zes maanden preventieve chemotherapie en geniet ik ervan samen met mijn kinderen te zijn.': 'positive=0.6666666666666666, negative=0.3333333333333333, neutral=0.0',
#  'Dus, kameraad, zie jouw situatie ook als een uitdaging.': 'positive=0.0, negative=1.0, neutral=0.0',
#  'Wat het leven je ook brengt, je hebt de kracht en het optimisme in je om door te zetten.': 'positive=0.0, negative=0.0, neutral=1.0',
#  'Houd je hoofd omhoog en blijf scoren!': 'positive=0.0, negative=0.0, neutral=1.0'}

# %% [markdown]
# ---
# ### **STEP 8: Sentiment Probability -Text-level**
# ---

# %%
def text_sentiment_prob(text, pos, neg, neu):
  prob = f'positive={pos/(pos+neg+neu)}, negative={neg/(pos+neg+neu)}, neutral={neu/(pos+neg+neu)}'
  print(Fore.CYAN+ text)
  print(Fore.GREEN+ "----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
  print(prob)
  return prob

# %%
text1_prob = text_sentiment_prob(text_1, pos_text1, neg_text1, neu_text1)
# Out:
# Hallo kameraden, ik wil met jullie mijn ervaring delen over hoe ik na een operatie tegen kanker opnieuw een doelpunt scoorde en de stand op 3–0 bracht. Ik hoop dat dit verhaal iemand daarbuiten zal inspireren.
#
# In mei 2020 kreeg ik de diagnose darmkanker toen ik ernstige bloedingen had, je weet wel waar. Voordat ik het doorhad, hadden de chirurgen al 30 cm van mijn dikke darm verwijderd. Het herstel was zwaar, maar te doen. Het goede nieuws was dat, ook al was mijn tumor groot, de lymfeklieren schoon waren, waardoor ik in stadium 2 zat. Volgens de artsen was ik schoon, en één van de gelukkigen die kanker nu achter zich had met een mooi verhaal om in de kroeg te vertellen. De stand was 1–0 in mijn voordeel.
#
# Maar later leerde ik op de harde manier dat deze rotzooi ook via de bloedbaan kan reizen. In januari 2021 liet mijn routine-scan niet zulk goed nieuws zien. Ik had meerdere laesies in mijn lever, en toen de chirurg zei dat deze niet te opereren waren, stortte mijn wereld in. Ik had nu stadium 4 darmkanker met niet-operabele levermetastasen, en thuis had ik twee zoontjes van 3 en 5, die ik niet zonder vader wilde achterlaten.
#
# Dit gebeurde allemaal tijdens de coronapandemie, toen mijn familie en kinderen door ziekenhuisbeperkingen niet altijd bij me konden zijn.
#
# Toch ben ik geen opgever, en ik zag dit als een nieuwe uitdaging die ik moest overwinnen. Met lage overlevingskansen begon ik aan anderhalf jaar chemo- en radiotherapie, die me flink op mijn donder gaven, maar ervoor zorgden dat ik kankervrij werd. Ik had niet eens een leveroperatie nodig. De stand was nu 2–0, en we hoopten allemaal dat deze niet zou terugkeren.
#
# Het kwam inderdaad niet terug, maar nu kreeg ik te maken met iets compleet nieuws. Bij een routineonderzoek verdachten de dokters iets in mijn schildklier. Na extra scans en een naaldbiopsie kreeg ik te horen dat ik schildklierkanker had. Ik dacht bij mezelf: “Ach, deze is gemakkelijk te tackelen.”
#
# Gisteren is mijn hele schildklier verwijderd. De tumor was al 2 cm groot.
#
# De stand staat nu op 3–0. Ik weet niet wat me hierna te wachten staat, maar wat er ook komt, ik zal tegen deze rotziekte blijven vechten. In de tussentijd krijg ik iedere zes maanden preventieve chemotherapie en geniet ik ervan samen met mijn kinderen te zijn.
#
# Dus, kameraad, zie jouw situatie ook als een uitdaging. Wat het leven je ook brengt, je hebt de kracht en het optimisme in je om door te zetten. Houd je hoofd omhoog en blijf scoren!
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# positive=0.14285714285714285, negative=0.37142857142857144, neutral=0.4857142857142857
