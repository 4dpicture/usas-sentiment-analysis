# %% [markdown]
# ---
# # **FRENCH**
# ---

# %% [markdown]
# ### **STEP 1: Downloading and installing the dependencies:**
# >>**English PyMUSAS RuleBasedTagger**
#
# >>**English spaCy pipeline**
#
# >>**colorama:** *Colorama is a Python module that displays colored output in consoles.*
# ---

# %%
# !pip install https://github.com/UCREL/pymusas-models/releases/download/fr_single_upos2usas_contextual-0.3.3/fr_single_upos2usas_contextual-0.3.3-py3-none-any.whl
# !python -m spacy download fr_core_news_sm
# Out:
# Collecting fr-single-upos2usas-contextual==0.3.3
#   Downloading https://github.com/UCREL/pymusas-models/releases/download/fr_single_upos2usas_contextual-0.3.3/fr_single_upos2usas_contextual-0.3.3-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<4.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from fr-single-upos2usas-contextual==0.3.3) (3.8.7)
# Collecting pymusas<0.4.0,>=0.3.0 (from fr-single-upos2usas-contextual==0.3.3)
#   Downloading pymusas-0.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from pymusas<0.4.0,>=0.3.0->fr-single-upos2usas-contextual==0.3.3) (2.5.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.50.0 in /usr/local/lib/python3.11/dist-packages (from pymusas<0.4.0,>=0.3.0->fr-single-upos2usas-contextual==0.3.3) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from pymusas<0.4.0,>=0.3.0->fr-single-upos2usas-contextual==0.3.3) (2.32.3)
# Collecting click<8.1.0 (from pymusas<0.4.0,>=0.3.0->fr-single-upos2usas-contextual==0.3.3)
#   Downloading click-8.0.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (1.1.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (0.16.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (2.0.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (2.11.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->pymusas<0.4.0,>=0.3.0->fr-single-upos2usas-contextual==0.3.3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->pymusas<0.4.0,>=0.3.0->fr-single-upos2usas-contextual==0.3.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->pymusas<0.4.0,>=0.3.0->fr-single-upos2usas-contextual==0.3.3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->pymusas<0.4.0,>=0.3.0->fr-single-upos2usas-contextual==0.3.3) (2025.6.15)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->fr-single-upos2usas-contextual==0.3.3) (0.1.2)
# Downloading pymusas-0.3.0-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 2.0 MB/s eta 0:00:00
# Downloading click-8.0.4-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: click, pymusas, fr-single-upos2usas-contextual
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 3.1.1 requires click>=8.1.3, but you have click 8.0.4 which is incompatible.
# dask 2024.12.1 requires click>=8.1, but you have click 8.0.4 which is incompatible.
# dask-cuda 25.2.0 requires click>=8.1, but you have click 8.0.4 which is incompatible.
# Successfully installed click-8.0.4 fr-single-upos2usas-contextual-0.3.3 pymusas-0.3.0
# Collecting fr-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.8.0/fr_core_news_sm-3.8.0-py3-none-any.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 44.1 MB/s eta 0:00:00
# Installing collected packages: fr-core-news-sm
# Successfully installed fr-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !pip install colorama
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %% [markdown]
# ---
# ### **STEP 2: Creating the tagger**
#
# ---

# %%
import spacy

# We exclude the following components as we do not need them.
nlp = spacy.load('fr_core_news_sm', exclude=['parser', 'ner'])
# Load the French PyMUSAS rule-based tagger in a separate spaCy pipeline
french_tagger_pipeline = spacy.load('fr_single_upos2usas_contextual')
# Adds the French PyMUSAS rule-based tagger to the main spaCy pipeline
nlp.add_pipe('pymusas_rule_based_tagger', source=french_tagger_pipeline)

# %% [markdown]
# ---
#
# ### **STEP 3: Importing the libraries**
#
# ---

# %%
import re
import pandas as pd
import numpy as np
from colorama import Fore, Back, Style

import nltk
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %% [markdown]
# ---
# ### **STEP 4: Tagging text:** *tag_text function*
#
# >>**input:** piece of text
#
# >>**output:** python dictionary where *keys* represent the index of a sentence in the input text and *values* represent the usas semantic tags for that sentence
#
# ---

# %%
import re

# Defining the tagging function
def tag_text(text):
  usas_eval_tags = {}
  usas_list = {}
  sentences = re.split(r'(。|！|\!|？|\?)', text)
  for i in range(len(sentences)):
    if(sentences[i]):
      print(Fore.GREEN + Style.BRIGHT + "------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
      print(Fore.CYAN + Style.BRIGHT + f"Sentence {i}:", sentences[i])
      print(Fore.CYAN + Style.BRIGHT + "------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
      sent = nlp(sentences[i])
      for token in sent:
        tags = token._.pymusas_tags
        print(Fore.CYAN + f'{token.text}:' + Fore.GREEN, tags)
        for tag in tags:
          usas_list[token.text] = token._.pymusas_tags
      usas_eval_tags[i] = usas_list
  return usas_eval_tags

# %%
# Input text 1
text_1 = """ Bonjour camarades, je voulais juste partager mon histoire après une opération où j'ai marqué un autre but contre le cancer, menant 3-0. J'espère qu'elle inspirera quelqu'un.

J'ai été diagnostiqué d'un cancer du côlon en mai 2020 lorsque j'ai eu une hémorragie majeure. Avant que je ne réalise, les chirurgiens avaient retiré 30 cm de mon côlon. La récupération a été difficile, mais gérable. Le côté positif était que, malgré la taille de la tumeur, les ganglions lymphatiques étaient indemnes, me plaçant au stade 2. Selon les médecins, j'étais guéri, l'un des chanceux à laisser le cancer derrière soi et à raconter son histoire autour d'un verre. Le score était de 1-0.

Pourtant, j'ai vite appris que cette saloperie pouvait aussi voyager par le sang. En janvier 2021, un scanner de routine a révélé de mauvaises nouvelles. J'avais des lésions au foie et le chirurgien m'a annoncé que c'était inopérable. J'étais désormais atteint d'un cancer du côlon de stade 4 avec métastases hépatiques inopérables et deux jeunes garçons de 3 et 5 ans que je ne pouvais laisser orphelins.

C'était pendant le confinement du Covid-19, ma famille et mes enfants ne pouvaient pas m'accompagner à l'hôpital à cause des restrictions.

Néanmoins, je ne suis pas du genre à abandonner, j'ai pris cela comme un défi à relever. Avec peu de chances au départ, j'ai été déclaré sans signe de cancer après 1,5 an de chimiothérapie et de radiothérapie extrêmement éprouvante. Je n'ai même pas eu besoin d'une opération du foie. Le score était de 2-0, et nous croisions les doigts pour qu'il ne revienne jamais.

Il n'est pas revenu, mais un autre cancer allait devenir mon nouveau défi. Les médecins suspectaient quelque chose à la thyroïde lors d'un contrôle de routine. Après des examens supplémentaires et des biopsies à l'aiguille, j'ai appris que j'avais maintenant un cancer de la thyroïde. Je me suis dit : "meh, ça c’est facile".

Hier, on m'a retiré toute la thyroïde. La tumeur faisait déjà 2 cm. C’est désormais 3-0. Je ne sais pas ce qui m’attend, mais peu importe, je continuerai à me battre. En attendant, je suivrai une chimiothérapie préventive tous les 6 mois tout en continuant à profiter de mes enfants.

Alors camarade, vois cela comme un défi à relever. Tu as en toi la force et l'optimisme nécessaires, peu importe à quel point la vie est dure. Garde la tête haute et continue à marquer des buts."""

# %%
# Tagging input text 1
text1_tags = tag_text(text_1)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 0:  Bonjour camarades, je voulais juste partager mon histoire après une opération où j'ai marqué un autre but contre le cancer, menant 3-0. J'espère qu'elle inspirera quelqu'un.
#
# J'ai été diagnostiqué d'un cancer du côlon en mai 2020 lorsque j'ai eu une hémorragie majeure. Avant que je ne réalise, les chirurgiens avaient retiré 30 cm de mon côlon. La récupération a été difficile, mais gérable. Le côté positif était que, malgré la taille de la tumeur, les ganglions lymphatiques étaient indemnes, me plaçant au stade 2. Selon les médecins, j'étais guéri, l'un des chanceux à laisser le cancer derrière soi et à raconter son histoire autour d'un verre. Le score était de 1-0.
#
# Pourtant, j'ai vite appris que cette saloperie pouvait aussi voyager par le sang. En janvier 2021, un scanner de routine a révélé de mauvaises nouvelles. J'avais des lésions au foie et le chirurgien m'a annoncé que c'était inopérable. J'étais désormais atteint d'un cancer du côlon de stade 4 avec métastases hépatiques inopérables et deux jeunes garçons de 3 et 5 ans que je ne pouvais laisser orphelins.
#
# C'était pendant le confinement du Covid-19, ma famille et mes enfants ne pouvaient pas m'accompagner à l'hôpital à cause des restrictions.
#
# Néanmoins, je ne suis pas du genre à abandonner, j'ai pris cela comme un défi à relever. Avec peu de chances au départ, j'ai été déclaré sans signe de cancer après 1,5 an de chimiothérapie et de radiothérapie extrêmement éprouvante. Je n'ai même pas eu besoin d'une opération du foie. Le score était de 2-0, et nous croisions les doigts pour qu'il ne revienne jamais.
#
# Il n'est pas revenu, mais un autre cancer allait devenir mon nouveau défi. Les médecins suspectaient quelque chose à la thyroïde lors d'un contrôle de routine. Après des examens supplémentaires et des biopsies à l'aiguille, j'ai appris que j'avais maintenant un cancer de la thyroïde. Je me suis dit : "meh, ça c’est facile".
#
# Hier, on m'a retiré toute la thyroïde. La tumeur faisait déjà 2 cm. C’est désormais 3-0. Je ne sais pas ce qui m’attend, mais peu importe, je continuerai à me battre. En attendant, je suivrai une chimiothérapie préventive tous les 6 mois tout en continuant à profiter de mes enfants.
#
# Alors camarade, vois cela comme un défi à relever. Tu as en toi la force et l'optimisme nécessaires, peu importe à quel point la vie est dure. Garde la tête haute et continue à marquer des buts.
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  : ['Z99']
# Bonjour: ['S1.1.1', 'Z4']
# camarades: ['Z99']
# ,: ['PUNCT']
# je: ['Z8mf']
# voulais: ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-']
# juste: ['Z99']
# partager: ['S1.1.2+']
# mon: ['Z8']
# histoire: ['Z99']
# après: ['Z5']
# une: ['Z5']
# opération: ['A1.1.1', 'B3', 'G3']
# où: ['Z8']
# j': ['Z8mf']
# ai: ['A9+', 'Z5', 'A2.2', 'S4']
# marqué: ['O4.2-', 'Q1.2', 'A5/P1', 'N3.1', 'Q1.1']
# un: ['Z5']
# autre: ['A6.1-', 'A6.1-/Z8']
# but: ['Z99']
# contre: ['Z5']
# le: ['Z5']
# cancer: ['B2-']
# ,: ['PUNCT']
# menant: ['S7.1+', 'A2.2', 'M2', 'A1.1.1']
# 3: ['N1']
# -: ['N1']
# 0: ['Z99']
# .: ['PUNCT']
# J': ['Z8mf']
# espère: ['X2.6+', 'E4.1+', 'X9.2+', 'A5.1+']
# qu': ['Z5']
# elle: ['Z8']
# inspirera: ['S8+']
# quelqu': ['A13.5', 'N5', 'Z5']
# un: ['Z5']
# .: ['PUNCT']
#
#
# : ['Z99']
# J': ['Z8mf']
# ai: ['A9+', 'Z5', 'A2.2', 'S4']
# été: ['T1.3']
# diagnostiqué: ['Z99']
# d': ['Z5']
# un: ['Z5']
# cancer: ['B2-']
# du: ['Z5']
# côlon: ['Z99']
# en: ['Z5']
# mai: ['T1.3', 'Z1f']
# 2020: ['N1']
# lorsque: ['Z5']
# j': ['Z8mf']
# ai: ['A9+', 'Z5', 'A2.2', 'S4']
# eu: ['A9+', 'Z5', 'A2.2', 'S4']
# une: ['Z5']
# hémorragie: ['Z99']
# majeure: ['A11.1+', 'N3.2+', 'G3/S7.1+/S2mf', 'P1', 'P1/S2mf']
# .: ['PUNCT']
# Avant: ['Z5']
# que: ['Z5']
# je: ['Z8mf']
# ne: ['Z6']
# réalise: ['Z99']
# ,: ['PUNCT']
# les: ['Z5']
# chirurgiens: ['B3/S2mf']
# avaient: ['A9+', 'Z5', 'A2.2', 'S4']
# retiré: ['Z99']
# 30: ['N1']
#  : ['Z99']
# cm: ['Z99']
# de: ['Z5']
# mon: ['Z8']
# côlon: ['Z99']
# .: ['PUNCT']
# La: ['Z5']
# récupération: ['Z99']
# a: ['A9+', 'Z5', 'A2.2', 'S4']
# été: ['T1.3']
# difficile: ['A12-']
# ,: ['PUNCT']
# mais: ['Z5']
# gérable: ['Z99']
# .: ['PUNCT']
# Le: ['Z5']
# côté: ['A4.1', 'M6', 'N5.1-', 'S7.3+/S5+c', 'B1', 'S5+c', 'S4c', 'F1', 'S1.2', 'S5+']
# positif: ['A5.1+', 'A7+', 'N2']
# était: ['Z99']
# que: ['Z5']
# ,: ['PUNCT']
# malgré: ['Z5']
# la: ['Z5']
# taille: ['Z99']
# de: ['Z5']
# la: ['Z5']
# tumeur: ['Z99']
# ,: ['PUNCT']
# les: ['Z5']
# ganglions: ['Z99']
# lymphatiques: ['Z99']
# étaient: ['Z99']
# indemnes: ['Z99']
# ,: ['PUNCT']
# me: ['Z8']
# plaçant: ['M2', 'X2.2+', 'I3.1', 'Q2.2']
# au: ['Z5']
# stade: ['Z99']
#  : ['Z99']
# 2: ['N1']
# .: ['PUNCT']
# Selon: ['Z5']
# les: ['Z5']
# médecins: ['Z99']
# ,: ['PUNCT']
# j': ['Z8mf']
# étais: ['Z99']
# guéri: ['Z99']
# ,: ['PUNCT']
# l': ['Z5']
# un: ['Z5']
# des: ['Z5']
# chanceux: ['Z99']
# à: ['Z5']
# laisser: ['M1', 'M2', 'A1.1.1', 'A1.9', 'A9-', 'T2-']
# le: ['Z5']
# cancer: ['B2-']
# derrière: ['Z5']
# soi: ['Z8']
# et: ['Z5']
# à: ['Z5']
# raconter: ['Q2.2', 'Q2.1', 'X3', 'A10+']
# son: ['Z5']
# histoire: ['Z99']
# autour: ['A13.4', 'M6', 'Z5']
# d': ['Z5']
# un: ['Z5']
# verre: ['O1.1', 'O2']
# .: ['PUNCT']
# Le: ['Z5']
# score: ['K5', 'A5.1', 'N3.1', 'O2', 'K2', 'X4.1', 'N5%', 'X9.2+', 'A1.1.1']
# était: ['Z99']
# de: ['Z5']
# 1: ['Z99']
# -: ['Z99']
# 0: ['Z99']
# .: ['PUNCT']
#
#
# : ['Z99']
# Pourtant: ['Z99']
# ,: ['PUNCT']
# j': ['Z8mf']
# ai: ['A9+', 'Z5', 'A2.2', 'S4']
# vite: ['Z99']
# appris: ['X2.3+', 'P1']
# que: ['Z5']
# cette: ['Z5']
# saloperie: ['Z99']
# pouvait: ['Z99']
# aussi: ['Z99']
# voyager: ['M1']
# par: ['M6', 'Z5']
# le: ['Z5']
# sang: ['B1']
# .: ['PUNCT']
# En: ['Z5']
# janvier: ['T1.3']
#  : ['Z99']
# 2021: ['N1']
# ,: ['PUNCT']
# un: ['Z5']
# scanner: ['Z99']
# de: ['Z5']
# routine: ['A6.2+', 'X4.2', 'K4']
# a: ['A9+', 'Z5', 'A2.2', 'S4']
# révélé: ['A10+']
# de: ['Z5']
# mauvaises: ['Z99']
# nouvelles: ['T3-']
# .: ['PUNCT']
# J': ['Z8mf']
# avais: ['A9+', 'Z5', 'A2.2', 'S4']
# des: ['Z5']
# lésions: ['Z99']
# au: ['Z5']
# foie: ['B1', 'F1', 'S2mf']
# et: ['Z5']
# le: ['Z5']
# chirurgien: ['B3/S2mf']
# m': ['Z8']
# a: ['A9+', 'Z5', 'A2.2', 'S4']
# annoncé: ['Q2.2']
# que: ['Z5']
# c': ['Z8']
# était: ['Z99']
# inopérable: ['Z99']
# .: ['PUNCT']
# J': ['Z8mf']
# étais: ['Z99']
# désormais: ['Z99']
# atteint: ['M1', 'N3.3', 'Q2.1', 'X9.2+']
# d': ['Z5']
# un: ['Z5']
# cancer: ['B2-']
# du: ['Z5']
# côlon: ['Z99']
# de: ['Z5']
# stade: ['Z99']
#  : ['Z99']
# 4: ['N1']
# avec: ['Z5']
# métastases: ['Z99']
# hépatiques: ['Z99']
# inopérables: ['Z99']
# et: ['Z5']
# deux: ['N1', 'T3', 'T1.2']
# jeunes: ['T3-']
# garçons: ['S2.2m', 'L2m@', 'Z4']
# de: ['Z5']
# 3: ['N1']
# et: ['Z5']
# 5: ['N1']
#  : ['Z99']
# ans: ['T1.3', 'P1c']
# que: ['Z8']
# je: ['Z8mf']
# ne: ['Z6']
# pouvais: ['Z99']
# laisser: ['M1', 'M2', 'A1.1.1', 'A1.9', 'A9-', 'T2-']
# orphelins: ['Z99']
# .: ['PUNCT']
#
#
# : ['Z99']
# C': ['Z8']
# était: ['Z99']
# pendant: ['Z5']
# le: ['Z5']
# confinement: ['Z99']
# du: ['Z5']
# Covid-19: ['Z99']
# ,: ['PUNCT']
# ma: ['Z5']
# famille: ['S4c', 'A4.1c']
# et: ['Z5']
# mes: ['Z5']
# enfants: ['S2mf/T3-', 'S4mf']
# ne: ['Z6']
# pouvaient: ['Z99']
# pas: ['Z99']
# m': ['Z8']
# accompagner: ['S3.1', 'K2', 'T1.1.2']
# à: ['Z5']
# l': ['Z5']
# hôpital: ['B3/H1c']
# à: ['Z5']
# cause: ['A2.2', 'X2.1', 'X4.1', 'Z5/A2.2']
# des: ['Z5']
# restrictions: ['A1.7+']
# .: ['PUNCT']
#
#
# : ['Z99']
# Néanmoins: ['Z4']
# ,: ['PUNCT']
# je: ['Z8mf']
# ne: ['Z6']
# suis: ['Z99']
# pas: ['Z99']
# du: ['Z5']
# genre: ['Z99']
# à: ['Z5']
# abandonner: ['Z99']
# ,: ['PUNCT']
# j': ['Z8mf']
# ai: ['A9+', 'Z5', 'A2.2', 'S4']
# pris: ['A9+', 'T1.3', 'C1', 'A1.1.1', 'M2', 'S7.1-', 'A2.1+', 'X2.4', 'S6+', 'S7.4+', 'N3', 'A2.1+', 'P1', 'M1', 'X2.5+', 'F1@', 'F2@', 'Q1.2@', 'B3@']
# cela: ['Z8']
# comme: ['Z5']
# un: ['Z5']
# défi: ['A12-', 'A6.1-', 'S7.3+', 'E3-', 'Q2.2']
# à: ['Z5']
# relever: ['M2', 'N5+/A2.1', 'A5.1+/A2.1', 'X3.2++', 'A9+', 'A1.1.1', 'A2.2', 'S1.1.1', 'F4', 'Q2.2', 'S4']
# .: ['PUNCT']
# Avec: ['Z5']
# peu: ['A13.7', 'N3.2-', 'T3-', 'N3.7-', 'N3.3-', 'T1.3-', 'A11.1-', 'N5-']
# de: ['Z5']
# chances: ['Z99']
# au: ['Z5']
# départ: ['M1', 'T2+']
# ,: ['PUNCT']
# j': ['Z8mf']
# ai: ['A9+', 'Z5', 'A2.2', 'S4']
# été: ['T1.3']
# déclaré: ['Q2.2', 'K5.1%']
# sans: ['M6', 'Z5']
# signe: ['Q1.1', 'A6.2+', 'X4.1', 'Q1.2', 'O4.1', 'S9', 'B2', 'M2', 'K2', 'G2.1', 'I3.1']
# de: ['Z5']
# cancer: ['B2-']
# après: ['Z5']
# 1,5: ['N1']
#  : ['Z99']
# an: ['T1.3', 'P1c']
# de: ['Z5']
# chimiothérapie: ['Z99']
# et: ['Z5']
# de: ['Z5']
# radiothérapie: ['Z99']
# extrêmement: ['A13.3']
# éprouvante: ['Z99']
# .: ['PUNCT']
# Je: ['Z8mf']
# n': ['Z6']
# ai: ['A9+', 'Z5', 'A2.2', 'S4']
# même: ['Z99']
# pas: ['Z99']
# eu: ['A9+', 'Z5', 'A2.2', 'S4']
# besoin: ['S6+']
# d': ['Z5']
# une: ['Z5']
# opération: ['A1.1.1', 'B3', 'G3']
# du: ['Z5']
# foie: ['B1', 'F1', 'S2mf']
# .: ['PUNCT']
# Le: ['Z5']
# score: ['K5', 'A5.1', 'N3.1', 'O2', 'K2', 'X4.1', 'N5%', 'X9.2+', 'A1.1.1']
# était: ['Z99']
# de: ['Z5']
# 2: ['N1']
# -: ['N1']
# 0: ['Z99']
# ,: ['PUNCT']
# et: ['Z5']
# nous: ['Z8']
# croisions: ['M1', 'M6', 'S8-', 'A1.8+', 'A6.3+', 'F4/L2', 'O4.4', 'Q1.2', 'E3-', 'S1.1.1', 'S9@']
# les: ['Z5']
# doigts: ['B1', 'O4.4', 'X3.3']
# pour: ['Z5']
# qu': ['Z5']
# il: ['Z8']
# ne: ['Z6']
# revienne: ['Z99']
# jamais: ['T1/Z6']
# .: ['PUNCT']
#
#
# : ['Z99']
# Il: ['Z8']
# n': ['Z6']
# est: ['M6']
# pas: ['Z99']
# revenu: ['I1.1']
# ,: ['PUNCT']
# mais: ['Z5']
# un: ['Z5']
# autre: ['A6.1-', 'A6.1-/Z8']
# cancer: ['B2-']
# allait: ['M1', 'A2.1+', 'A1.1.1', 'A9-', 'A1.8+', 'Q2.1', 'N6+', 'I2.2', 'A1.1.2', 'T2-', 'S3.2', 'A6.3+', 'B2-/X1%', 'B1%']
# devenir: ['A2.1+', 'O4.2+']
# mon: ['Z8']
# nouveau: ['T3-']
# défi: ['A12-', 'A6.1-', 'S7.3+', 'E3-', 'Q2.2']
# .: ['PUNCT']
# Les: ['Z5']
# médecins: ['Z99']
# suspectaient: ['Z99']
# quelque: ['A13.5', 'N5', 'Z5']
# chose: ['O2', 'X4.1', 'A7-', 'S2mf', 'L2mf']
# à: ['Z5']
# la: ['Z5']
# thyroïde: ['Z99']
# lors: ['Z99']
# d': ['Z5']
# un: ['Z5']
# contrôle: ['S7.1+', 'A1.7+', 'O2']
# de: ['Z5']
# routine: ['A6.2+', 'X4.2', 'K4']
# .: ['PUNCT']
# Après: ['Z5']
# des: ['Z5']
# examens: ['P1', 'B3%', 'X2.4%']
# supplémentaires: ['N5++']
# et: ['Z5']
# des: ['Z5']
# biopsies: ['Z99']
# à: ['Z5']
# l': ['Z5']
# aiguille: ['Z99']
# ,: ['PUNCT']
# j': ['Z8mf']
# ai: ['A9+', 'Z5', 'A2.2', 'S4']
# appris: ['X2.3+', 'P1']
# que: ['Z5']
# j': ['Z8mf']
# avais: ['A9+', 'Z5', 'A2.2', 'S4']
# maintenant: ['T1.1.2', 'Z4', 'Z5']
# un: ['Z5']
# cancer: ['B2-']
# de: ['Z5']
# la: ['Z5']
# thyroïde: ['Z99']
# .: ['PUNCT']
# Je: ['Z8mf']
# me: ['Z8']
# suis: ['Z99']
# dit: ['Q2.1', 'Z4%']
# :: ['PUNCT']
# ": ['PUNCT']
# meh: ['Z99']
# ,: ['PUNCT']
# ça: ['Z8']
# c’: ['Z99']
# est: ['M6']
# facile: ['A12+']
# ": ['PUNCT']
# .: ['PUNCT']
#
#
# : ['Z99']
# Hier: ['T1.1.1']
# ,: ['PUNCT']
# on: ['Z8']
# m': ['Z8']
# a: ['A9+', 'Z5', 'A2.2', 'S4']
# retiré: ['Z99']
# toute: ['Z8']
# la: ['Z5']
# thyroïde: ['Z99']
# .: ['PUNCT']
# La: ['Z5']
# tumeur: ['Z99']
# faisait: ['Z99']
# déjà: ['T1.1.1']
# 2: ['N1']
#  : ['Z99']
# cm: ['Z99']
# .: ['PUNCT']
# C’: ['Z99']
# est: ['M6']
# désormais: ['Z99']
# 3: ['N1']
# -: ['Z99']
# 0: ['Z99']
# .: ['PUNCT']
# Je: ['Z8mf']
# ne: ['Z6']
# sais: ['X2.2+', 'S3.2/B1%']
# pas: ['Z99']
# ce: ['Z8']
# qui: ['Z8']
# m’: ['Z99']
# attend: ['T1.3', 'A3+', 'A11.1+', 'S1.1.1%']
# ,: ['PUNCT']
# mais: ['Z5']
# peu: ['A13.7', 'N3.2-', 'T3-', 'N3.7-', 'N3.3-', 'T1.3-', 'A11.1-', 'N5-']
# importe: ['Z99']
# ,: ['PUNCT']
# je: ['Z8mf']
# continuerai: ['T2++']
# à: ['Z5']
# me: ['Z8']
# battre: ['Z99']
# .: ['PUNCT']
# En: ['Z5']
# attendant: ['Z99']
# ,: ['PUNCT']
# je: ['Z8mf']
# suivrai: ['M1', 'N4', 'S7.1-', 'X2.4', 'X2.5+', 'A6.1+', 'A1.1.1', 'A2.2', 'K5.1', 'X3.4']
# une: ['Z5']
# chimiothérapie: ['Z99']
# préventive: ['S8-']
# tous: ['Z8']
# les: ['Z5']
# 6: ['N1']
#  : ['Z99']
# mois: ['T1.3']
# tout: ['Z8']
# en: ['Z5']
# continuant: ['T2++']
# à: ['Z5']
# profiter: ['Z99']
# de: ['Z5']
# mes: ['Z5']
# enfants: ['S2mf/T3-', 'S4mf']
# .: ['PUNCT']
#
#
# : ['Z99']
# Alors: ['Z99']
# camarade: ['Z99']
# ,: ['PUNCT']
# vois: ['X3.4', 'X2.1', 'S1.1.1', 'X2.5+', 'X2.3+', 'X3', 'A7+', 'Z4', 'S3.2']
# cela: ['Z8']
# comme: ['Z5']
# un: ['Z5']
# défi: ['A12-', 'A6.1-', 'S7.3+', 'E3-', 'Q2.2']
# à: ['Z5']
# relever: ['M2', 'N5+/A2.1', 'A5.1+/A2.1', 'X3.2++', 'A9+', 'A1.1.1', 'A2.2', 'S1.1.1', 'F4', 'Q2.2', 'S4']
# .: ['PUNCT']
# Tu: ['Z8mf']
# as: ['Z99']
# en: ['Z5']
# toi: ['Z8']
# la: ['Z5']
# force: ['E3-', 'S7.1+', 'G2.1c', 'N3', 'S5+c', 'A1.1.1']
# et: ['Z5']
# l': ['Z5']
# optimisme: ['X2.6+/A5.1+']
# nécessaires: ['Z99']
# ,: ['PUNCT']
# peu: ['A13.7', 'N3.2-', 'T3-', 'N3.7-', 'N3.3-', 'T1.3-', 'A11.1-', 'N5-']
# importe: ['Z99']
# à: ['Z5']
# quel: ['Z5']
# point: ['A10+', 'M6', 'H1', 'Q2.1', 'X4.1', 'A5.1', 'A1.5.2', 'M7', 'T1.2', 'O4.4', 'O3', 'K5']
# la: ['Z5']
# vie: ['L1+', 'A3+', 'T1.3', 'S1.1.1', 'A1.1.1', 'X5.2+', 'Q4.1', 'A11.1+++', 'A5.4+/C1']
# est: ['M6']
# dure: ['O4.1', 'X8+', 'X5.2+', 'N5+', 'A12-', 'O4.5', 'S1.2.5+']
# .: ['PUNCT']
# Garde: ['A1.1.1/A15+', 'X3.4/A15+', 'A15+/I3.2/S2mf', 'O2/A15+']
# la: ['Z5']
# tête: ['B1', 'S7.1+/S2mf', 'P1/S2mf', 'X1', 'M6', 'A4.1', 'S2mf', 'F2', 'H5/M4%', 'S7.1+', 'K5.1', 'M1', 'N5', 'A2.1+', 'A11.1+', 'Q1.2', 'T1.1.3']
# haute: ['Z99']
# et: ['Z5']
# continue: ['T2++']
# à: ['Z5']
# marquer: ['O4.2-', 'Q1.2', 'A5/P1', 'N3.1', 'Q1.1']
# des: ['Z5']
# buts: ['Z99']
# .: ['PUNCT']

# %%
# Output tags text 1
text1_tags
# Out:
# {0: {' ': ['Z99'],
#   'Bonjour': ['S1.1.1', 'Z4'],
#   'camarades': ['Z99'],
#   ',': ['PUNCT'],
#   'je': ['Z8mf'],
#   'voulais': ['X7+', 'S6+', 'A7+', 'S3.2', 'A9-'],
#   'juste': ['Z99'],
#   'partager': ['S1.1.2+'],
#   'mon': ['Z8'],
#   'histoire': ['Z99'],
#   'après': ['Z5'],
#   'une': ['Z5'],
#   'opération': ['A1.1.1', 'B3', 'G3'],
#   'où': ['Z8'],
#   "j'": ['Z8mf'],
#   'ai': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'marqué': ['O4.2-', 'Q1.2', 'A5/P1', 'N3.1', 'Q1.1'],
#   'un': ['Z5'],
#   'autre': ['A6.1-', 'A6.1-/Z8'],
#   'but': ['Z99'],
#   'contre': ['Z5'],
#   'le': ['Z5'],
#   'cancer': ['B2-'],
#   'menant': ['S7.1+', 'A2.2', 'M2', 'A1.1.1'],
#   '3': ['N1'],
#   '-': ['Z99'],
#   '0': ['Z99'],
#   '.': ['PUNCT'],
#   "J'": ['Z8mf'],
#   'espère': ['X2.6+', 'E4.1+', 'X9.2+', 'A5.1+'],
#   "qu'": ['Z5'],
#   'elle': ['Z8'],
#   'inspirera': ['S8+'],
#   "quelqu'": ['A13.5', 'N5', 'Z5'],
#   '\n\n': ['Z99'],
#   'été': ['T1.3'],
#   'diagnostiqué': ['Z99'],
#   "d'": ['Z5'],
#   'du': ['Z5'],
#   'côlon': ['Z99'],
#   'en': ['Z5'],
#   'mai': ['T1.3', 'Z1f'],
#   '2020': ['N1'],
#   'lorsque': ['Z5'],
#   'eu': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'hémorragie': ['Z99'],
#   'majeure': ['A11.1+', 'N3.2+', 'G3/S7.1+/S2mf', 'P1', 'P1/S2mf'],
#   'Avant': ['Z5'],
#   'que': ['Z5'],
#   'ne': ['Z6'],
#   'réalise': ['Z99'],
#   'les': ['Z5'],
#   'chirurgiens': ['B3/S2mf'],
#   'avaient': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'retiré': ['Z99'],
#   '30': ['N1'],
#   '\xa0': ['Z99'],
#   'cm': ['Z99'],
#   'de': ['Z5'],
#   'La': ['Z5'],
#   'récupération': ['Z99'],
#   'a': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'difficile': ['A12-'],
#   'mais': ['Z5'],
#   'gérable': ['Z99'],
#   'Le': ['Z5'],
#   'côté': ['A4.1',
#    'M6',
#    'N5.1-',
#    'S7.3+/S5+c',
#    'B1',
#    'S5+c',
#    'S4c',
#    'F1',
#    'S1.2',
#    'S5+'],
#   'positif': ['A5.1+', 'A7+', 'N2'],
#   'était': ['Z99'],
#   'malgré': ['Z5'],
#   'la': ['Z5'],
#   'taille': ['Z99'],
#   'tumeur': ['Z99'],
#   'ganglions': ['Z99'],
#   'lymphatiques': ['Z99'],
#   'étaient': ['Z99'],
#   'indemnes': ['Z99'],
#   'me': ['Z8'],
#   'plaçant': ['M2', 'X2.2+', 'I3.1', 'Q2.2'],
#   'au': ['Z5'],
#   'stade': ['Z99'],
#   '2': ['N1'],
#   'Selon': ['Z5'],
#   'médecins': ['Z99'],
#   'étais': ['Z99'],
#   'guéri': ['Z99'],
#   "l'": ['Z5'],
#   'des': ['Z5'],
#   'chanceux': ['Z99'],
#   'à': ['Z5'],
#   'laisser': ['M1', 'M2', 'A1.1.1', 'A1.9', 'A9-', 'T2-'],
#   'derrière': ['Z5'],
#   'soi': ['Z8'],
#   'et': ['Z5'],
#   'raconter': ['Q2.2', 'Q2.1', 'X3', 'A10+'],
#   'son': ['Z5'],
#   'autour': ['A13.4', 'M6', 'Z5'],
#   'verre': ['O1.1', 'O2'],
#   'score': ['K5',
#    'A5.1',
#    'N3.1',
#    'O2',
#    'K2',
#    'X4.1',
#    'N5%',
#    'X9.2+',
#    'A1.1.1'],
#   '1': ['Z99'],
#   'Pourtant': ['Z99'],
#   'vite': ['Z99'],
#   'appris': ['X2.3+', 'P1'],
#   'cette': ['Z5'],
#   'saloperie': ['Z99'],
#   'pouvait': ['Z99'],
#   'aussi': ['Z99'],
#   'voyager': ['M1'],
#   'par': ['M6', 'Z5'],
#   'sang': ['B1'],
#   'En': ['Z5'],
#   'janvier': ['T1.3'],
#   '2021': ['N1'],
#   'scanner': ['Z99'],
#   'routine': ['A6.2+', 'X4.2', 'K4'],
#   'révélé': ['A10+'],
#   'mauvaises': ['Z99'],
#   'nouvelles': ['T3-'],
#   'avais': ['A9+', 'Z5', 'A2.2', 'S4'],
#   'lésions': ['Z99'],
#   'foie': ['B1', 'F1', 'S2mf'],
#   'chirurgien': ['B3/S2mf'],
#   "m'": ['Z8'],
#   'annoncé': ['Q2.2'],
#   "c'": ['Z8'],
#   'inopérable': ['Z99'],
#   'désormais': ['Z99'],
#   'atteint': ['M1', 'N3.3', 'Q2.1', 'X9.2+'],
#   '4': ['N1'],
#   'avec': ['Z5'],
#   'métastases': ['Z99'],
#   'hépatiques': ['Z99'],
#   'inopérables': ['Z99'],
#   'deux': ['N1', 'T3', 'T1.2'],
#   'jeunes': ['T3-'],
#   'garçons': ['S2.2m', 'L2m@', 'Z4'],
#   '5': ['N1'],
#   'ans': ['T1.3', 'P1c'],
#   'pouvais': ['Z99'],
#   'orphelins': ['Z99'],
#   "C'": ['Z8'],
#   'pendant': ['Z5'],
#   'confinement': ['Z99'],
#   'Covid-19': ['Z99'],
#   'ma': ['Z5'],
#   'famille': ['S4c', 'A4.1c'],
#   'mes': ['Z5'],
#   'enfants': ['S2mf/T3-', 'S4mf'],
#   'pouvaient': ['Z99'],
#   'pas': ['Z99'],
#   'accompagner': ['S3.1', 'K2', 'T1.1.2'],
#   'hôpital': ['B3/H1c'],
#   'cause': ['A2.2', 'X2.1', 'X4.1', 'Z5/A2.2'],
#   'restrictions': ['A1.7+'],
#   'Néanmoins': ['Z4'],
#   'suis': ['Z99'],
#   'genre': ['Z99'],
#   'abandonner': ['Z99'],
#   'pris': ['A9+',
#    'T1.3',
#    'C1',
#    'A1.1.1',
#    'M2',
#    'S7.1-',
#    'A2.1+',
#    'X2.4',
#    'S6+',
#    'S7.4+',
#    'N3',
#    'A2.1+',
#    'P1',
#    'M1',
#    'X2.5+',
#    'F1@',
#    'F2@',
#    'Q1.2@',
#    'B3@'],
#   'cela': ['Z8'],
#   'comme': ['Z5'],
#   'défi': ['A12-', 'A6.1-', 'S7.3+', 'E3-', 'Q2.2'],
#   'relever': ['M2',
#    'N5+/A2.1',
#    'A5.1+/A2.1',
#    'X3.2++',
#    'A9+',
#    'A1.1.1',
#    'A2.2',
#    'S1.1.1',
#    'F4',
#    'Q2.2',
#    'S4'],
#   'Avec': ['Z5'],
#   'peu': ['A13.7', 'N3.2-', 'T3-', 'N3.7-', 'N3.3-', 'T1.3-', 'A11.1-', 'N5-'],
#   'chances': ['Z99'],
#   'départ': ['M1', 'T2+'],
#   'déclaré': ['Q2.2', 'K5.1%'],
#   'sans': ['M6', 'Z5'],
#   'signe': ['Q1.1',
#    'A6.2+',
#    'X4.1',
#    'Q1.2',
#    'O4.1',
#    'S9',
#    'B2',
#    'M2',
#    'K2',
#    'G2.1',
#    'I3.1'],
#   '1,5': ['N1'],
#   'an': ['T1.3', 'P1c'],
#   'chimiothérapie': ['Z99'],
#   'radiothérapie': ['Z99'],
#   'extrêmement': ['A13.3'],
#   'éprouvante': ['Z99'],
#   'Je': ['Z8mf'],
#   "n'": ['Z6'],
#   'même': ['Z99'],
#   'besoin': ['S6+'],
#   'nous': ['Z8'],
#   'croisions': ['M1',
#    'M6',
#    'S8-',
#    'A1.8+',
#    'A6.3+',
#    'F4/L2',
#    'O4.4',
#    'Q1.2',
#    'E3-',
#    'S1.1.1',
#    'S9@'],
#   'doigts': ['B1', 'O4.4', 'X3.3'],
#   'pour': ['Z5'],
#   'il': ['Z8'],
#   'revienne': ['Z99'],
#   'jamais': ['T1/Z6'],
#   'Il': ['Z8'],
#   'est': ['M6'],
#   'revenu': ['I1.1'],
#   'allait': ['M1',
#    'A2.1+',
#    'A1.1.1',
#    'A9-',
#    'A1.8+',
#    'Q2.1',
#    'N6+',
#    'I2.2',
#    'A1.1.2',
#    'T2-',
#    'S3.2',
#    'A6.3+',
#    'B2-/X1%',
#    'B1%'],
#   'devenir': ['A2.1+', 'O4.2+'],
#   'nouveau': ['T3-'],
#   'Les': ['Z5'],
#   'suspectaient': ['Z99'],
#   'quelque': ['A13.5', 'N5', 'Z5'],
#   'chose': ['O2', 'X4.1', 'A7-', 'S2mf', 'L2mf'],
#   'thyroïde': ['Z99'],
#   'lors': ['Z99'],
#   'contrôle': ['S7.1+', 'A1.7+', 'O2'],
#   'Après': ['Z5'],
#   'examens': ['P1', 'B3%', 'X2.4%'],
#   'supplémentaires': ['N5++'],
#   'biopsies': ['Z99'],
#   'aiguille': ['Z99'],
#   'maintenant': ['T1.1.2', 'Z4', 'Z5'],
#   'dit': ['Q2.1', 'Z4%'],
#   ':': ['PUNCT'],
#   '"': ['PUNCT'],
#   'meh': ['Z99'],
#   'ça': ['Z8'],
#   'c’': ['Z99'],
#   'facile': ['A12+'],
#   'Hier': ['T1.1.1'],
#   'on': ['Z8'],
#   'toute': ['Z8'],
#   'faisait': ['Z99'],
#   'déjà': ['T1.1.1'],
#   'C’': ['Z99'],
#   'sais': ['X2.2+', 'S3.2/B1%'],
#   'ce': ['Z8'],
#   'qui': ['Z8'],
#   'm’': ['Z99'],
#   'attend': ['T1.3', 'A3+', 'A11.1+', 'S1.1.1%'],
#   'importe': ['Z99'],
#   'continuerai': ['T2++'],
#   'battre': ['Z99'],
#   'attendant': ['Z99'],
#   'suivrai': ['M1',
#    'N4',
#    'S7.1-',
#    'X2.4',
#    'X2.5+',
#    'A6.1+',
#    'A1.1.1',
#    'A2.2',
#    'K5.1',
#    'X3.4'],
#   'préventive': ['S8-'],
#   'tous': ['Z8'],
#   '6': ['N1'],
#   'mois': ['T1.3'],
#   'tout': ['Z8'],
#   'continuant': ['T2++'],
#   'profiter': ['Z99'],
#   'Alors': ['Z99'],
#   'camarade': ['Z99'],
#   'vois': ['X3.4',
#    'X2.1',
#    'S1.1.1',
#    'X2.5+',
#    'X2.3+',
#    'X3',
#    'A7+',
#    'Z4',
#    'S3.2'],
#   'Tu': ['Z8mf'],
#   'as': ['Z99'],
#   'toi': ['Z8'],
#   'force': ['E3-', 'S7.1+', 'G2.1c', 'N3', 'S5+c', 'A1.1.1'],
#   'optimisme': ['X2.6+/A5.1+'],
#   'nécessaires': ['Z99'],
#   'quel': ['Z5'],
#   'point': ['A10+',
#    'M6',
#    'H1',
#    'Q2.1',
#    'X4.1',
#    'A5.1',
#    'A1.5.2',
#    'M7',
#    'T1.2',
#    'O4.4',
#    'O3',
#    'K5'],
#   'vie': ['L1+',
#    'A3+',
#    'T1.3',
#    'S1.1.1',
#    'A1.1.1',
#    'X5.2+',
#    'Q4.1',
#    'A11.1+++',
#    'A5.4+/C1'],
#   'dure': ['O4.1', 'X8+', 'X5.2+', 'N5+', 'A12-', 'O4.5', 'S1.2.5+'],
#   'Garde': ['A1.1.1/A15+', 'X3.4/A15+', 'A15+/I3.2/S2mf', 'O2/A15+'],
#   'tête': ['B1',
#    'S7.1+/S2mf',
#    'P1/S2mf',
#    'X1',
#    'M6',
#    'A4.1',
#    'S2mf',
#    'F2',
#    'H5/M4%',
#    'S7.1+',
#    'K5.1',
#    'M1',
#    'N5',
#    'A2.1+',
#    'A11.1+',
#    'Q1.2',
#    'T1.1.3'],
#   'haute': ['Z99'],
#   'continue': ['T2++'],
#   'marquer': ['O4.2-', 'Q1.2', 'A5/P1', 'N3.1', 'Q1.1'],
#   'buts': ['Z99']}}

# %% [markdown]
# ---
#
# ### **STEP 5: Extracting emotion words using USAS emotion tags:** *usas_emotion_tags function*
#
# >>**input:** piece of text
#
# >>**output:** python dictionary where *keys* represent a sentence in the input text and *values* represent a dictionary of usas tagged emotion words and tags for that sentence
#
# ---

# %%
usas_emo_cls_dict = {'E1': 'Emotional Actions, States And Processes General',
 'E1+': 'Emotional',
 'E1-': 'Unemotional',
 'E2': 'Liking',
 'E2+': 'Like',
 'E2-': 'Dislike',
 'E3': 'Calm/Violent/Angry',
 'E3+': 'Calm',
 'E3-': 'Violent/Angry',
 'E4': 'Happiness and Contentment',
 'E4.1': 'Happy/sad',
 'E4.1+': 'Happy',
 'E4.1-': 'Sad',
 'E4.2': 'Contentment',
 'E4.2+': 'Content',
 'E4.2-': 'Discontent',
 'E5': 'Bravery and Fear',
 'E5+': 'Bravery',
 'E5-': 'Fear/shock',
 'E6': 'Worry and confidence',
 'E6+': 'Confident',
 'E6-': 'Worry'}

# %%
# Defining the emotion tag extraction function
def usas_emotion_tags(text):
  usas_eval_tags = {}
  sentences = re.split(r'(。|！|\!|？|\?)', text)
  for i in range(len(sentences)):
    if(sentences[i]):
      usas_list = {}
      sent = nlp(sentences[i])
      print("\n")
      print(Fore.MAGENTA + Style.BRIGHT + "--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
      print(Fore.BLUE + Style.BRIGHT + f"Sentence {i}:", sentences[i])
      for token in sent:
        tags = token._.pymusas_tags
        emo_tags = [x for x in tags if x.startswith('E')]
        if emo_tags:
          usas_list[token.text] = emo_tags
          print(Fore.MAGENTA + f'{token.text}:' + Fore.GREEN, emo_tags)
      usas_eval_tags[sentences[i]] = usas_list
  return usas_eval_tags

# %%
# Text 1 emotion tag extraction
text1_emo_tags = usas_emotion_tags(text_1)
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Sentence 0:  Bonjour camarades, je voulais juste partager mon histoire après une opération où j'ai marqué un autre but contre le cancer, menant 3-0. J'espère qu'elle inspirera quelqu'un.
#
# J'ai été diagnostiqué d'un cancer du côlon en mai 2020 lorsque j'ai eu une hémorragie majeure. Avant que je ne réalise, les chirurgiens avaient retiré 30 cm de mon côlon. La récupération a été difficile, mais gérable. Le côté positif était que, malgré la taille de la tumeur, les ganglions lymphatiques étaient indemnes, me plaçant au stade 2. Selon les médecins, j'étais guéri, l'un des chanceux à laisser le cancer derrière soi et à raconter son histoire autour d'un verre. Le score était de 1-0.
#
# Pourtant, j'ai vite appris que cette saloperie pouvait aussi voyager par le sang. En janvier 2021, un scanner de routine a révélé de mauvaises nouvelles. J'avais des lésions au foie et le chirurgien m'a annoncé que c'était inopérable. J'étais désormais atteint d'un cancer du côlon de stade 4 avec métastases hépatiques inopérables et deux jeunes garçons de 3 et 5 ans que je ne pouvais laisser orphelins.
#
# C'était pendant le confinement du Covid-19, ma famille et mes enfants ne pouvaient pas m'accompagner à l'hôpital à cause des restrictions.
#
# Néanmoins, je ne suis pas du genre à abandonner, j'ai pris cela comme un défi à relever. Avec peu de chances au départ, j'ai été déclaré sans signe de cancer après 1,5 an de chimiothérapie et de radiothérapie extrêmement éprouvante. Je n'ai même pas eu besoin d'une opération du foie. Le score était de 2-0, et nous croisions les doigts pour qu'il ne revienne jamais.
#
# Il n'est pas revenu, mais un autre cancer allait devenir mon nouveau défi. Les médecins suspectaient quelque chose à la thyroïde lors d'un contrôle de routine. Après des examens supplémentaires et des biopsies à l'aiguille, j'ai appris que j'avais maintenant un cancer de la thyroïde. Je me suis dit : "meh, ça c’est facile".
#
# Hier, on m'a retiré toute la thyroïde. La tumeur faisait déjà 2 cm. C’est désormais 3-0. Je ne sais pas ce qui m’attend, mais peu importe, je continuerai à me battre. En attendant, je suivrai une chimiothérapie préventive tous les 6 mois tout en continuant à profiter de mes enfants.
#
# Alors camarade, vois cela comme un défi à relever. Tu as en toi la force et l'optimisme nécessaires, peu importe à quel point la vie est dure. Garde la tête haute et continue à marquer des buts.
# espère: ['E4.1+']
# défi: ['E3-']
# croisions: ['E3-']
# défi: ['E3-']
# défi: ['E3-']
# force: ['E3-']

# %%
text1_emo_tags
# Out:
# {' Bonjour camarades, je voulais juste partager mon histoire après une opération où j\'ai marqué un autre but contre le cancer, menant 3-0. J\'espère qu\'elle inspirera quelqu\'un.\n\nJ\'ai été diagnostiqué d\'un cancer du côlon en mai 2020 lorsque j\'ai eu une hémorragie majeure. Avant que je ne réalise, les chirurgiens avaient retiré 30\xa0cm de mon côlon. La récupération a été difficile, mais gérable. Le côté positif était que, malgré la taille de la tumeur, les ganglions lymphatiques étaient indemnes, me plaçant au stade\xa02. Selon les médecins, j\'étais guéri, l\'un des chanceux à laisser le cancer derrière soi et à raconter son histoire autour d\'un verre. Le score était de 1-0.\n\nPourtant, j\'ai vite appris que cette saloperie pouvait aussi voyager par le sang. En janvier\xa02021, un scanner de routine a révélé de mauvaises nouvelles. J\'avais des lésions au foie et le chirurgien m\'a annoncé que c\'était inopérable. J\'étais désormais atteint d\'un cancer du côlon de stade\xa04 avec métastases hépatiques inopérables et deux jeunes garçons de 3 et 5\xa0ans que je ne pouvais laisser orphelins.\n\nC\'était pendant le confinement du Covid-19, ma famille et mes enfants ne pouvaient pas m\'accompagner à l\'hôpital à cause des restrictions.\n\nNéanmoins, je ne suis pas du genre à abandonner, j\'ai pris cela comme un défi à relever. Avec peu de chances au départ, j\'ai été déclaré sans signe de cancer après 1,5\xa0an de chimiothérapie et de radiothérapie extrêmement éprouvante. Je n\'ai même pas eu besoin d\'une opération du foie. Le score était de 2-0, et nous croisions les doigts pour qu\'il ne revienne jamais.\n\nIl n\'est pas revenu, mais un autre cancer allait devenir mon nouveau défi. Les médecins suspectaient quelque chose à la thyroïde lors d\'un contrôle de routine. Après des examens supplémentaires et des biopsies à l\'aiguille, j\'ai appris que j\'avais maintenant un cancer de la thyroïde. Je me suis dit : "meh, ça c’est facile".\n\nHier, on m\'a retiré toute la thyroïde. La tumeur faisait déjà 2\xa0cm. C’est désormais 3-0. Je ne sais pas ce qui m’attend, mais peu importe, je continuerai à me battre. En attendant, je suivrai une chimiothérapie préventive tous les 6\xa0mois tout en continuant à profiter de mes enfants.\n\nAlors camarade, vois cela comme un défi à relever. Tu as en toi la force et l\'optimisme nécessaires, peu importe à quel point la vie est dure. Garde la tête haute et continue à marquer des buts.': {'espère': ['E4.1+'],
#   'défi': ['E3-'],
#   'croisions': ['E3-'],
#   'force': ['E3-']}}

# %% [markdown]
# ---
#
# ### **STEP 6: USAS Sentiment Classification:** *usas_sentiment_classifier function*
#
# >>**input:** dictionary of sentence and emotion word tags
#
# >>**output:** sentiment class *positive*, *negative*, *neutral* with counts per class
#
# ---

# %%
# Defining the sentiment classifier
def usas_sentiment_classifier(usas_emo_tag, positive, negative, neutral):
  sentiment_cls = {}
  for sent, emo_dict in usas_emo_tag.items():
    neg, pos, neu = 0, 0, 0
    if(emo_dict):
      for key, val_list in emo_dict.items():
        for val in val_list:
          if val.endswith('-'):
            neg+=1
            negative+=1
          elif  val.endswith('+'):
            pos+=1
            positive+=1
          else:
            neu+=1
            neutral+=1
    else:
      neu+=1
      neutral+=1
    if neg==max(pos, neg, neu):
          sentiment = 'negative'
          sentiment_cls[sent] = sentiment
    elif pos==max(pos, neg, neu):
          sentiment = 'positive'
          sentiment_cls[sent] = sentiment
    else:
          sentiment = 'neutral'
          sentiment_cls[sent] = sentiment
    print(Fore.MAGENTA + Style.BRIGHT + "Sentence:", sent)
    print(Fore.GREEN + Style.BRIGHT + "class:", sentiment)
    print("\n")
    print(Fore.GREEN + Style.BRIGHT + "--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
  return sentiment_cls, positive, negative, neutral

# %%
# Sentiment counts and tagging
sentiments_text1, pos_text1, neg_text1, neu_text1 = usas_sentiment_classifier(text1_emo_tags, 0, 0, 0)
# Out:
# Sentence:  Bonjour camarades, je voulais juste partager mon histoire après une opération où j'ai marqué un autre but contre le cancer, menant 3-0. J'espère qu'elle inspirera quelqu'un.
#
# J'ai été diagnostiqué d'un cancer du côlon en mai 2020 lorsque j'ai eu une hémorragie majeure. Avant que je ne réalise, les chirurgiens avaient retiré 30 cm de mon côlon. La récupération a été difficile, mais gérable. Le côté positif était que, malgré la taille de la tumeur, les ganglions lymphatiques étaient indemnes, me plaçant au stade 2. Selon les médecins, j'étais guéri, l'un des chanceux à laisser le cancer derrière soi et à raconter son histoire autour d'un verre. Le score était de 1-0.
#
# Pourtant, j'ai vite appris que cette saloperie pouvait aussi voyager par le sang. En janvier 2021, un scanner de routine a révélé de mauvaises nouvelles. J'avais des lésions au foie et le chirurgien m'a annoncé que c'était inopérable. J'étais désormais atteint d'un cancer du côlon de stade 4 avec métastases hépatiques inopérables et deux jeunes garçons de 3 et 5 ans que je ne pouvais laisser orphelins.
#
# C'était pendant le confinement du Covid-19, ma famille et mes enfants ne pouvaient pas m'accompagner à l'hôpital à cause des restrictions.
#
# Néanmoins, je ne suis pas du genre à abandonner, j'ai pris cela comme un défi à relever. Avec peu de chances au départ, j'ai été déclaré sans signe de cancer après 1,5 an de chimiothérapie et de radiothérapie extrêmement éprouvante. Je n'ai même pas eu besoin d'une opération du foie. Le score était de 2-0, et nous croisions les doigts pour qu'il ne revienne jamais.
#
# Il n'est pas revenu, mais un autre cancer allait devenir mon nouveau défi. Les médecins suspectaient quelque chose à la thyroïde lors d'un contrôle de routine. Après des examens supplémentaires et des biopsies à l'aiguille, j'ai appris que j'avais maintenant un cancer de la thyroïde. Je me suis dit : "meh, ça c’est facile".
#
# Hier, on m'a retiré toute la thyroïde. La tumeur faisait déjà 2 cm. C’est désormais 3-0. Je ne sais pas ce qui m’attend, mais peu importe, je continuerai à me battre. En attendant, je suivrai une chimiothérapie préventive tous les 6 mois tout en continuant à profiter de mes enfants.
#
# Alors camarade, vois cela comme un défi à relever. Tu as en toi la force et l'optimisme nécessaires, peu importe à quel point la vie est dure. Garde la tête haute et continue à marquer des buts.
# class: negative
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Text 1 sentiment tags per sentence
sentiments_text1
# Out:
# {' Bonjour camarades, je voulais juste partager mon histoire après une opération où j\'ai marqué un autre but contre le cancer, menant 3-0. J\'espère qu\'elle inspirera quelqu\'un.\n\nJ\'ai été diagnostiqué d\'un cancer du côlon en mai 2020 lorsque j\'ai eu une hémorragie majeure. Avant que je ne réalise, les chirurgiens avaient retiré 30\xa0cm de mon côlon. La récupération a été difficile, mais gérable. Le côté positif était que, malgré la taille de la tumeur, les ganglions lymphatiques étaient indemnes, me plaçant au stade\xa02. Selon les médecins, j\'étais guéri, l\'un des chanceux à laisser le cancer derrière soi et à raconter son histoire autour d\'un verre. Le score était de 1-0.\n\nPourtant, j\'ai vite appris que cette saloperie pouvait aussi voyager par le sang. En janvier\xa02021, un scanner de routine a révélé de mauvaises nouvelles. J\'avais des lésions au foie et le chirurgien m\'a annoncé que c\'était inopérable. J\'étais désormais atteint d\'un cancer du côlon de stade\xa04 avec métastases hépatiques inopérables et deux jeunes garçons de 3 et 5\xa0ans que je ne pouvais laisser orphelins.\n\nC\'était pendant le confinement du Covid-19, ma famille et mes enfants ne pouvaient pas m\'accompagner à l\'hôpital à cause des restrictions.\n\nNéanmoins, je ne suis pas du genre à abandonner, j\'ai pris cela comme un défi à relever. Avec peu de chances au départ, j\'ai été déclaré sans signe de cancer après 1,5\xa0an de chimiothérapie et de radiothérapie extrêmement éprouvante. Je n\'ai même pas eu besoin d\'une opération du foie. Le score était de 2-0, et nous croisions les doigts pour qu\'il ne revienne jamais.\n\nIl n\'est pas revenu, mais un autre cancer allait devenir mon nouveau défi. Les médecins suspectaient quelque chose à la thyroïde lors d\'un contrôle de routine. Après des examens supplémentaires et des biopsies à l\'aiguille, j\'ai appris que j\'avais maintenant un cancer de la thyroïde. Je me suis dit : "meh, ça c’est facile".\n\nHier, on m\'a retiré toute la thyroïde. La tumeur faisait déjà 2\xa0cm. C’est désormais 3-0. Je ne sais pas ce qui m’attend, mais peu importe, je continuerai à me battre. En attendant, je suivrai une chimiothérapie préventive tous les 6\xa0mois tout en continuant à profiter de mes enfants.\n\nAlors camarade, vois cela comme un défi à relever. Tu as en toi la force et l\'optimisme nécessaires, peu importe à quel point la vie est dure. Garde la tête haute et continue à marquer des buts.': 'negative'}

# %%
# Text 1 sentiment counts for per class
print(f'Text 1: positive = {pos_text1}, negative = {neg_text1}, neutral = {neu_text1}')
# Out:
# Text 1: positive = 1, negative = 3, neutral = 0

# %%
text1_emo_tags
# Out:
# {' Bonjour camarades, je voulais juste partager mon histoire après une opération où j\'ai marqué un autre but contre le cancer, menant 3-0. J\'espère qu\'elle inspirera quelqu\'un.\n\nJ\'ai été diagnostiqué d\'un cancer du côlon en mai 2020 lorsque j\'ai eu une hémorragie majeure. Avant que je ne réalise, les chirurgiens avaient retiré 30\xa0cm de mon côlon. La récupération a été difficile, mais gérable. Le côté positif était que, malgré la taille de la tumeur, les ganglions lymphatiques étaient indemnes, me plaçant au stade\xa02. Selon les médecins, j\'étais guéri, l\'un des chanceux à laisser le cancer derrière soi et à raconter son histoire autour d\'un verre. Le score était de 1-0.\n\nPourtant, j\'ai vite appris que cette saloperie pouvait aussi voyager par le sang. En janvier\xa02021, un scanner de routine a révélé de mauvaises nouvelles. J\'avais des lésions au foie et le chirurgien m\'a annoncé que c\'était inopérable. J\'étais désormais atteint d\'un cancer du côlon de stade\xa04 avec métastases hépatiques inopérables et deux jeunes garçons de 3 et 5\xa0ans que je ne pouvais laisser orphelins.\n\nC\'était pendant le confinement du Covid-19, ma famille et mes enfants ne pouvaient pas m\'accompagner à l\'hôpital à cause des restrictions.\n\nNéanmoins, je ne suis pas du genre à abandonner, j\'ai pris cela comme un défi à relever. Avec peu de chances au départ, j\'ai été déclaré sans signe de cancer après 1,5\xa0an de chimiothérapie et de radiothérapie extrêmement éprouvante. Je n\'ai même pas eu besoin d\'une opération du foie. Le score était de 2-0, et nous croisions les doigts pour qu\'il ne revienne jamais.\n\nIl n\'est pas revenu, mais un autre cancer allait devenir mon nouveau défi. Les médecins suspectaient quelque chose à la thyroïde lors d\'un contrôle de routine. Après des examens supplémentaires et des biopsies à l\'aiguille, j\'ai appris que j\'avais maintenant un cancer de la thyroïde. Je me suis dit : "meh, ça c’est facile".\n\nHier, on m\'a retiré toute la thyroïde. La tumeur faisait déjà 2\xa0cm. C’est désormais 3-0. Je ne sais pas ce qui m’attend, mais peu importe, je continuerai à me battre. En attendant, je suivrai une chimiothérapie préventive tous les 6\xa0mois tout en continuant à profiter de mes enfants.\n\nAlors camarade, vois cela comme un défi à relever. Tu as en toi la force et l\'optimisme nécessaires, peu importe à quel point la vie est dure. Garde la tête haute et continue à marquer des buts.': {'espère': ['E4.1+'],
#   'défi': ['E3-'],
#   'croisions': ['E3-'],
#   'force': ['E3-']}}

# %% [markdown]
# ---
# ### **STEP 7: Sentiment Probability - Sentence-level**
# ---

# %%
# Defining the probability estimation function for sentiment classification at the sentence-level
def sentence_sentiment_prob(usas_emo_tag):
  sentiment_cls = {}
  for sent, emo_dict in usas_emo_tag.items():
    neg, pos, neu = 0, 0, 0
    if(emo_dict):
      for key, val_list in emo_dict.items():
        for val in val_list:
          if val.endswith('-'):
            neg+=1
          elif val.endswith('+'):
            pos+=1
          else:
            neu+=1
    else:
      neu+=1
    sentiment = f'positive={pos/(pos+neg+neu)}, negative={neg/(pos+neg+neu)}, neutral={neu/(pos+neg+neu)}'
    sentiment_cls[sent] = sentiment
    print(Fore.GREEN + Style.BRIGHT + "Sentence:", sent)
    print(Fore.CYAN + Style.BRIGHT + "class:", sentiment)
    print("\n")
    print(Fore.CYAN + Style.BRIGHT + "--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
  return sentiment_cls

# %%
# Text 1 sentence-level sentiment probability
sentiment_prob_text1 = (sentence_sentiment_prob(text1_emo_tags))
# Out:
# Sentence:  Bonjour camarades, je voulais juste partager mon histoire après une opération où j'ai marqué un autre but contre le cancer, menant 3-0. J'espère qu'elle inspirera quelqu'un.
#
# J'ai été diagnostiqué d'un cancer du côlon en mai 2020 lorsque j'ai eu une hémorragie majeure. Avant que je ne réalise, les chirurgiens avaient retiré 30 cm de mon côlon. La récupération a été difficile, mais gérable. Le côté positif était que, malgré la taille de la tumeur, les ganglions lymphatiques étaient indemnes, me plaçant au stade 2. Selon les médecins, j'étais guéri, l'un des chanceux à laisser le cancer derrière soi et à raconter son histoire autour d'un verre. Le score était de 1-0.
#
# Pourtant, j'ai vite appris que cette saloperie pouvait aussi voyager par le sang. En janvier 2021, un scanner de routine a révélé de mauvaises nouvelles. J'avais des lésions au foie et le chirurgien m'a annoncé que c'était inopérable. J'étais désormais atteint d'un cancer du côlon de stade 4 avec métastases hépatiques inopérables et deux jeunes garçons de 3 et 5 ans que je ne pouvais laisser orphelins.
#
# C'était pendant le confinement du Covid-19, ma famille et mes enfants ne pouvaient pas m'accompagner à l'hôpital à cause des restrictions.
#
# Néanmoins, je ne suis pas du genre à abandonner, j'ai pris cela comme un défi à relever. Avec peu de chances au départ, j'ai été déclaré sans signe de cancer après 1,5 an de chimiothérapie et de radiothérapie extrêmement éprouvante. Je n'ai même pas eu besoin d'une opération du foie. Le score était de 2-0, et nous croisions les doigts pour qu'il ne revienne jamais.
#
# Il n'est pas revenu, mais un autre cancer allait devenir mon nouveau défi. Les médecins suspectaient quelque chose à la thyroïde lors d'un contrôle de routine. Après des examens supplémentaires et des biopsies à l'aiguille, j'ai appris que j'avais maintenant un cancer de la thyroïde. Je me suis dit : "meh, ça c’est facile".
#
# Hier, on m'a retiré toute la thyroïde. La tumeur faisait déjà 2 cm. C’est désormais 3-0. Je ne sais pas ce qui m’attend, mais peu importe, je continuerai à me battre. En attendant, je suivrai une chimiothérapie préventive tous les 6 mois tout en continuant à profiter de mes enfants.
#
# Alors camarade, vois cela comme un défi à relever. Tu as en toi la force et l'optimisme nécessaires, peu importe à quel point la vie est dure. Garde la tête haute et continue à marquer des buts.
# class: positive=0.25, negative=0.75, neutral=0.0
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
sentiment_prob_text1
# Out:
# {' Bonjour camarades, je voulais juste partager mon histoire après une opération où j\'ai marqué un autre but contre le cancer, menant 3-0. J\'espère qu\'elle inspirera quelqu\'un.\n\nJ\'ai été diagnostiqué d\'un cancer du côlon en mai 2020 lorsque j\'ai eu une hémorragie majeure. Avant que je ne réalise, les chirurgiens avaient retiré 30\xa0cm de mon côlon. La récupération a été difficile, mais gérable. Le côté positif était que, malgré la taille de la tumeur, les ganglions lymphatiques étaient indemnes, me plaçant au stade\xa02. Selon les médecins, j\'étais guéri, l\'un des chanceux à laisser le cancer derrière soi et à raconter son histoire autour d\'un verre. Le score était de 1-0.\n\nPourtant, j\'ai vite appris que cette saloperie pouvait aussi voyager par le sang. En janvier\xa02021, un scanner de routine a révélé de mauvaises nouvelles. J\'avais des lésions au foie et le chirurgien m\'a annoncé que c\'était inopérable. J\'étais désormais atteint d\'un cancer du côlon de stade\xa04 avec métastases hépatiques inopérables et deux jeunes garçons de 3 et 5\xa0ans que je ne pouvais laisser orphelins.\n\nC\'était pendant le confinement du Covid-19, ma famille et mes enfants ne pouvaient pas m\'accompagner à l\'hôpital à cause des restrictions.\n\nNéanmoins, je ne suis pas du genre à abandonner, j\'ai pris cela comme un défi à relever. Avec peu de chances au départ, j\'ai été déclaré sans signe de cancer après 1,5\xa0an de chimiothérapie et de radiothérapie extrêmement éprouvante. Je n\'ai même pas eu besoin d\'une opération du foie. Le score était de 2-0, et nous croisions les doigts pour qu\'il ne revienne jamais.\n\nIl n\'est pas revenu, mais un autre cancer allait devenir mon nouveau défi. Les médecins suspectaient quelque chose à la thyroïde lors d\'un contrôle de routine. Après des examens supplémentaires et des biopsies à l\'aiguille, j\'ai appris que j\'avais maintenant un cancer de la thyroïde. Je me suis dit : "meh, ça c’est facile".\n\nHier, on m\'a retiré toute la thyroïde. La tumeur faisait déjà 2\xa0cm. C’est désormais 3-0. Je ne sais pas ce qui m’attend, mais peu importe, je continuerai à me battre. En attendant, je suivrai une chimiothérapie préventive tous les 6\xa0mois tout en continuant à profiter de mes enfants.\n\nAlors camarade, vois cela comme un défi à relever. Tu as en toi la force et l\'optimisme nécessaires, peu importe à quel point la vie est dure. Garde la tête haute et continue à marquer des buts.': 'positive=0.25, negative=0.75, neutral=0.0'}

# %% [markdown]
# ---
# ### **STEP 8: Sentiment Probability -Text-level**
# ---

# %%
def text_sentiment_prob(text, pos, neg, neu):
  prob = f'positive={pos/(pos+neg+neu)}, negative={neg/(pos+neg+neu)}, neutral={neu/(pos+neg+neu)}'
  print(Fore.CYAN+ text)
  print(Fore.GREEN+ "----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
  print(prob)
  return prob

# %%
text1_prob = text_sentiment_prob(text_1, pos_text1, neg_text1, neu_text1)
# Out:
#  Bonjour camarades, je voulais juste partager mon histoire après une opération où j'ai marqué un autre but contre le cancer, menant 3-0. J'espère qu'elle inspirera quelqu'un.
#
# J'ai été diagnostiqué d'un cancer du côlon en mai 2020 lorsque j'ai eu une hémorragie majeure. Avant que je ne réalise, les chirurgiens avaient retiré 30 cm de mon côlon. La récupération a été difficile, mais gérable. Le côté positif était que, malgré la taille de la tumeur, les ganglions lymphatiques étaient indemnes, me plaçant au stade 2. Selon les médecins, j'étais guéri, l'un des chanceux à laisser le cancer derrière soi et à raconter son histoire autour d'un verre. Le score était de 1-0.
#
# Pourtant, j'ai vite appris que cette saloperie pouvait aussi voyager par le sang. En janvier 2021, un scanner de routine a révélé de mauvaises nouvelles. J'avais des lésions au foie et le chirurgien m'a annoncé que c'était inopérable. J'étais désormais atteint d'un cancer du côlon de stade 4 avec métastases hépatiques inopérables et deux jeunes garçons de 3 et 5 ans que je ne pouvais laisser orphelins.
#
# C'était pendant le confinement du Covid-19, ma famille et mes enfants ne pouvaient pas m'accompagner à l'hôpital à cause des restrictions.
#
# Néanmoins, je ne suis pas du genre à abandonner, j'ai pris cela comme un défi à relever. Avec peu de chances au départ, j'ai été déclaré sans signe de cancer après 1,5 an de chimiothérapie et de radiothérapie extrêmement éprouvante. Je n'ai même pas eu besoin d'une opération du foie. Le score était de 2-0, et nous croisions les doigts pour qu'il ne revienne jamais.
#
# Il n'est pas revenu, mais un autre cancer allait devenir mon nouveau défi. Les médecins suspectaient quelque chose à la thyroïde lors d'un contrôle de routine. Après des examens supplémentaires et des biopsies à l'aiguille, j'ai appris que j'avais maintenant un cancer de la thyroïde. Je me suis dit : "meh, ça c’est facile".
#
# Hier, on m'a retiré toute la thyroïde. La tumeur faisait déjà 2 cm. C’est désormais 3-0. Je ne sais pas ce qui m’attend, mais peu importe, je continuerai à me battre. En attendant, je suivrai une chimiothérapie préventive tous les 6 mois tout en continuant à profiter de mes enfants.
#
# Alors camarade, vois cela comme un défi à relever. Tu as en toi la force et l'optimisme nécessaires, peu importe à quel point la vie est dure. Garde la tête haute et continue à marquer des buts.
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# positive=0.25, negative=0.75, neutral=0.0
